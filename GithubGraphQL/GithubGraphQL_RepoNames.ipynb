# %% [markdown]
# # Queried Repo: Public, Stars >= 5, and Forks >= 5

# %%
import requests
import pandas as pd

# %%
# Open and read file
with open ('../../../Auth_Keys/graphql_api_auth.txt') as file:
    token = file.read()
    
# Specify the Authorization code
headers = {"Authorization": 'Bearer ' + token}

# %%
# Function to use requests.post to make an API call
def run_query(query): 
    request = requests.post('https://api.github.com/graphql', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

# %% [markdown]
# ## Randomize Date time

# %%
import random
import numpy as np
import datetime
import time

# %%
# Change start and end date to date time object
date_time_start = datetime.date(2008,8,23)
date_time_end = datetime.date(2019,8,29)

# Convert start and end dates to unix
unix_start = time.mktime(date_time_start.timetuple())
unix_end = time.mktime(date_time_end.timetuple())

# Get a random date between the dates
rand_range = random.randrange(unix_start, unix_end)

# https://stackoverflow.com/questions/3682748/converting-unix-timestamp-string-to-readable-date
# Change unix the utc format
date_query = datetime.datetime.utcfromtimestamp(rand_range).strftime('%Y-%m-%dT%H')#:%M:%SZ')

# %%
def get_date():
    rand_range = random.randrange(unix_start, unix_end)
    return datetime.datetime.utcfromtimestamp(rand_range).strftime('%Y-%m-%dT%H')#:%M:%SZ')

def to_df(result):
    
    # Get the keys of nodes.
    data = result['data']['search']['nodes']
    
    # Put the data into a dataframe
    df_repo = pd.DataFrame(data)
    
    return df_repo

# %%
query_2 = '''
{{
  search(query: "is:public stars:>=5 forks:>=5 created:{date_query}", type: REPOSITORY, first:1) {{
    repositoryCount
    pageInfo {{
      endCursor
      hasNextPage
    }}
    nodes {{
      ... on Repository {{
        id
        createdAt
        updatedAt
        owner {{
          login
        }}
        name
        nameWithOwner
        primaryLanguage {{
          name
        }}
        description
        hasIssuesEnabled
        hasWikiEnabled
        licenseInfo {{
          spdxId
        }}
        object(expression:"master:README.md") {{
          ... on Blob {{
            text
          }}
        }}
        second_object: object(expression: "master") {{
          ... on Commit {{
            history {{
              totalCount
            }}
          }}
        }}
        forkCount
        stargazers {{
          totalCount
        }}
        issues {{
          totalCount
        }}
        pullRequests {{
          totalCount
        }}
      }}
    }}
  }}
    rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

variables = {
    "date_query": ""
}

# %%
# Instantiate new df
df_repo = pd.DataFrame()

# %%
# Run While Loop below
i=40

while i>=0:
    print('Iteration number: ', i)
    # Get new random date
    variables['date_query'] = get_date()
    print('Random Date Generated')
    
    # Run next queries
    result = run_query(query_2.format(**variables))
    print('Query Finish')
    
    # Save to df
    df_repo_2 = to_df(result)
    print('Saved Query to DF')

    # Concat to existing df_star
    df_repo = pd.concat([df_repo, df_repo_2])
    print('Concat repo successful')
    
    # Iterate next random repo
    i -= 1
    
    print('Next Iteration number: ', i, '\n')
# Out:
# Iteration number:  4480
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4479
#
# Iteration number:  4479
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4478
#
# Iteration number:  4478
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4477
#
# Iteration number:  4477
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4476
#
# Iteration number:  4476
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4475
#
# Iteration number:  4475
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4474
#
# Iteration number:  4474
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4473
#
# Iteration number:  4473
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4472
#
# Iteration number:  4472
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4471
#
# Iteration number:  4471
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4470
#
# Iteration number:  4470
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4469
#
# Iteration number:  4469
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4468
#
# Iteration number:  4468
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4467
#
# Iteration number:  4467
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4466
#
# Iteration number:  4466
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4465
#
# Iteration number:  4465
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4464
#
# Iteration number:  4464
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4463
#
# Iteration number:  4463
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4462
#
# Iteration number:  4462
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4461
#
# Iteration number:  4461
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4460
#
# Iteration number:  4460
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4459
#
# Iteration number:  4459
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4458
#
# Iteration number:  4458
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4457
#
# Iteration number:  4457
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4456
#
# Iteration number:  4456
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4455
#
# Iteration number:  4455
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4454
#
# Iteration number:  4454
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4453
#
# Iteration number:  4453
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4452
#
# Iteration number:  4452
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4451
#
# Iteration number:  4451
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4450
#
# Iteration number:  4450
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4449
#
# Iteration number:  4449
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4448
#
# Iteration number:  4448
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4447
#
# Iteration number:  4447
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4446
#
# Iteration number:  4446
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4445
#
# Iteration number:  4445
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4444
#
# Iteration number:  4444
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4443
#
# Iteration number:  4443
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4442
#
# Iteration number:  4442
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4441
#
# Iteration number:  4441
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4440
#
# Iteration number:  4440
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4439
#
# Iteration number:  4439
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4438
#
# Iteration number:  4438
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4437
#
# Iteration number:  4437
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4436
#
# Iteration number:  4436
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4435
#
# Iteration number:  4435
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4434
#
# Iteration number:  4434
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4433
#
# Iteration number:  4433
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4432
#
# Iteration number:  4432
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4431
#
# Iteration number:  4431
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4430
#
# Iteration number:  4430
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4429
#
# Iteration number:  4429
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4428
#
# Iteration number:  4428
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4427
#
# Iteration number:  4427
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4426
#
# Iteration number:  4426
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4425
#
# Iteration number:  4425
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4424
#
# Iteration number:  4424
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4423
#
# Iteration number:  4423
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4422
#
# Iteration number:  4422
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4421
#
# Iteration number:  4421
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4420
#
# Iteration number:  4420
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4419
#
# Iteration number:  4419
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4418
#
# Iteration number:  4418
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4417
#
# Iteration number:  4417
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4416
#
# Iteration number:  4416
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4415
#
# Iteration number:  4415
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4414
#
# Iteration number:  4414
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4413
#
# Iteration number:  4413
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4412
#
# Iteration number:  4412
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4411
#
# Iteration number:  4411
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4410
#
# Iteration number:  4410
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4409
#
# Iteration number:  4409
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4408
#
# Iteration number:  4408
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4407
#
# Iteration number:  4407
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4406
#
# Iteration number:  4406
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4405
#
# Iteration number:  4405
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4404
#
# Iteration number:  4404
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4403
#
# Iteration number:  4403
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4402
#
# Iteration number:  4402
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4401
#
# Iteration number:  4401
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4400
#
# Iteration number:  4400
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4399
#
# Iteration number:  4399
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4398
#
# Iteration number:  4398
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4397
#
# Iteration number:  4397
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4396
#
# Iteration number:  4396
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4395
#
# Iteration number:  4395
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4394
#
# Iteration number:  4394
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4393
#
# Iteration number:  4393
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4392
#
# Iteration number:  4392
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4391
#
# Iteration number:  4391
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4390
#
# Iteration number:  4390
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4389
#
# Iteration number:  4389
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4388
#
# Iteration number:  4388
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4387
#
# Iteration number:  4387
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4386
#
# Iteration number:  4386
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4385
#
# Iteration number:  4385
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4384
#
# Iteration number:  4384
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4383
#
# Iteration number:  4383
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4382
#
# Iteration number:  4382
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4381
#
# Iteration number:  4381
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4380
#
# Iteration number:  4380
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4379
#
# Iteration number:  4379
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4378
#
# Iteration number:  4378
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4377
#
# Iteration number:  4377
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4376
#
# Iteration number:  4376
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4375
#
# Iteration number:  4375
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4374
#
# Iteration number:  4374
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4373
#
# Iteration number:  4373
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4372
#
# Iteration number:  4372
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4371
#
# Iteration number:  4371
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4370
#
# Iteration number:  4370
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4369
#
# Iteration number:  4369
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4368
#
# Iteration number:  4368
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4367
#
# Iteration number:  4367
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4366
#
# Iteration number:  4366
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4365
#
# Iteration number:  4365
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4364
#
# Iteration number:  4364
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4363
#
# Iteration number:  4363
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4362
#
# Iteration number:  4362
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4361
#
# Iteration number:  4361
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4360
#
# Iteration number:  4360
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4359
#
# Iteration number:  4359
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4358
#
# Iteration number:  4358
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4357
#
# Iteration number:  4357
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4356
#
# Iteration number:  4356
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4355
#
# Iteration number:  4355
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4354
#
# Iteration number:  4354
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4353
#
# Iteration number:  4353
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4352
#
# Iteration number:  4352
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4351
#
# Iteration number:  4351
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4350
#
# Iteration number:  4350
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4349
#
# Iteration number:  4349
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4348
#
# Iteration number:  4348
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4347
#
# Iteration number:  4347
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4346
#
# Iteration number:  4346
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4345
#
# Iteration number:  4345
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4344
#
# Iteration number:  4344
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4343
#
# Iteration number:  4343
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4342
#
# Iteration number:  4342
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4341
#
# Iteration number:  4341
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4340
#
# Iteration number:  4340
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4339
#
# Iteration number:  4339
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4338
#
# Iteration number:  4338
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4337
#
# Iteration number:  4337
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4336
#
# Iteration number:  4336
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4335
#
# Iteration number:  4335
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4334
#
# Iteration number:  4334
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4333
#
# Iteration number:  4333
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4332
#
# Iteration number:  4332
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4331
#
# Iteration number:  4331
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4330
#
# Iteration number:  4330
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4329
#
# Iteration number:  4329
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4328
#
# Iteration number:  4328
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4327
#
# Iteration number:  4327
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4326
#
# Iteration number:  4326
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4325
#
# Iteration number:  4325
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4324
#
# Iteration number:  4324
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4323
#
# Iteration number:  4323
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4322
#
# Iteration number:  4322
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4321
#
# Iteration number:  4321
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4320
#
# Iteration number:  4320
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4319
#
# Iteration number:  4319
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4318
#
# Iteration number:  4318
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4317
#
# Iteration number:  4317
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4316
#
# Iteration number:  4316
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4315
#
# Iteration number:  4315
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4314
#
# Iteration number:  4314
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4313
#
# Iteration number:  4313
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4312
#
# Iteration number:  4312
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4311
#
# Iteration number:  4311
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4310
#
# Iteration number:  4310
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4309
#
# Iteration number:  4309
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4308
#
# Iteration number:  4308
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4307
#
# Iteration number:  4307
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4306
#
# Iteration number:  4306
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4305
#
# Iteration number:  4305
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4304
#
# Iteration number:  4304
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4303
#
# Iteration number:  4303
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4302
#
# Iteration number:  4302
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4301
#
# Iteration number:  4301
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4300
#
# Iteration number:  4300
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4299
#
# Iteration number:  4299
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4298
#
# Iteration number:  4298
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4297
#
# Iteration number:  4297
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4296
#
# Iteration number:  4296
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4295
#
# Iteration number:  4295
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4294
#
# Iteration number:  4294
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4293
#
# Iteration number:  4293
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4292
#
# Iteration number:  4292
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4291
#
# Iteration number:  4291
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4290
#
# Iteration number:  4290
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4289
#
# Iteration number:  4289
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4288
#
# Iteration number:  4288
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4287
#
# Iteration number:  4287
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4286
#
# Iteration number:  4286
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4285
#
# Iteration number:  4285
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4284
#
# Iteration number:  4284
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4283
#
# Iteration number:  4283
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4282
#
# Iteration number:  4282
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4281
#
# Iteration number:  4281
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4280
#
# Iteration number:  4280
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4279
#
# Iteration number:  4279
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4278
#
# Iteration number:  4278
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4277
#
# Iteration number:  4277
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4276
#
# Iteration number:  4276
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4275
#
# Iteration number:  4275
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4274
#
# Iteration number:  4274
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4273
#
# Iteration number:  4273
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4272
#
# Iteration number:  4272
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4271
#
# Iteration number:  4271
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4270
#
# Iteration number:  4270
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4269
#
# Iteration number:  4269
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4268
#
# Iteration number:  4268
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4267
#
# Iteration number:  4267
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4266
#
# Iteration number:  4266
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4265
#
# Iteration number:  4265
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4264
#
# Iteration number:  4264
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4263
#
# Iteration number:  4263
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4262
#
# Iteration number:  4262
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4261
#
# Iteration number:  4261
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4260
#
# Iteration number:  4260
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4259
#
# Iteration number:  4259
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4258
#
# Iteration number:  4258
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4257
#
# Iteration number:  4257
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4256
#
# Iteration number:  4256
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4255
#
# Iteration number:  4255
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4254
#
# Iteration number:  4254
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4253
#
# Iteration number:  4253
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4252
#
# Iteration number:  4252
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4251
#
# Iteration number:  4251
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4250
#
# Iteration number:  4250
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4249
#
# Iteration number:  4249
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4248
#
# Iteration number:  4248
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4247
#
# Iteration number:  4247
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4246
#
# Iteration number:  4246
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4245
#
# Iteration number:  4245
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4244
#
# Iteration number:  4244
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4243
#
# Iteration number:  4243
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4242
#
# Iteration number:  4242
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4241
#
# Iteration number:  4241
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4240
#
# Iteration number:  4240
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4239
#
# Iteration number:  4239
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4238
#
# Iteration number:  4238
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4237
#
# Iteration number:  4237
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4236
#
# Iteration number:  4236
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4235
#
# Iteration number:  4235
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4234
#
# Iteration number:  4234
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4233
#
# Iteration number:  4233
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4232
#
# Iteration number:  4232
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4231
#
# Iteration number:  4231
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4230
#
# Iteration number:  4230
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4229
#
# Iteration number:  4229
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4228
#
# Iteration number:  4228
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4227
#
# Iteration number:  4227
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4226
#
# Iteration number:  4226
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4225
#
# Iteration number:  4225
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4224
#
# Iteration number:  4224
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4223
#
# Iteration number:  4223
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4222
#
# Iteration number:  4222
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4221
#
# Iteration number:  4221
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4220
#
# Iteration number:  4220
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4219
#
# Iteration number:  4219
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4218
#
# Iteration number:  4218
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4217
#
# Iteration number:  4217
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4216
#
# Iteration number:  4216
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4215
#
# Iteration number:  4215
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4214
#
# Iteration number:  4214
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4213
#
# Iteration number:  4213
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4212
#
# Iteration number:  4212
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4211
#
# Iteration number:  4211
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4210
#
# Iteration number:  4210
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4209
#
# Iteration number:  4209
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4208
#
# Iteration number:  4208
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4207
#
# Iteration number:  4207
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4206
#
# Iteration number:  4206
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4205
#
# Iteration number:  4205
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4204
#
# Iteration number:  4204
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4203
#
# Iteration number:  4203
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4202
#
# Iteration number:  4202
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4201
#
# Iteration number:  4201
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4200
#
# Iteration number:  4200
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4199
#
# Iteration number:  4199
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4198
#
# Iteration number:  4198
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4197
#
# Iteration number:  4197
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4196
#
# Iteration number:  4196
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4195
#
# Iteration number:  4195
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4194
#
# Iteration number:  4194
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4193
#
# Iteration number:  4193
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4192
#
# Iteration number:  4192
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4191
#
# Iteration number:  4191
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4190
#
# Iteration number:  4190
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4189
#
# Iteration number:  4189
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4188
#
# Iteration number:  4188
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4187
#
# Iteration number:  4187
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4186
#
# Iteration number:  4186
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4185
#
# Iteration number:  4185
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4184
#
# Iteration number:  4184
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4183
#
# Iteration number:  4183
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4182
#
# Iteration number:  4182
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4181
#
# Iteration number:  4181
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4180
#
# Iteration number:  4180
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4179
#
# Iteration number:  4179
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4178
#
# Iteration number:  4178
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4177
#
# Iteration number:  4177
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4176
#
# Iteration number:  4176
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4175
#
# Iteration number:  4175
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4174
#
# Iteration number:  4174
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4173
#
# Iteration number:  4173
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4172
#
# Iteration number:  4172
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4171
#
# Iteration number:  4171
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4170
#
# Iteration number:  4170
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4169
#
# Iteration number:  4169
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4168
#
# Iteration number:  4168
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4167
#
# Iteration number:  4167
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4166
#
# Iteration number:  4166
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4165
#
# Iteration number:  4165
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4164
#
# Iteration number:  4164
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4163
#
# Iteration number:  4163
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4162
#
# Iteration number:  4162
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4161
#
# Iteration number:  4161
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4160
#
# Iteration number:  4160
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4159
#
# Iteration number:  4159
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4158
#
# Iteration number:  4158
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4157
#
# Iteration number:  4157
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4156
#
# Iteration number:  4156
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4155
#
# Iteration number:  4155
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4154
#
# Iteration number:  4154
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4153
#
# Iteration number:  4153
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4152
#
# Iteration number:  4152
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4151
#
# Iteration number:  4151
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4150
#
# Iteration number:  4150
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4149
#
# Iteration number:  4149
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4148
#
# Iteration number:  4148
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4147
#
# Iteration number:  4147
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4146
#
# Iteration number:  4146
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4145
#
# Iteration number:  4145
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4144
#
# Iteration number:  4144
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4143
#
# Iteration number:  4143
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4142
#
# Iteration number:  4142
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4141
#
# Iteration number:  4141
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4140
#
# Iteration number:  4140
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4139
#
# Iteration number:  4139
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4138
#
# Iteration number:  4138
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4137
#
# Iteration number:  4137
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4136
#
# Iteration number:  4136
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4135
#
# Iteration number:  4135
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4134
#
# Iteration number:  4134
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4133
#
# Iteration number:  4133
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4132
#
# Iteration number:  4132
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4131
#
# Iteration number:  4131
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4130
#
# Iteration number:  4130
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4129
#
# Iteration number:  4129
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4128
#
# Iteration number:  4128
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4127
#
# Iteration number:  4127
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4126
#
# Iteration number:  4126
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4125
#
# Iteration number:  4125
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4124
#
# Iteration number:  4124
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4123
#
# Iteration number:  4123
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4122
#
# Iteration number:  4122
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4121
#
# Iteration number:  4121
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4120
#
# Iteration number:  4120
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4119
#
# Iteration number:  4119
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4118
#
# Iteration number:  4118
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4117
#
# Iteration number:  4117
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4116
#
# Iteration number:  4116
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4115
#
# Iteration number:  4115
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  4114
#
# Iteration number:  4114
# Random Date Generated
# ...
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3149
#
# Iteration number:  3149
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3148
#
# Iteration number:  3148
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3147
#
# Iteration number:  3147
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3146
#
# Iteration number:  3146
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3145
#
# Iteration number:  3145
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3144
#
# Iteration number:  3144
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3143
#
# Iteration number:  3143
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3142
#
# Iteration number:  3142
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3141
#
# Iteration number:  3141
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3140
#
# Iteration number:  3140
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3139
#
# Iteration number:  3139
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3138
#
# Iteration number:  3138
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3137
#
# Iteration number:  3137
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3136
#
# Iteration number:  3136
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3135
#
# Iteration number:  3135
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3134
#
# Iteration number:  3134
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3133
#
# Iteration number:  3133
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3132
#
# Iteration number:  3132
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3131
#
# Iteration number:  3131
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3130
#
# Iteration number:  3130
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3129
#
# Iteration number:  3129
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3128
#
# Iteration number:  3128
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3127
#
# Iteration number:  3127
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3126
#
# Iteration number:  3126
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3125
#
# Iteration number:  3125
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3124
#
# Iteration number:  3124
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3123
#
# Iteration number:  3123
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3122
#
# Iteration number:  3122
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3121
#
# Iteration number:  3121
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3120
#
# Iteration number:  3120
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3119
#
# Iteration number:  3119
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3118
#
# Iteration number:  3118
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3117
#
# Iteration number:  3117
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3116
#
# Iteration number:  3116
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3115
#
# Iteration number:  3115
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3114
#
# Iteration number:  3114
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3113
#
# Iteration number:  3113
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3112
#
# Iteration number:  3112
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3111
#
# Iteration number:  3111
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3110
#
# Iteration number:  3110
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3109
#
# Iteration number:  3109
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3108
#
# Iteration number:  3108
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3107
#
# Iteration number:  3107
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3106
#
# Iteration number:  3106
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3105
#
# Iteration number:  3105
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3104
#
# Iteration number:  3104
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3103
#
# Iteration number:  3103
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3102
#
# Iteration number:  3102
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3101
#
# Iteration number:  3101
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3100
#
# Iteration number:  3100
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3099
#
# Iteration number:  3099
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3098
#
# Iteration number:  3098
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3097
#
# Iteration number:  3097
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3096
#
# Iteration number:  3096
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3095
#
# Iteration number:  3095
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3094
#
# Iteration number:  3094
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3093
#
# Iteration number:  3093
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3092
#
# Iteration number:  3092
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3091
#
# Iteration number:  3091
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3090
#
# Iteration number:  3090
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3089
#
# Iteration number:  3089
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3088
#
# Iteration number:  3088
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3087
#
# Iteration number:  3087
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3086
#
# Iteration number:  3086
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3085
#
# Iteration number:  3085
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3084
#
# Iteration number:  3084
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3083
#
# Iteration number:  3083
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3082
#
# Iteration number:  3082
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3081
#
# Iteration number:  3081
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3080
#
# Iteration number:  3080
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3079
#
# Iteration number:  3079
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3078
#
# Iteration number:  3078
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3077
#
# Iteration number:  3077
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3076
#
# Iteration number:  3076
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3075
#
# Iteration number:  3075
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3074
#
# Iteration number:  3074
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3073
#
# Iteration number:  3073
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3072
#
# Iteration number:  3072
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3071
#
# Iteration number:  3071
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3070
#
# Iteration number:  3070
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3069
#
# Iteration number:  3069
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3068
#
# Iteration number:  3068
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3067
#
# Iteration number:  3067
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3066
#
# Iteration number:  3066
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3065
#
# Iteration number:  3065
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3064
#
# Iteration number:  3064
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3063
#
# Iteration number:  3063
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3062
#
# Iteration number:  3062
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3061
#
# Iteration number:  3061
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3060
#
# Iteration number:  3060
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3059
#
# Iteration number:  3059
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3058
#
# Iteration number:  3058
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3057
#
# Iteration number:  3057
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3056
#
# Iteration number:  3056
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3055
#
# Iteration number:  3055
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3054
#
# Iteration number:  3054
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3053
#
# Iteration number:  3053
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3052
#
# Iteration number:  3052
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3051
#
# Iteration number:  3051
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3050
#
# Iteration number:  3050
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3049
#
# Iteration number:  3049
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3048
#
# Iteration number:  3048
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3047
#
# Iteration number:  3047
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3046
#
# Iteration number:  3046
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3045
#
# Iteration number:  3045
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3044
#
# Iteration number:  3044
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3043
#
# Iteration number:  3043
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3042
#
# Iteration number:  3042
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3041
#
# Iteration number:  3041
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3040
#
# Iteration number:  3040
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3039
#
# Iteration number:  3039
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3038
#
# Iteration number:  3038
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3037
#
# Iteration number:  3037
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3036
#
# Iteration number:  3036
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3035
#
# Iteration number:  3035
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3034
#
# Iteration number:  3034
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3033
#
# Iteration number:  3033
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3032
#
# Iteration number:  3032
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3031
#
# Iteration number:  3031
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3030
#
# Iteration number:  3030
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3029
#
# Iteration number:  3029
# Random Date Generated
# Query Finish
# Saved Query to DF
# Concat repo successful
# Next Iteration number:  3028
#
# Iteration number:  3028
# Random Date Generated

# %%
df_repo
# Out:
#               createdAt                                        description  \
# 0  2016-08-21T05:31:51Z  An android process bar library associated with...
# 0  2015-10-20T18:22:34Z  A ScrollView component that handles keyboard a...
# 0  2015-11-24T12:43:44Z                 Sample app to demonstrate multidex
# 0  2015-10-05T09:34:22Z  multiNetX is a python package for the manipula...
# 0  2013-07-18T14:39:58Z      Painlessly create beautiful matplotlib plots.
# 0  2010-08-15T22:59:33Z  Github Repository Finder, now powered by GitHu...
# 0  2016-04-01T13:53:58Z  🍡 LeetCode Online Judge刷题题解(Java/C++/Python/Ru...
# 0  2012-03-20T16:17:18Z                                【鼠鬚管】Rime for macOS
# 0  2018-12-01T21:10:44Z                  Reversible Reproducible Documents
# 0  2019-02-07T03:27:12Z  Provable adversarial robustness at ImageNet scale
# 0  2012-06-04T22:23:04Z  Graceful restart & zero downtime deploy for Go...
# 0  2012-05-31T23:09:08Z  C# Generic Repository for use with Entity Fram...
# 0  2013-10-09T02:33:48Z                                LeetCode题解，151道题完整版
# 0  2010-12-01T16:44:54Z                      Protocol Buffer coder/decoder
# 0  2011-10-30T07:50:04Z                                           mini os
# 0  2015-11-08T18:47:28Z  :raised_hands: React compatibility layer for P...
# 0  2017-05-18T07:34:10Z         Raspberry Pi web simulator. Demo address:
# 0  2012-01-12T18:03:37Z  UITableViewController with customizable overla...
# 0  2019-08-13T16:08:13Z                 2019中国高校计算机大赛——大数据挑战赛 第15名 WriteUp
# 0  2009-07-22T11:30:59Z  Generic favorites app for django with some mor...
# 0  2016-05-14T10:51:15Z                                            Mac开发者
#
#    forkCount  hasIssuesEnabled  hasWikiEnabled  \
# 0         37              True            True
# 0        377              True            True
# 0         51              True            True
# 0         31              True            True
# 0        140              True            True
# 0          8              True            True
# 0        113              True            True
# 0        263              True            True
# 0         23              True            True
# 0         12              True            True
# 0        337              True           False
# 0        134              True            True
# 0       2869              True            True
# 0         22              True            True
# 0          8              True            True
# 0        137              True            True
# 0         80              True            True
# 0         54              True            True
# 0          6              True            True
# 0         24              True            True
# 0         46              True            True
#
#                                  id               issues  \
# 0  MDEwOlJlcG9zaXRvcnk2NjE4Mjg1MA==    {'totalCount': 0}
# 0  MDEwOlJlcG9zaXRvcnk0NDYyNjI1MA==  {'totalCount': 272}
# 0  MDEwOlJlcG9zaXRvcnk0Njc5MTAyMg==    {'totalCount': 1}
# 0  MDEwOlJlcG9zaXRvcnk0MzY3NTc1OQ==    {'totalCount': 6}
# 0  MDEwOlJlcG9zaXRvcnkxMTUwNTIxOA==   {'totalCount': 64}
# 0      MDEwOlJlcG9zaXRvcnk4Mzk5NTQ=   {'totalCount': 15}
# 0  MDEwOlJlcG9zaXRvcnk1NTIzNjA1Ng==    {'totalCount': 6}
# 0      MDEwOlJlcG9zaXRvcnkzNzc3MjEw  {'totalCount': 316}
# 0  MDEwOlJlcG9zaXRvcnkxNTk5ODc1NjA=   {'totalCount': 43}
# 0  MDEwOlJlcG9zaXRvcnkxNjk1MTM4MzA=    {'totalCount': 0}
# 0      MDEwOlJlcG9zaXRvcnk0NTUzMjQ2   {'totalCount': 30}
# 0      MDEwOlJlcG9zaXRvcnk0NTE0MDQ3  {'totalCount': 198}
# 0  MDEwOlJlcG9zaXRvcnkxMzQzMTIzNQ==   {'totalCount': 53}
# 0      MDEwOlJlcG9zaXRvcnkxMTI5MjIx    {'totalCount': 4}
# 0      MDEwOlJlcG9zaXRvcnkyNjc0MjQ5    {'totalCount': 0}
# 0  MDEwOlJlcG9zaXRvcnk0NTc5Mzc2MA==  {'totalCount': 227}
# 0  MDEwOlJlcG9zaXRvcnk5MTY2MzA0NA==    {'totalCount': 9}
# 0      MDEwOlJlcG9zaXRvcnkzMTY0MzQ3    {'totalCount': 2}
# 0  MDEwOlJlcG9zaXRvcnkyMDIxODAxOTU=    {'totalCount': 0}
# 0      MDEwOlJlcG9zaXRvcnkyNTc1NTk=    {'totalCount': 0}
# 0  MDEwOlJlcG9zaXRvcnk1ODgwMzExMg==    {'totalCount': 9}
#
#                   licenseInfo                                     name  \
# 0                        None                       android_ProcessBar
# 0           {'spdxId': 'MIT'}  react-native-keyboard-aware-scroll-view
# 0                        None                          multidex-sample
# 0                        None                                multinetx
# 0           {'spdxId': 'MIT'}                            prettyplotlib
# 0                        None                             GithubFinder
# 0                        None                                 LeetCode
# 0       {'spdxId': 'GPL-3.0'}                                 squirrel
# 0   {'spdxId': 'NOASSERTION'}                                    redoc
# 0                        None                                smoothing
# 0           {'spdxId': 'MIT'}                                    grace
# 0   {'spdxId': 'NOASSERTION'}                          SharpRepository
# 0  {'spdxId': 'BSD-3-Clause'}                                 leetcode
# 0    {'spdxId': 'Apache-2.0'}                           protobuf-codec
# 0                        None                                    ratos
# 0           {'spdxId': 'MIT'}                            preact-compat
# 0                        None               raspberry-pi-web-simulator
# 0                        None                KNPathTableViewController
# 0                        None                              MatchModels
# 0      {'spdxId': 'LGPL-3.0'}                         django-favorites
# 0                        None                             MacDeveloper
#
#                                   nameWithOwner  \
# 0                    hzw1199/android_ProcessBar
# 0  APSL/react-native-keyboard-aware-scroll-view
# 0                        mmadev/multidex-sample
# 0                               nkoub/multinetx
# 0                         olgabot/prettyplotlib
# 0                             sr3d/GithubFinder
# 0                              liuchuo/LeetCode
# 0                                 rime/squirrel
# 0                                noamross/redoc
# 0                            locuslab/smoothing
# 0                         facebookarchive/grace
# 0               SharpRepository/SharpRepository
# 0                          soulmachine/leetcode
# 0                          sijuv/protobuf-codec
# 0                              rajneshrat/ratos
# 0                       developit/preact-compat
# 0      Azure-Samples/raspberry-pi-web-simulator
# 0          kentnguyen/KNPathTableViewController
# 0                        P01son6415/MatchModels
# 0                          apg/django-favorites
# 0                         GcsSloop/MacDeveloper
#
#                                               object  \
# 0  {'text': '# Process Bar
# [![](https://jitpack.i...
# 0  {'text': '# react-native-keyboard-aware-scroll...
# 0  {'text': '# multidex-sample
# Sample app to demo...
# 0  {'text': '![png](logo.png) multiNetX v2.0
# ===...
# 0  {'text': '# Announcement
#
# Thank you to everyon...
# 0  {'text': '# Github Finder
# GithubFinder is a fa...
# 0  {'text': '- 博客地址：https://www.liuchuo.net/
#
# |  ...
# 0  {'text': '    鼠鬚管
#     爲物雖微情不淺
#     新詩醉墨時一揮
#     ...
# 0  {'text': '
# <!-- README.md is generated from RE...
# 0  {'text': '# Certified Adversarial Robustness v...
# 0                                               None
# 0  {'text': '![sharp repository logo](https://use...
# 0  {'text': '#LeetCode题解
# -----------------
# ## 在线阅...
# 0  {'text': '# Protobuf Codec
# Protobuf-codec pro...
# 0                                               None
# 0  {'text': '# preact-compat
#
# [![NPM](https://img...
# 0                                               None
# 0  {'text': '## KNPathTableViewController
#
# KNPath...
# 0                                               None
# 0                                               None
# 0  {'text': '![](http://ww2.sinaimg.cn/large/005X...
#
#                           owner               primaryLanguage  \
# 0          {'login': 'hzw1199'}              {'name': 'Java'}
# 0             {'login': 'APSL'}        {'name': 'JavaScript'}
# 0           {'login': 'mmadev'}              {'name': 'Java'}
# 0            {'login': 'nkoub'}  {'name': 'Jupyter Notebook'}
# 0          {'login': 'olgabot'}            {'name': 'Python'}
# 0             {'login': 'sr3d'}        {'name': 'JavaScript'}
# 0          {'login': 'liuchuo'}               {'name': 'C++'}
# 0             {'login': 'rime'}       {'name': 'Objective-C'}
# 0         {'login': 'noamross'}                 {'name': 'R'}
# 0         {'login': 'locuslab'}            {'name': 'Python'}
# 0  {'login': 'facebookarchive'}                {'name': 'Go'}
# 0  {'login': 'SharpRepository'}                {'name': 'C#'}
# 0      {'login': 'soulmachine'}               {'name': 'TeX'}
# 0            {'login': 'sijuv'}              {'name': 'Java'}
# 0       {'login': 'rajneshrat'}                 {'name': 'C'}
# 0        {'login': 'developit'}        {'name': 'JavaScript'}
# 0    {'login': 'Azure-Samples'}        {'name': 'JavaScript'}
# 0       {'login': 'kentnguyen'}       {'name': 'Objective-C'}
# 0       {'login': 'P01son6415'}  {'name': 'Jupyter Notebook'}
# 0              {'login': 'apg'}            {'name': 'Python'}
# 0         {'login': 'GcsSloop'}            {'name': 'Python'}
#
#           pullRequests                     second_object  \
# 0    {'totalCount': 0}   {'history': {'totalCount': 10}}
# 0  {'totalCount': 110}  {'history': {'totalCount': 166}}
# 0    {'totalCount': 0}    {'history': {'totalCount': 2}}
# 0    {'totalCount': 3}   {'history': {'totalCount': 70}}
# 0   {'totalCount': 37}  {'history': {'totalCount': 252}}
# 0    {'totalCount': 2}  {'history': {'totalCount': 128}}
# 0    {'totalCount': 2}  {'history': {'totalCount': 354}}
# 0   {'totalCount': 42}  {'history': {'totalCount': 389}}
# 0   {'totalCount': 11}  {'history': {'totalCount': 103}}
# 0    {'totalCount': 4}    {'history': {'totalCount': 5}}
# 0   {'totalCount': 16}   {'history': {'totalCount': 93}}
# 0   {'totalCount': 43}  {'history': {'totalCount': 556}}
# 0   {'totalCount': 46}  {'history': {'totalCount': 175}}
# 0    {'totalCount': 2}   {'history': {'totalCount': 40}}
# 0    {'totalCount': 0}   {'history': {'totalCount': 57}}
# 0  {'totalCount': 307}  {'history': {'totalCount': 334}}
# 0   {'totalCount': 30}   {'history': {'totalCount': 71}}
# 0    {'totalCount': 1}   {'history': {'totalCount': 36}}
# 0    {'totalCount': 0}    {'history': {'totalCount': 5}}
# 0    {'totalCount': 1}    {'history': {'totalCount': 6}}
# 0    {'totalCount': 1}  {'history': {'totalCount': 221}}
#
#              stargazers             updatedAt
# 0   {'totalCount': 199}  2019-08-28T06:14:45Z
# 0  {'totalCount': 3118}  2019-09-09T21:17:49Z
# 0   {'totalCount': 118}  2019-03-22T01:44:33Z
# 0   {'totalCount': 104}  2019-08-22T15:04:41Z
# 0  {'totalCount': 1482}  2019-09-09T13:16:14Z
# 0   {'totalCount': 126}  2019-07-14T10:02:17Z
# 0   {'totalCount': 327}  2019-09-09T03:50:24Z
# 0  {'totalCount': 2269}  2019-09-09T18:56:21Z
# 0   {'totalCount': 391}  2019-09-09T09:52:39Z
# 0    {'totalCount': 83}  2019-09-08T08:08:57Z
# 0  {'totalCount': 4387}  2019-09-09T18:08:06Z
# 0   {'totalCount': 451}  2019-09-08T07:32:01Z
# 0  {'totalCount': 7862}  2019-09-09T15:24:19Z
# 0    {'totalCount': 40}  2018-12-07T06:20:03Z
# 0    {'totalCount': 21}  2018-09-13T10:48:09Z
# 0   {'totalCount': 831}  2019-09-03T14:20:33Z
# 0   {'totalCount': 268}  2019-09-08T15:59:09Z
# 0   {'totalCount': 586}  2019-08-13T14:55:22Z
# 0    {'totalCount': 31}  2019-09-03T11:56:57Z
# 0    {'totalCount': 31}  2019-03-19T15:32:16Z
# 0   {'totalCount': 212}  2019-08-18T10:03:19Z

# %% [markdown]
# ### Clean data

# %%
df_repo['issues'] = df_repo['issues'].apply(lambda x: x['totalCount'])

# %%
df_repo['licenseInfo'] = df_repo['licenseInfo'].apply(lambda x: x['spdxId'] if x != None else None)

# %%
df_repo['object'] = df_repo['object'].apply(lambda x: x['text'])

# %%
df_repo['owner'] = df_repo['owner'].apply(lambda x: x['login'])

# %%
df_repo['primaryLanguage'] = df_repo['primaryLanguage'].apply(lambda x: x['name'])

# %%
df_repo['pullRequests'] = df_repo['pullRequests'].apply(lambda x: x['totalCount'])

# %%
df_repo['second_object'] = df_repo['second_object'].apply(lambda x: x['history']['totalCount'])

# %%
df_repo['stargazers'] = df_repo['stargazers'].apply(lambda x: x['totalCount'])

# %%
df_repo = df_repo.reset_index().drop(columns='index')

# %% [markdown]
# ### Rename columns

# %%
df_repo = df_repo.rename(columns={'object':'readMe','issues':'totalIssues','pullRequests':'totalPullRequests',
                'second_object':'totalCommits', 'stargazers':'totalStargazers', 'forkCount':'totalForks'})

# %%
df_repo['createdAt'] = df_repo['createdAt'].apply(lambda x: pd.to_datetime(x))
df_repo['updatedAt'] = df_repo['updatedAt'].apply(lambda x: pd.to_datetime(x))

# %%
df_repo.head()
# Out:
#                   createdAt  \
# 0 2013-01-19 02:21:47+00:00
# 1 2014-04-01 22:40:40+00:00
# 2 2014-07-17 04:50:32+00:00
# 3 2017-03-21 11:05:58+00:00
# 4 2012-09-14 14:19:46+00:00
#
#                                          description  totalForks  \
# 0    A game-theoretic poker player (written in 2005)          30
# 1                    The Google I/O 2019 Android App        5931
# 2  SEX IS ZERO (0), so, who wanna be the ONE (1),...        1959
# 3                  在线地址: http://www.jobinfo.cc:8000/          91
# 4    Using Spring from within a Play 2.0 application          24
#
#    hasIssuesEnabled  hasWikiEnabled                                id  \
# 0              True            True      MDEwOlJlcG9zaXRvcnk3Njk4MTkx
# 1              True           False  MDEwOlJlcG9zaXRvcnkxODM0NzQ3Ng==
# 2              True            True  MDEwOlJlcG9zaXRvcnkyMTkyOTAyOQ==
# 3              True            True  MDEwOlJlcG9zaXRvcnk4NTY5MjA1Mg==
# 4             False           False      MDEwOlJlcG9zaXRvcnk1ODEwMjM4
#
#    totalIssues  licenseInfo                name  \
# 0            0         None   game-theory-poker
# 1          192  NOASSERTION             iosched
# 2           76      GPL-2.0            hardseed
# 3            8          MIT           webspider
# 4            0         None  play20-spring-demo
#
#                       nameWithOwner  \
# 0       adamsmith/game-theory-poker
# 1                    google/iosched
# 2          yangyangwithgnu/hardseed
# 3                 iven-he/webspider
# 4  guillaumebort/play20-spring-demo
#
#                                               readMe            owner  \
# 0  game-theory-poker\n=====\n\nThis is a game-the...        adamsmith
# 1  Google I/O Android App\n======================...           google
# 2  <h1 align="center">给不了你梦中情人，至少还有硬盘女神：hardseed<...  yangyangwithgnu
# 3  # \n\n[![Build Status](https://travis-ci.org/G...          iven-he
# 4  Using Spring from within a Play 2.0 applicatio...    guillaumebort
#
#   primaryLanguage  totalPullRequests  totalCommits  totalStargazers  \
# 0            Java                  1             2              167
# 1          Kotlin                134          2635            18987
# 2             C++                 12           197             9102
# 3          Python                  8            51              260
# 4            Java                  3             3               88
#
#                   updatedAt
# 0 2019-08-13 15:14:46+00:00
# 1 2019-09-03 15:52:27+00:00
# 2 2019-09-02 12:40:54+00:00
# 3 2019-08-29 15:43:08+00:00
# 4 2019-05-31 11:35:43+00:00

# %%
df_repo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 17 columns):
# createdAt           9 non-null datetime64[ns, UTC]
# description         9 non-null object
# forkCount           9 non-null int64
# hasIssuesEnabled    9 non-null bool
# hasWikiEnabled      9 non-null bool
# id                  9 non-null object
# issues              9 non-null int64
# licenseInfo         7 non-null object
# name                9 non-null object
# nameWithOwner       9 non-null object
# object              9 non-null object
# owner               9 non-null object
# primaryLanguage     9 non-null object
# pullRequests        9 non-null int64
# second_object       9 non-null int64
# stargazers          9 non-null int64
# updatedAt           9 non-null datetime64[ns, UTC]
# dtypes: bool(2), datetime64[ns, UTC](2), int64(5), object(8)
# memory usage: 1.2+ KB

# %%
df_repo.head()
# Out:
#                   createdAt  \
# 0 2013-01-19 02:21:47+00:00
# 1 2014-04-01 22:40:40+00:00
# 2 2014-07-17 04:50:32+00:00
# 3 2017-03-21 11:05:58+00:00
# 4 2012-09-14 14:19:46+00:00
#
#                                          description  forkCount  \
# 0    A game-theoretic poker player (written in 2005)         30
# 1                    The Google I/O 2019 Android App       5931
# 2  SEX IS ZERO (0), so, who wanna be the ONE (1),...       1959
# 3                  在线地址: http://www.jobinfo.cc:8000/         91
# 4    Using Spring from within a Play 2.0 application         24
#
#    hasIssuesEnabled  hasWikiEnabled                                id  issues  \
# 0              True            True      MDEwOlJlcG9zaXRvcnk3Njk4MTkx       0
# 1              True           False  MDEwOlJlcG9zaXRvcnkxODM0NzQ3Ng==     192
# 2              True            True  MDEwOlJlcG9zaXRvcnkyMTkyOTAyOQ==      76
# 3              True            True  MDEwOlJlcG9zaXRvcnk4NTY5MjA1Mg==       8
# 4             False           False      MDEwOlJlcG9zaXRvcnk1ODEwMjM4       0
#
#    licenseInfo                name                     nameWithOwner  \
# 0         None   game-theory-poker       adamsmith/game-theory-poker
# 1  NOASSERTION             iosched                    google/iosched
# 2      GPL-2.0            hardseed          yangyangwithgnu/hardseed
# 3          MIT           webspider                 iven-he/webspider
# 4         None  play20-spring-demo  guillaumebort/play20-spring-demo
#
#                                               object            owner  \
# 0  game-theory-poker\n=====\n\nThis is a game-the...        adamsmith
# 1  Google I/O Android App\n======================...           google
# 2  <h1 align="center">给不了你梦中情人，至少还有硬盘女神：hardseed<...  yangyangwithgnu
# 3  # \n\n[![Build Status](https://travis-ci.org/G...          iven-he
# 4  Using Spring from within a Play 2.0 applicatio...    guillaumebort
#
#   primaryLanguage  pullRequests  second_object  stargazers  \
# 0            Java             1              2         167
# 1          Kotlin           134           2635       18987
# 2             C++            12            197        9102
# 3          Python             8             51         260
# 4            Java             3              3          88
#
#                   updatedAt
# 0 2019-08-13 15:14:46+00:00
# 1 2019-09-03 15:52:27+00:00
# 2 2019-09-02 12:40:54+00:00
# 3 2019-08-29 15:43:08+00:00
# 4 2019-05-31 11:35:43+00:00

# %%
df_repo.to_pickle('../../../Files/df_repo_10.pk1')

# %% [markdown]
# ---
# # Querying only 1000 repos - Must use created:{date} and retrieve it by chunks(days or weeks)
# ---

# %% [markdown]
# ## Original query

# %%
query = '''
{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first:15) {
    repositoryCount
    pageInfo {
      endCursor
      hasNextPage
    }
    nodes {
      ... on Repository {
        id
        createdAt
        updatedAt
        owner {
          login
        }
        name
        nameWithOwner
        primaryLanguage {
          name
        }
        description
        hasIssuesEnabled
        hasWikiEnabled
        licenseInfo {
          spdxId
        }
        object(expression:"master:README.md") {
          ... on Blob {
            text
          }
        }
        second_object: object(expression: "master") {
          ... on Commit {
            history {
              totalCount
            }
          }
        }
        forkCount
        stargazers {
          totalCount
        }
        issues {
          totalCount
        }
        pullRequests {
          totalCount
        }
      }
    }
  }
    rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
'''
query_2 = '''
{{
  search(query: "is:public stars:>=5 forks:>=5, type: REPOSITORY, first:1, after:"{end_cursor}") {{
    repositoryCount
    pageInfo {{
      endCursor
      hasNextPage
    }}
    nodes {{
      ... on Repository {{
        id
        createdAt
        updatedAt
        owner {{
          login
        }}
        name
        nameWithOwner
        primaryLanguage {{
          name
        }}
        description
        hasIssuesEnabled
        hasWikiEnabled
        licenseInfo {{
          spdxId
        }}
        object(expression:"master:README.md") {{
          ... on Blob {{
            text
          }}
        }}
        second_object: object(expression: "master") {{
          ... on Commit {{
            history {{
              totalCount
            }}
          }}
        }}
        forkCount
        stargazers {{
          totalCount
        }}
        issues {{
          totalCount
        }}
        pullRequests {{
          totalCount
        }}
      }}
    }}
  }}
    rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

variables = {
    "end_cursor": ""
}

# %% [markdown]
# ## Seperate Query

# %% [markdown]
# ### Query 1/3: Repo info

# %%
query = '''
{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first:100) {
    repositoryCount
    pageInfo {
      endCursor
      hasNextPage
    }
    nodes {
      ... on Repository {
        id
        createdAt
        updatedAt
        owner {
          login
        }
        name
        nameWithOwner
        primaryLanguage {
          name
        }
        description
        hasIssuesEnabled
        hasWikiEnabled
        licenseInfo {
          spdxId
        }
        forkCount
        stargazers {
          totalCount
        }
        issues {
          totalCount
        }
        pullRequests {
          totalCount
        }
      }
    }
  }
    rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
'''

query_2 = '''
{{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first:100, after:"{end_cursor}") {{
    repositoryCount
    pageInfo {{
      endCursor
      hasNextPage
    }}
    nodes {{
      ... on Repository {{
        id
        createdAt
        updatedAt
        owner {{
          login
        }}
        name
        nameWithOwner
        primaryLanguage {{
          name
        }}
        description
        hasIssuesEnabled
        hasWikiEnabled
        licenseInfo {{
          spdxId
        }}
        forkCount
        stargazers {{
          totalCount
        }}
        issues {{
          totalCount
        }}
        pullRequests {{
          totalCount
        }}
      }}
    }}
  }}
    rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

variables = {
    "end_cursor": ""
}

# %% [markdown]
# ### Query 2/3: Readme

# %%
query = '''
{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first: 100) {
    pageInfo {
      endCursor
      hasNextPage
    }
    nodes {
      ... on Repository {
        id
        object(expression: "master:README.md") {
          ... on Blob {
            text
          }
        }
      }
    }
  }
  rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
'''

query_2 = '''
{{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first: 100, after:"{end_cursor}") {{
    pageInfo {{
      endCursor
      hasNextPage
    }}
    nodes {{
      ... on Repository {{
        id
        object(expression: "master:README.md") {{
          ... on Blob {{
            text
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

variables = {
    "end_cursor": ""
}

# %% [markdown]
# ### Query 3/3: Commit Count

# %%
query = '''
{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first: 15) {
    pageInfo {
      endCursor
      hasNextPage
    }
    nodes {
      ... on Repository {
        id
        object(expression: "master") {
          ... on Commit {
            history {
              totalCount
            }
          }
        }
      }
    }
  }
  rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
'''

query_2 = '''
{{
  search(query: "is:public stars:>=5 forks:>=5", type: REPOSITORY, first: 10, after:"{end_cursor}") {{
    pageInfo {{
      endCursor
      hasNextPage
    }}
    nodes {{
      ... on Repository {{
        id
        object: object(expression: "master") {{
          ... on Commit {{
            history {{
              totalCount
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

variables = {
    "end_cursor": ""
}

# %%
def to_df(result):
    
    # Get the keys of nodes.
    data = result['data']['search']['nodes']
    
    # Put the data into a dataframe
    df_repo = pd.DataFrame(data)
    
    return df_repo

def get_page_info(result):
    cur = result['data']['search']['pageInfo']['endCursor']
    has_cur = result['data']['search']['pageInfo']['hasNextPage']
    return cur, has_cur

def result_query(query):
    # Run first query
    result = run_query(query)

    # Save to DF
    df_repo = to_df(result)

    # Get end cursor and has cursor
    variables['end_cursor'], has_cursor = get_page_info(result)

    # Limit
    limit = result['data']['rateLimit']['remaining']
    
    return df_repo, has_cursor, limit

# %%
# %%time
##### Comment Out this section if there's a 403 error #####

# Run first query
df_repo, has_cursor, limit = result_query(query)

print('Starting limit is: ', limit)
print('Start cursor: ', has_cursor, '\n')

##### Comment Out this section if there's a 403 error #####

# Run While Loop below
while has_cursor and (limit >= 0):
    
    # Run next queries
    df_repo_2, has_cursor, limit = result_query(query_2.format(**variables))

    # Concat to existing df_star
    df_repo = pd.concat([df_repo, df_repo_2])
    
    # Print limit and cursor
    print('Next limit is: ', limit)
    print('Next cursor: ', has_cursor, '\n')
# Out:
# Starting limit is:  4847
# Start cursor:  True
#
# Next limit is:  4846
# Next cursor:  True
#
# Next limit is:  4845
# Next cursor:  True
#
# Next limit is:  4844
# Next cursor:  True
#
# Next limit is:  4843
# Next cursor:  True
#
# Next limit is:  4842
# Next cursor:  True
#
# Next limit is:  4841
# Next cursor:  True
#
# Next limit is:  4840
# Next cursor:  True
#
# Next limit is:  4839
# Next cursor:  True
#
# Next limit is:  4838
# Next cursor:  True
#
# Next limit is:  4837
# Next cursor:  True
#
# Next limit is:  4836
# Next cursor:  True
#
# Next limit is:  4835
# Next cursor:  True
#
# Next limit is:  4834
# Next cursor:  True
#
# Next limit is:  4833
# Next cursor:  True
#
# Next limit is:  4832
# Next cursor:  True
#
# Next limit is:  4831
# Next cursor:  True
#
# Next limit is:  4830
# Next cursor:  True
#
# Next limit is:  4829
# Next cursor:  True
#
# Next limit is:  4828
# Next cursor:  True
#
# Next limit is:  4827
# Next cursor:  True
#
# Next limit is:  4826
# Next cursor:  True
#
# Next limit is:  4825
# Next cursor:  True
#
# Next limit is:  4824
# Next cursor:  True
#
# Next limit is:  4823
# Next cursor:  True
#
# Next limit is:  4822
# Next cursor:  True
#
# Next limit is:  4821
# Next cursor:  True
#
# Next limit is:  4820
# Next cursor:  True
#
# Next limit is:  4819
# Next cursor:  True
#
# Next limit is:  4818
# Next cursor:  True
#
# Next limit is:  4817
# Next cursor:  True
#
# Next limit is:  4816
# Next cursor:  True
#
# Next limit is:  4815
# Next cursor:  True
#
# Next limit is:  4814
# Next cursor:  True
#
# Next limit is:  4813
# Next cursor:  True
#
# Next limit is:  4812
# Next cursor:  True
#
# Next limit is:  4811
# Next cursor:  True
#
# Next limit is:  4810
# Next cursor:  True
#
# Next limit is:  4809
# Next cursor:  True
#
# Next limit is:  4808
# Next cursor:  True
#
# Next limit is:  4807
# Next cursor:  True
#
# Next limit is:  4806
# Next cursor:  True
#
# Next limit is:  4805
# Next cursor:  True
#
# Next limit is:  4804
# Next cursor:  True
#
# Next limit is:  4803
# Next cursor:  True
#
# Next limit is:  4802
# Next cursor:  True
#
# Next limit is:  4801
# Next cursor:  True
#
# Next limit is:  4800
# Next cursor:  True
#
# Next limit is:  4799
# Next cursor:  True
#
# Next limit is:  4798
# Next cursor:  True
#
# Next limit is:  4797
# Next cursor:  True
#
# Next limit is:  4796
# Next cursor:  True
#
# Next limit is:  4795
# Next cursor:  True
#
# Next limit is:  4794
# Next cursor:  True
#
# Next limit is:  4793
# Next cursor:  True
#
# Next limit is:  4792
# Next cursor:  True
#
# Next limit is:  4791
# Next cursor:  True
#
# Next limit is:  4790
# Next cursor:  True
#
# Next limit is:  4789
# Next cursor:  True
#
# Next limit is:  4788
# Next cursor:  True
#
# Next limit is:  4787
# Next cursor:  True
#
# Next limit is:  4786
# Next cursor:  True
#
# Next limit is:  4785
# Next cursor:  True
#
# Next limit is:  4784
# Next cursor:  True
#
# Next limit is:  4783
# Next cursor:  True
#
# Next limit is:  4782
# Next cursor:  True
#
# Next limit is:  4781
# Next cursor:  True
#
# Next limit is:  4780
# Next cursor:  True
#
# Next limit is:  4779
# Next cursor:  True
#
# Next limit is:  4778
# Next cursor:  True
#
# Next limit is:  4777
# Next cursor:  True
#
# Next limit is:  4776
# Next cursor:  True
#
# Next limit is:  4775
# Next cursor:  True
#
# Next limit is:  4774
# Next cursor:  True
#
# Next limit is:  4773
# Next cursor:  True
#
# Next limit is:  4772
# Next cursor:  True
#
# Next limit is:  4771
# Next cursor:  True
#
# Next limit is:  4770
# Next cursor:  True
#
# Next limit is:  4769
# Next cursor:  True
#
# Next limit is:  4768
# Next cursor:  True
#
# Next limit is:  4767
# Next cursor:  True
#
# Next limit is:  4766
# Next cursor:  True
#
# Next limit is:  4765
# Next cursor:  True
#
# Next limit is:  4764
# Next cursor:  True
#
# Next limit is:  4763
# Next cursor:  True
#
# Next limit is:  4762
# Next cursor:  True
#
# Next limit is:  4761
# Next cursor:  True
#
# Next limit is:  4760
# Next cursor:  True
#
# Next limit is:  4759
# Next cursor:  True
#
# Next limit is:  4758
# Next cursor:  True
#
# Next limit is:  4757
# Next cursor:  True
#
# Next limit is:  4756
# Next cursor:  True
#
# Next limit is:  4755
# Next cursor:  True
#
# Next limit is:  4754
# Next cursor:  True
#
# Next limit is:  4753
# Next cursor:  True
#
# Next limit is:  4752
# Next cursor:  True
#
# Next limit is:  4751
# Next cursor:  True
#
# Next limit is:  4750
# Next cursor:  True
#
# Next limit is:  4749
# Next cursor:  False
#
# Wall time: 2min 43s

# %%
print(df_repo.shape)
df_repo.head()
# Out:
# (995, 2)
#                                  id                              object
# 0  MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==  {'history': {'totalCount': 24700}}
# 1  MDEwOlJlcG9zaXRvcnkxNzc3MzY1MzM=   {'history': {'totalCount': 2960}}
# 2  MDEwOlJlcG9zaXRvcnkxMTczMDM0Mg==   {'history': {'totalCount': 2283}}
# 3      MDEwOlJlcG9zaXRvcnkyMTI2MjQ0  {'history': {'totalCount': 18978}}
# 4  MDEwOlJlcG9zaXRvcnkxMDI3MDI1MA==  {'history': {'totalCount': 12327}}

# %% [markdown]
# ### Pickle df

# %%
df_repo.to_pickle('../../../Files/df_repo_pandas_3.pk1')

# %%
df1 =pd.read_pickle('../../../Files/df_repo_pandas_1.pk1')
df2 =pd.read_pickle('../../../Files/df_repo_pandas_2.pk1')
df3 =pd.read_pickle('../../../Files/df_repo_pandas_3.pk1')

# %% [markdown]
# ### Merge all 3 and pickle

# %%
print(df1.shape)
df1.head()
# Out:
# (1000, 15)
#               createdAt                                        description  \
# 0  2014-12-24T17:49:19Z  The https://www.freeCodeCamp.org open source c...
# 1  2019-03-26T07:31:14Z  Repo for counting stars and contributing. Pres...
# 2  2013-07-29T03:24:51Z  🖖 Vue.js is a progressive, incrementally-adopt...
# 3  2011-07-29T21:19:00Z  The most popular HTML, CSS, and JavaScript fra...
# 4  2013-05-24T16:15:54Z  A declarative, efficient, and flexible JavaScr...
#
#    forkCount  hasIssuesEnabled  hasWikiEnabled  \
# 0      22478              True           False
# 1      21315             False           False
# 2      21536              True            True
# 3      66660              True           False
# 4      25294              True            True
#
#                                  id                 issues  \
# 0  MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==  {'totalCount': 13752}
# 1  MDEwOlJlcG9zaXRvcnkxNzc3MzY1MzM=      {'totalCount': 0}
# 2  MDEwOlJlcG9zaXRvcnkxMTczMDM0Mg==   {'totalCount': 8344}
# 3      MDEwOlJlcG9zaXRvcnkyMTI2MjQ0  {'totalCount': 18731}
# 4  MDEwOlJlcG9zaXRvcnkxMDI3MDI1MA==   {'totalCount': 7959}
#
#                   licenseInfo          name              nameWithOwner  \
# 0  {'spdxId': 'BSD-3-Clause'}  freeCodeCamp  freeCodeCamp/freeCodeCamp
# 1   {'spdxId': 'NOASSERTION'}       996.ICU             996icu/996.ICU
# 2           {'spdxId': 'MIT'}           vue                  vuejs/vue
# 3           {'spdxId': 'MIT'}     bootstrap             twbs/bootstrap
# 4           {'spdxId': 'MIT'}         react             facebook/react
#
#                        owner         primaryLanguage           pullRequests  \
# 0  {'login': 'freeCodeCamp'}  {'name': 'JavaScript'}  {'totalCount': 22525}
# 1        {'login': '996icu'}        {'name': 'Rust'}   {'totalCount': 1802}
# 2         {'login': 'vuejs'}  {'name': 'JavaScript'}   {'totalCount': 1596}
# 3          {'login': 'twbs'}  {'name': 'JavaScript'}  {'totalCount': 10057}
# 4      {'login': 'facebook'}  {'name': 'JavaScript'}   {'totalCount': 8478}
#
#                stargazers             updatedAt
# 0  {'totalCount': 304556}  2019-08-28T23:48:45Z
# 1  {'totalCount': 247156}  2019-08-28T21:26:17Z
# 2  {'totalCount': 147000}  2019-08-28T23:04:19Z
# 3  {'totalCount': 135471}  2019-08-28T22:52:51Z
# 4  {'totalCount': 135172}  2019-08-28T21:21:48Z

# %%
print(df2.shape)
print(df2.isna().sum())
df2[:10]
# Out:
# (1000, 2)
# id          0
# object    114
# dtype: int64
#                                  id  \
# 0  MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==
# 1  MDEwOlJlcG9zaXRvcnkxNzc3MzY1MzM=
# 2  MDEwOlJlcG9zaXRvcnkxMTczMDM0Mg==
# 3  MDEwOlJlcG9zaXRvcnkxMDI3MDI1MA==
# 4  MDEwOlJlcG9zaXRvcnk0NTcxNzI1MA==
# 5  MDEwOlJlcG9zaXRvcnkyMTczNzQ2NQ==
# 6  MDEwOlJlcG9zaXRvcnkxNDQ0MDI3MA==
# 7      MDEwOlJlcG9zaXRvcnkyOTExMzc=
# 8      MDEwOlJlcG9zaXRvcnkxMDYyODk3
# 9      MDEwOlJlcG9zaXRvcnk2NDk4NDky
#
#                                               object
# 0  {'text': '![freeCodeCamp.org Social Banner](ht...
# 1  {'text': '[996.ICU](https://996.icu/#/en_US)
# =...
# 2  {'text': '<p align="center"><a href="https://v...
# 3  {'text': '# [React](https://reactjs.org/) &mid...
# 4  {'text': '<div align="center">
#   <img src="htt...
# 5                                               None
# 6  {'text': '# You Don't Know JS Yet (book series...
# 7  {'text': '<p align="center">
#   <img src="https...
# 8  {'text': '# A collection of `.gitignore` templ...
# 9  {'text': '# Airbnb JavaScript Style Guide() {
# ...

# %%
print(df3.shape)
print(df3.isna().sum())
df3[:10]
# Out:
# (995, 2)
# id         0
# object    18
# dtype: int64
#                                  id                              object
# 0  MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==  {'history': {'totalCount': 24700}}
# 1  MDEwOlJlcG9zaXRvcnkxNzc3MzY1MzM=   {'history': {'totalCount': 2960}}
# 2  MDEwOlJlcG9zaXRvcnkxMTczMDM0Mg==   {'history': {'totalCount': 2283}}
# 3      MDEwOlJlcG9zaXRvcnkyMTI2MjQ0  {'history': {'totalCount': 18978}}
# 4  MDEwOlJlcG9zaXRvcnkxMDI3MDI1MA==  {'history': {'totalCount': 12327}}
# 5  MDEwOlJlcG9zaXRvcnk0NTcxNzI1MA==  {'history': {'totalCount': 63831}}
# 6  MDEwOlJlcG9zaXRvcnkxMzQ5MTg5NQ==   {'history': {'totalCount': 5060}}
# 7  MDEwOlJlcG9zaXRvcnkyMTczNzQ2NQ==    {'history': {'totalCount': 849}}
# 8  MDEwOlJlcG9zaXRvcnkxNDQ0MDI3MA==   {'history': {'totalCount': 1491}}
# 9      MDEwOlJlcG9zaXRvcnkyOTExMzc=   {'history': {'totalCount': 5218}}

# %%
merge_2_3 = df2.merge(df3, on=['id'], how='outer').rename(columns={'object_x':'readMeText', 'object_y':'commit'})

# %%
all_merge = df1.merge(merge_2_3, on=['id'], how='outer')
# Out:
#                  createdAt                                        description  \
# 0     2014-12-24T17:49:19Z  The https://www.freeCodeCamp.org open source c...
# 1     2019-03-26T07:31:14Z  Repo for counting stars and contributing. Pres...
# 2     2013-07-29T03:24:51Z  🖖 Vue.js is a progressive, incrementally-adopt...
# 3     2011-07-29T21:19:00Z  The most popular HTML, CSS, and JavaScript fra...
# 4     2013-05-24T16:15:54Z  A declarative, efficient, and flexible JavaScr...
# 5     2015-11-07T01:19:20Z  An Open Source Machine Learning Framework for ...
# 6     2013-10-11T06:50:37Z         :books: Freely available programming books
# 7     2014-07-11T13:42:37Z  😎 Awesome lists about all kinds of interesting...
# 8     2013-11-16T02:37:24Z    A book series on JavaScript. @YDKJS on twitter.
# 9     2009-08-28T18:15:37Z  🙃 A delightful community-driven (with 1,300+ c...
# 10    2010-11-08T20:17:14Z        A collection of useful .gitignore templates
# 11    2012-11-01T23:13:50Z                             JavaScript Style Guide
# 12    2016-06-06T02:34:12Z  A complete computer science study plan to beco...
# 13    2017-03-15T13:45:52Z        Roadmap to becoming a web developer in 2019
# 14    2010-09-27T17:22:42Z  Bring data to life with SVG, Canvas and HTML. ...
# 15    2015-09-03T20:23:38Z                                 Visual Studio Code
# 16    2015-01-09T18:10:16Z   A framework for building native apps with React.
# 17    2011-09-04T22:48:12Z                           Linux kernel source tree
# 18    2013-04-12T01:47:36Z  :electron: Build cross-platform desktop apps w...
# 19    2018-02-13T14:56:24Z  :books: Tech Interview Guide 技术面试必备基础知识、Leetco...
# 20    2015-03-06T22:54:58Z  Flutter makes it easy and fast to build beauti...
# 21    2014-06-27T21:00:06Z  A curated list of awesome Python frameworks, l...
# 22    2017-02-26T16:15:28Z  Learn how to design large-scale systems. Prep ...
# 23    2016-07-17T14:55:11Z    Set up a modern web app by running one command.
# 24    2015-05-20T15:11:03Z               Master the command line, in one page
# 25    2014-11-26T19:57:11Z  Node.js JavaScript runtime :sparkles::turtle::...
# 26    2014-08-18T22:30:27Z  Promise based HTTP client for the browser and ...
# 27    2014-08-19T04:33:40Z                        The Go programming language
# 28    2011-10-12T10:07:38Z  🍿 A cross-browser library of CSS animations. A...
# 29    2012-02-17T14:19:43Z              The iconic SVG, font, and CSS toolkit
# ...                    ...                                                ...
# 1057                   NaN                                                NaN
# 1058                   NaN                                                NaN
# 1059                   NaN                                                NaN
# 1060                   NaN                                                NaN
# 1061                   NaN                                                NaN
# 1062                   NaN                                                NaN
# 1063                   NaN                                                NaN
# 1064                   NaN                                                NaN
# 1065                   NaN                                                NaN
# 1066                   NaN                                                NaN
# 1067                   NaN                                                NaN
# 1068                   NaN                                                NaN
# 1069                   NaN                                                NaN
# 1070                   NaN                                                NaN
# 1071                   NaN                                                NaN
# 1072                   NaN                                                NaN
# 1073                   NaN                                                NaN
# 1074                   NaN                                                NaN
# 1075                   NaN                                                NaN
# 1076                   NaN                                                NaN
# 1077                   NaN                                                NaN
# 1078                   NaN                                                NaN
# 1079                   NaN                                                NaN
# 1080                   NaN                                                NaN
# 1081                   NaN                                                NaN
# 1082                   NaN                                                NaN
# 1083                   NaN                                                NaN
# 1084                   NaN                                                NaN
# 1085                   NaN                                                NaN
# 1086                   NaN                                                NaN
#
#       forkCount hasIssuesEnabled hasWikiEnabled  \
# 0       22478.0             True          False
# 1       21315.0            False          False
# 2       21536.0             True           True
# 3       66660.0             True          False
# 4       25294.0             True           True
# 5       76997.0             True          False
# 6       31766.0             True           True
# 7       15214.0             True          False
# 8       21400.0             True           True
# 9       17368.0             True           True
# 10      44231.0            False          False
# 11      17004.0             True           True
# 12      25804.0             True          False
# 13      13830.0             True           True
# 14      21220.0             True           True
# 15      11692.0             True           True
# 16      17969.0             True           True
# 17      27749.0            False          False
# 18      10053.0             True          False
# 19      23973.0             True           True
# 20       8944.0             True           True
# 21      14146.0             True          False
# 22      11386.0             True           True
# 23      16390.0             True          False
# 24       7173.0             True          False
# 25      14664.0             True          False
# 26       5342.0             True          False
# 27       8729.0             True           True
# 28      13061.0             True          False
# 29      10256.0             True           True
# ...         ...              ...            ...
# 1057        NaN              NaN            NaN
# 1058        NaN              NaN            NaN
# 1059        NaN              NaN            NaN
# 1060        NaN              NaN            NaN
# 1061        NaN              NaN            NaN
# 1062        NaN              NaN            NaN
# 1063        NaN              NaN            NaN
# 1064        NaN              NaN            NaN
# 1065        NaN              NaN            NaN
# 1066        NaN              NaN            NaN
# 1067        NaN              NaN            NaN
# 1068        NaN              NaN            NaN
# 1069        NaN              NaN            NaN
# 1070        NaN              NaN            NaN
# 1071        NaN              NaN            NaN
# 1072        NaN              NaN            NaN
# 1073        NaN              NaN            NaN
# 1074        NaN              NaN            NaN
# 1075        NaN              NaN            NaN
# 1076        NaN              NaN            NaN
# 1077        NaN              NaN            NaN
# 1078        NaN              NaN            NaN
# 1079        NaN              NaN            NaN
# 1080        NaN              NaN            NaN
# 1081        NaN              NaN            NaN
# 1082        NaN              NaN            NaN
# 1083        NaN              NaN            NaN
# 1084        NaN              NaN            NaN
# 1085        NaN              NaN            NaN
# 1086        NaN              NaN            NaN
#
#                                     id                 issues  \
# 0     MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==  {'totalCount': 13752}
# 1     MDEwOlJlcG9zaXRvcnkxNzc3MzY1MzM=      {'totalCount': 0}
# 2     MDEwOlJlcG9zaXRvcnkxMTczMDM0Mg==   {'totalCount': 8344}
# 3         MDEwOlJlcG9zaXRvcnkyMTI2MjQ0  {'totalCount': 18731}
# 4     MDEwOlJlcG9zaXRvcnkxMDI3MDI1MA==   {'totalCount': 7959}
# 5     MDEwOlJlcG9zaXRvcnk0NTcxNzI1MA==  {'totalCount': 19770}
# 6     MDEwOlJlcG9zaXRvcnkxMzQ5MTg5NQ==    {'totalCount': 398}
# 7     MDEwOlJlcG9zaXRvcnkyMTczNzQ2NQ==    {'totalCount': 230}
# 8     MDEwOlJlcG9zaXRvcnkxNDQ0MDI3MA==    {'totalCount': 771}
# 9         MDEwOlJlcG9zaXRvcnkyOTExMzc=   {'totalCount': 2968}
# 10        MDEwOlJlcG9zaXRvcnkxMDYyODk3      {'totalCount': 0}
# 11        MDEwOlJlcG9zaXRvcnk2NDk4NDky    {'totalCount': 916}
# 12    MDEwOlJlcG9zaXRvcnk2MDQ5MzEwMQ==    {'totalCount': 104}
# 13    MDEwOlJlcG9zaXRvcnk4NTA3NzU1OA==    {'totalCount': 405}
# 14        MDEwOlJlcG9zaXRvcnk5NDMxNDk=   {'totalCount': 2012}
# 15    MDEwOlJlcG9zaXRvcnk0MTg4MTkwMA==  {'totalCount': 73475}
# 16    MDEwOlJlcG9zaXRvcnkyOTAyODc3NQ==  {'totalCount': 17298}
# 17        MDEwOlJlcG9zaXRvcnkyMzI1Mjk4      {'totalCount': 0}
# 18        MDEwOlJlcG9zaXRvcnk5Mzg0MjY3  {'totalCount': 11375}
# 19    MDEwOlJlcG9zaXRvcnkxMjEzOTU1MTA=    {'totalCount': 329}
# 20    MDEwOlJlcG9zaXRvcnkzMTc5MjgyNA==  {'totalCount': 24511}
# 21    MDEwOlJlcG9zaXRvcnkyMTI4OTExMA==    {'totalCount': 152}
# 22    MDEwOlJlcG9zaXRvcnk4MzIyMjQ0MQ==     {'totalCount': 93}
# 23    MDEwOlJlcG9zaXRvcnk2MzUzNzI0OQ==   {'totalCount': 4863}
# 24    MDEwOlJlcG9zaXRvcnkzNTk1NTY2Ng==    {'totalCount': 153}
# 25    MDEwOlJlcG9zaXRvcnkyNzE5Mzc3OQ==  {'totalCount': 10375}
# 26    MDEwOlJlcG9zaXRvcnkyMzA4ODc0MA==   {'totalCount': 1858}
# 27    MDEwOlJlcG9zaXRvcnkyMzA5Njk1OQ==  {'totalCount': 33046}
# 28        MDEwOlJlcG9zaXRvcnkyNTYxNTgy    {'totalCount': 652}
# 29        MDEwOlJlcG9zaXRvcnkzNDcwNDcx  {'totalCount': 14800}
# ...                                ...                    ...
# 1057  MDEwOlJlcG9zaXRvcnkxMDcxMTk2NDk=                    NaN
# 1058      MDEwOlJlcG9zaXRvcnkyMjAzNjQ1                    NaN
# 1059  MDEwOlJlcG9zaXRvcnkxMjUxMjgzMw==                    NaN
# 1060  MDEwOlJlcG9zaXRvcnk3NzM1ODI2Mw==                    NaN
# 1061  MDEwOlJlcG9zaXRvcnk0MDAxMzQzNQ==                    NaN
# 1062      MDEwOlJlcG9zaXRvcnk4Mzg1NjE2                    NaN
# 1063      MDEwOlJlcG9zaXRvcnkxMjIzMDI5                    NaN
# 1064  MDEwOlJlcG9zaXRvcnk4MDIzMzgxNg==                    NaN
# 1065      MDEwOlJlcG9zaXRvcnkxNTM4MjEw                    NaN
# 1066      MDEwOlJlcG9zaXRvcnkyOTkwMTky                    NaN
# 1067  MDEwOlJlcG9zaXRvcnkxMDIxOTEwNg==                    NaN
# 1068  MDEwOlJlcG9zaXRvcnkxOTQxNjU1MQ==                    NaN
# 1069  MDEwOlJlcG9zaXRvcnkyOTA3ODk5Nw==                    NaN
# 1070  MDEwOlJlcG9zaXRvcnkzNzkzMTMwMQ==                    NaN
# 1071  MDEwOlJlcG9zaXRvcnk2OTQ5NTE3MA==                    NaN
# 1072      MDEwOlJlcG9zaXRvcnk5MDg4OTM=                    NaN
# 1073  MDEwOlJlcG9zaXRvcnkzNTY4NTAzNA==                    NaN
# 1074      MDEwOlJlcG9zaXRvcnkzNzQ0NTQ1                    NaN
# 1075  MDEwOlJlcG9zaXRvcnkxMzgzMzE1NzM=                    NaN
# 1076  MDEwOlJlcG9zaXRvcnkxODk4OTAzNzc=                    NaN
# 1077  MDEwOlJlcG9zaXRvcnk0MzY5NTQ3NA==                    NaN
# 1078  MDEwOlJlcG9zaXRvcnkxNzU3NTUzNQ==                    NaN
# 1079  MDEwOlJlcG9zaXRvcnk3ODY2NDM5MQ==                    NaN
# 1080  MDEwOlJlcG9zaXRvcnkxMTM5MzExMA==                    NaN
# 1081      MDEwOlJlcG9zaXRvcnk3NjgzNDU=                    NaN
# 1082      MDEwOlJlcG9zaXRvcnk4MjA1NjAy                    NaN
# 1083  MDEwOlJlcG9zaXRvcnkxNDA2ODc0MzA=                    NaN
# 1084  MDEwOlJlcG9zaXRvcnkxNzgxNDM1NA==                    NaN
# 1085  MDEwOlJlcG9zaXRvcnk2MDcxMTUxMg==                    NaN
# 1086      MDEwOlJlcG9zaXRvcnkxMzM3NjU4                    NaN
#
#                      licenseInfo                         name  \
# 0     {'spdxId': 'BSD-3-Clause'}                 freeCodeCamp
# 1      {'spdxId': 'NOASSERTION'}                      996.ICU
# 2              {'spdxId': 'MIT'}                          vue
# 3              {'spdxId': 'MIT'}                    bootstrap
# 4              {'spdxId': 'MIT'}                        react
# 5       {'spdxId': 'Apache-2.0'}                   tensorflow
# 6      {'spdxId': 'NOASSERTION'}       free-programming-books
# 7                           None                      awesome
# 8      {'spdxId': 'NOASSERTION'}             You-Dont-Know-JS
# 9      {'spdxId': 'NOASSERTION'}                    oh-my-zsh
# 10         {'spdxId': 'CC0-1.0'}                    gitignore
# 11             {'spdxId': 'MIT'}                   javascript
# 12    {'spdxId': 'CC-BY-SA-4.0'}  coding-interview-university
# 13                          None            developer-roadmap
# 14    {'spdxId': 'BSD-3-Clause'}                           d3
# 15             {'spdxId': 'MIT'}                       vscode
# 16     {'spdxId': 'NOASSERTION'}                 react-native
# 17     {'spdxId': 'NOASSERTION'}                        linux
# 18             {'spdxId': 'MIT'}                     electron
# 19                          None                     CS-Notes
# 20     {'spdxId': 'NOASSERTION'}                      flutter
# 21     {'spdxId': 'NOASSERTION'}               awesome-python
# 22     {'spdxId': 'NOASSERTION'}         system-design-primer
# 23             {'spdxId': 'MIT'}             create-react-app
# 24                          None      the-art-of-command-line
# 25     {'spdxId': 'NOASSERTION'}                         node
# 26             {'spdxId': 'MIT'}                        axios
# 27     {'spdxId': 'NOASSERTION'}                           go
# 28             {'spdxId': 'MIT'}                  animate.css
# 29     {'spdxId': 'NOASSERTION'}                 Font-Awesome
# ...                          ...                          ...
# 1057                         NaN                          NaN
# 1058                         NaN                          NaN
# 1059                         NaN                          NaN
# 1060                         NaN                          NaN
# 1061                         NaN                          NaN
# 1062                         NaN                          NaN
# 1063                         NaN                          NaN
# 1064                         NaN                          NaN
# 1065                         NaN                          NaN
# 1066                         NaN                          NaN
# 1067                         NaN                          NaN
# 1068                         NaN                          NaN
# 1069                         NaN                          NaN
# 1070                         NaN                          NaN
# 1071                         NaN                          NaN
# 1072                         NaN                          NaN
# 1073                         NaN                          NaN
# 1074                         NaN                          NaN
# 1075                         NaN                          NaN
# 1076                         NaN                          NaN
# 1077                         NaN                          NaN
# 1078                         NaN                          NaN
# 1079                         NaN                          NaN
# 1080                         NaN                          NaN
# 1081                         NaN                          NaN
# 1082                         NaN                          NaN
# 1083                         NaN                          NaN
# 1084                         NaN                          NaN
# 1085                         NaN                          NaN
# 1086                         NaN                          NaN
#
#                                nameWithOwner                         owner  \
# 0                  freeCodeCamp/freeCodeCamp     {'login': 'freeCodeCamp'}
# 1                             996icu/996.ICU           {'login': '996icu'}
# 2                                  vuejs/vue            {'login': 'vuejs'}
# 3                             twbs/bootstrap             {'login': 'twbs'}
# 4                             facebook/react         {'login': 'facebook'}
# 5                      tensorflow/tensorflow       {'login': 'tensorflow'}
# 6     EbookFoundation/free-programming-books  {'login': 'EbookFoundation'}
# 7                       sindresorhus/awesome     {'login': 'sindresorhus'}
# 8                    getify/You-Dont-Know-JS           {'login': 'getify'}
# 9                     robbyrussell/oh-my-zsh     {'login': 'robbyrussell'}
# 10                          github/gitignore           {'login': 'github'}
# 11                         airbnb/javascript           {'login': 'airbnb'}
# 12       jwasham/coding-interview-university          {'login': 'jwasham'}
# 13           kamranahmedse/developer-roadmap    {'login': 'kamranahmedse'}
# 14                                     d3/d3               {'login': 'd3'}
# 15                          microsoft/vscode        {'login': 'microsoft'}
# 16                     facebook/react-native         {'login': 'facebook'}
# 17                            torvalds/linux         {'login': 'torvalds'}
# 18                         electron/electron         {'login': 'electron'}
# 19                          CyC2018/CS-Notes          {'login': 'CyC2018'}
# 20                           flutter/flutter          {'login': 'flutter'}
# 21                      vinta/awesome-python            {'login': 'vinta'}
# 22          donnemartin/system-design-primer      {'login': 'donnemartin'}
# 23                 facebook/create-react-app         {'login': 'facebook'}
# 24             jlevy/the-art-of-command-line            {'login': 'jlevy'}
# 25                               nodejs/node           {'login': 'nodejs'}
# 26                               axios/axios            {'login': 'axios'}
# 27                                 golang/go           {'login': 'golang'}
# 28                       daneden/animate.css          {'login': 'daneden'}
# 29                  FortAwesome/Font-Awesome      {'login': 'FortAwesome'}
# ...                                      ...                           ...
# 1057                                     NaN                           NaN
# 1058                                     NaN                           NaN
# 1059                                     NaN                           NaN
# 1060                                     NaN                           NaN
# 1061                                     NaN                           NaN
# 1062                                     NaN                           NaN
# 1063                                     NaN                           NaN
# 1064                                     NaN                           NaN
# 1065                                     NaN                           NaN
# 1066                                     NaN                           NaN
# 1067                                     NaN                           NaN
# 1068                                     NaN                           NaN
# 1069                                     NaN                           NaN
# 1070                                     NaN                           NaN
# 1071                                     NaN                           NaN
# 1072                                     NaN                           NaN
# 1073                                     NaN                           NaN
# 1074                                     NaN                           NaN
# 1075                                     NaN                           NaN
# 1076                                     NaN                           NaN
# 1077                                     NaN                           NaN
# 1078                                     NaN                           NaN
# 1079                                     NaN                           NaN
# 1080                                     NaN                           NaN
# 1081                                     NaN                           NaN
# 1082                                     NaN                           NaN
# 1083                                     NaN                           NaN
# 1084                                     NaN                           NaN
# 1085                                     NaN                           NaN
# 1086                                     NaN                           NaN
#
#              primaryLanguage           pullRequests              stargazers  \
# 0     {'name': 'JavaScript'}  {'totalCount': 22525}  {'totalCount': 304556}
# 1           {'name': 'Rust'}   {'totalCount': 1802}  {'totalCount': 247156}
# 2     {'name': 'JavaScript'}   {'totalCount': 1596}  {'totalCount': 147000}
# 3     {'name': 'JavaScript'}  {'totalCount': 10057}  {'totalCount': 135471}
# 4     {'name': 'JavaScript'}   {'totalCount': 8478}  {'totalCount': 135172}
# 5            {'name': 'C++'}  {'totalCount': 12122}  {'totalCount': 133206}
# 6                       None   {'totalCount': 2875}  {'totalCount': 127409}
# 7                       None   {'totalCount': 1359}  {'totalCount': 114878}
# 8                       None    {'totalCount': 728}  {'totalCount': 107442}
# 9          {'name': 'Shell'}   {'totalCount': 5135}   {'totalCount': 94158}
# 10                      None   {'totalCount': 3120}   {'totalCount': 88688}
# 11    {'name': 'JavaScript'}   {'totalCount': 1154}   {'totalCount': 88404}
# 12                      None    {'totalCount': 342}   {'totalCount': 88043}
# 13                      None    {'totalCount': 124}   {'totalCount': 87008}
# 14    {'name': 'JavaScript'}   {'totalCount': 1087}   {'totalCount': 86952}
# 15    {'name': 'TypeScript'}   {'totalCount': 5754}   {'totalCount': 81970}
# 16    {'name': 'JavaScript'}   {'totalCount': 8751}   {'totalCount': 80449}
# 17             {'name': 'C'}    {'totalCount': 684}   {'totalCount': 79583}
# 18           {'name': 'C++'}   {'totalCount': 8504}   {'totalCount': 76481}
# 19          {'name': 'Java'}    {'totalCount': 433}   {'totalCount': 75477}
# 20          {'name': 'Dart'}  {'totalCount': 14896}   {'totalCount': 73583}
# 21        {'name': 'Python'}   {'totalCount': 1180}   {'totalCount': 72272}
# 22        {'name': 'Python'}    {'totalCount': 221}   {'totalCount': 71991}
# 23    {'name': 'JavaScript'}   {'totalCount': 2693}   {'totalCount': 71071}
# 24                      None    {'totalCount': 482}   {'totalCount': 63969}
# 25    {'name': 'JavaScript'}  {'totalCount': 18606}   {'totalCount': 63858}
# 26    {'name': 'JavaScript'}    {'totalCount': 522}   {'totalCount': 63848}
# 27            {'name': 'Go'}    {'totalCount': 782}   {'totalCount': 62658}
# 28           {'name': 'CSS'}    {'totalCount': 311}   {'totalCount': 61666}
# 29    {'name': 'JavaScript'}    {'totalCount': 568}   {'totalCount': 60784}
# ...                      ...                    ...                     ...
# 1057                     NaN                    NaN                     NaN
# 1058                     NaN                    NaN                     NaN
# 1059                     NaN                    NaN                     NaN
# 1060                     NaN                    NaN                     NaN
# 1061                     NaN                    NaN                     NaN
# 1062                     NaN                    NaN                     NaN
# 1063                     NaN                    NaN                     NaN
# 1064                     NaN                    NaN                     NaN
# 1065                     NaN                    NaN                     NaN
# 1066                     NaN                    NaN                     NaN
# 1067                     NaN                    NaN                     NaN
# 1068                     NaN                    NaN                     NaN
# 1069                     NaN                    NaN                     NaN
# 1070                     NaN                    NaN                     NaN
# 1071                     NaN                    NaN                     NaN
# 1072                     NaN                    NaN                     NaN
# 1073                     NaN                    NaN                     NaN
# 1074                     NaN                    NaN                     NaN
# 1075                     NaN                    NaN                     NaN
# 1076                     NaN                    NaN                     NaN
# 1077                     NaN                    NaN                     NaN
# 1078                     NaN                    NaN                     NaN
# 1079                     NaN                    NaN                     NaN
# 1080                     NaN                    NaN                     NaN
# 1081                     NaN                    NaN                     NaN
# 1082                     NaN                    NaN                     NaN
# 1083                     NaN                    NaN                     NaN
# 1084                     NaN                    NaN                     NaN
# 1085                     NaN                    NaN                     NaN
# 1086                     NaN                    NaN                     NaN
#
#                  updatedAt                                         readMeText  \
# 0     2019-08-28T23:48:45Z  {'text': '![freeCodeCamp.org Social Banner](ht...
# 1     2019-08-28T21:26:17Z  {'text': '[996.ICU](https://996.icu/#/en_US)
# =...
# 2     2019-08-28T23:04:19Z  {'text': '<p align="center"><a href="https://v...
# 3     2019-08-28T22:52:51Z                                                NaN
# 4     2019-08-28T21:21:48Z  {'text': '# [React](https://reactjs.org/) &mid...
# 5     2019-08-28T23:46:45Z  {'text': '<div align="center">
#   <img src="htt...
# 6     2019-08-28T23:30:49Z                                                NaN
# 7     2019-08-28T22:32:09Z                                               None
# 8     2019-08-28T23:41:11Z  {'text': '# You Don't Know JS Yet (book series...
# 9     2019-08-28T22:44:24Z  {'text': '<p align="center">
#   <img src="https...
# 10    2019-08-28T23:36:35Z  {'text': '# A collection of `.gitignore` templ...
# 11    2019-08-28T21:07:06Z  {'text': '# Airbnb JavaScript Style Guide() {
# ...
# 12    2019-08-28T23:33:15Z  {'text': '# Coding Interview University
#
# > I o...
# 13    2019-08-28T23:50:04Z                                               None
# 14    2019-08-28T23:25:55Z  {'text': '# D3: Data-Driven Documents
#
# <a href...
# 15    2019-08-28T23:50:40Z  {'text': '# Visual Studio Code - Open Source (...
# 16    2019-08-28T23:44:04Z  {'text': '<h1 align="center">
#   <a href="https...
# 17    2019-08-28T23:50:38Z                                               None
# 18    2019-08-28T23:47:28Z  {'text': '[![Electron Logo](https://electronjs...
# 19    2019-08-28T23:46:55Z  {'text': '<div align="center">
#     <a href="ht...
# 20    2019-08-28T23:49:30Z  {'text': '# [![Flutter logo][]][flutter.dev]
#
# ...
# 21    2019-08-28T22:33:58Z  {'text': '# Awesome Python [![Awesome](https:/...
# 22    2019-08-28T23:06:20Z  {'text': '*[English](README.md) ∙ [日本語](README...
# 23    2019-08-28T22:26:03Z  {'text': '# Create React App [![Build Status](...
# 24    2019-08-28T23:05:36Z                                                NaN
# 25    2019-08-28T23:41:00Z  {'text': '<p align="center">
#   <a href="https:...
# 26    2019-08-28T23:48:10Z  {'text': '# axios
#
# [![npm version](https://img...
# 27    2019-08-28T22:22:04Z  {'text': '# The Go Programming Language
#
# Go is...
# 28    2019-08-28T23:32:12Z  {'text': '# Animate.css [![GitHub release](htt...
# 29    2019-08-28T20:14:30Z                                                NaN
# ...                    ...                                                ...
# 1057                   NaN  {'text': '<img src="https://emilwallner.github...
# 1058                   NaN  {'text': '![CocoaPods Logo](https://raw.github...
# 1059                   NaN  {'text': '# Solved by Flexbox
#
# A showcase of p...
# 1060                   NaN  {'text': '[![SpaceVim](https://spacevim.org/lo...
# 1061                   NaN  {'text': '[<img src="https://raw.githubusercon...
# 1062                   NaN  {'text': '![TOML Logo](logos/toml-200.png)
#
# TO...
# 1063                   NaN  {'text': '# `n` – Interactively Manage Your No...
# 1064                   NaN  {'text': '# Lottie for React Native, [iOS](htt...
# 1065                   NaN  {'text': '# SVProgressHUD
#
# ![Pod Version](http...
# 1066                   NaN  {'text': '# Signal Android
#
# Signal is a messa...
# 1067                   NaN  {'text': '## Welcome to the mean stack
#
# The me...
# 1068                   NaN  {'text': '# DB Browser for SQLite
#
# [![Wiki][wi...
# 1069                   NaN  {'text': '## Welcome to the .NET Compiler Plat...
# 1070                   NaN  {'text': '# React Redux Universal Hot Example
# ...
# 1071                   NaN  {'text': '<div align="center">
# <img src="https...
# 1072                   NaN  {'text': 'redis - a node.js redis client
# =====...
# 1073                   NaN  {'text': '![Vector Icons for React Native](htt...
# 1074                   NaN  {'text': '# bootstrap-datepicker
#
# [![Join the ...
# 1075                   NaN  {'text': '# Tracking Progress in Natural Langu...
# 1076                   NaN  {'text': '# FullStack
#
# ## What is this?
#
# This ...
# 1077                   NaN  {'text': '![Quasar Framework logo](https://cdn...
# 1078                   NaN  {'text': '# Big welcome by the Chartist Guy
#
# [...
# 1079                   NaN  {'text': '# Create React Native App
#
# **Note: T...
# 1080                   NaN  {'text': 'cli
# ===
#
# [![Build Status](https://tr...
# 1081                   NaN  {'text': '# Spectacle
#
# [![Build Status](https:...
# 1082                   NaN  {'text': 'MyBatis SQL Mapper Framework for Jav...
# 1083                   NaN  {'text': '# uni-app
#
# `uni-app` 是一个使用 `Vue.js` ...
# 1084                   NaN  {'text': 'mithril.js [![npm Version](https://i...
# 1085                   NaN  {'text': '# LearningNotes
#   ---
#
# ## 第一部分：
#
# * [...
# 1086                   NaN  {'text': '# Respond.js
# ### A fast & lightweigh...
#
#                                    commit
# 0      {'history': {'totalCount': 24700}}
# 1       {'history': {'totalCount': 2960}}
# 2       {'history': {'totalCount': 2283}}
# 3      {'history': {'totalCount': 18978}}
# 4      {'history': {'totalCount': 12327}}
# 5      {'history': {'totalCount': 63831}}
# 6       {'history': {'totalCount': 5060}}
# 7        {'history': {'totalCount': 849}}
# 8       {'history': {'totalCount': 1491}}
# 9       {'history': {'totalCount': 5218}}
# 10      {'history': {'totalCount': 3153}}
# 11      {'history': {'totalCount': 1772}}
# 12      {'history': {'totalCount': 1283}}
# 13       {'history': {'totalCount': 203}}
# 14      {'history': {'totalCount': 4191}}
# 15     {'history': {'totalCount': 53774}}
# 16     {'history': {'totalCount': 17850}}
# 17    {'history': {'totalCount': 857203}}
# 18     {'history': {'totalCount': 22421}}
# 19      {'history': {'totalCount': 3431}}
# 20     {'history': {'totalCount': 15513}}
# 21      {'history': {'totalCount': 1374}}
# 22       {'history': {'totalCount': 274}}
# 23      {'history': {'totalCount': 2304}}
# 24      {'history': {'totalCount': 1185}}
# 25     {'history': {'totalCount': 28011}}
# 26       {'history': {'totalCount': 853}}
# 27     {'history': {'totalCount': 40869}}
# 28       {'history': {'totalCount': 453}}
# 29        {'history': {'totalCount': 58}}
# ...                                   ...
# 1057     {'history': {'totalCount': 170}}
# 1058    {'history': {'totalCount': 8560}}
# 1059     {'history': {'totalCount': 357}}
# 1060    {'history': {'totalCount': 4117}}
# 1061    {'history': {'totalCount': 1948}}
# 1062     {'history': {'totalCount': 661}}
# 1063     {'history': {'totalCount': 577}}
# 1064     {'history': {'totalCount': 375}}
# 1065     {'history': {'totalCount': 768}}
# 1066    {'history': {'totalCount': 4437}}
# 1067    {'history': {'totalCount': 2202}}
# 1068    {'history': {'totalCount': 3016}}
# 1069   {'history': {'totalCount': 49180}}
# 1070     {'history': {'totalCount': 970}}
# 1071    {'history': {'totalCount': 2083}}
# 1072    {'history': {'totalCount': 1258}}
# 1073     {'history': {'totalCount': 495}}
# 1074    {'history': {'totalCount': 1648}}
# 1075     {'history': {'totalCount': 483}}
# 1076      {'history': {'totalCount': 60}}
# 1077    {'history': {'totalCount': 5706}}
# 1078     {'history': {'totalCount': 856}}
# 1079     {'history': {'totalCount': 259}}
# 1080    {'history': {'totalCount': 1113}}
# 1081     {'history': {'totalCount': 679}}
# 1082    {'history': {'totalCount': 2977}}
# 1083    {'history': {'totalCount': 1237}}
# 1084    {'history': {'totalCount': 3490}}
# 1085     {'history': {'totalCount': 227}}
# 1086     {'history': {'totalCount': 278}}
#
# [1087 rows x 17 columns]

# %%
df_repo.to_pickle('../../../Files/df_repo_pandas_final.pk1')
