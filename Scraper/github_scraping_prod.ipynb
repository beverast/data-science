# %%
from string import Template

import pandas as pd
import requests

# %% [markdown]
# ### Set `file`, `repo_owner`, and `repo_name` Before Running Notebook

# %%
file = open("/home/joseph/graphql_token.txt", "r")
api_token = file.read().strip()
headers = {"Authorization": "token %s" % api_token}

# %%
repo_owner = "pandas-dev"
repo_name = "pandas"

# %%
# Query Pull Request
pr_query = Template('''
{
  repositoryOwner(login: "$repo_owner") {
    repository(name: "$repo_name") {
      pullRequests(first: 100) {
        pageInfo {
          endCursor
          hasNextPage
        }
        nodes {
          createdAt
          updatedAt
          closedAt
          title
          mergedBy {
            login
          }
          author {
            login
            ... on User {
              company
            }
          }
          authorAssociation
          files {
            totalCount
          }
          state
          resourcePath
          bodyText
          comments(first: 25) {
            totalCount
            nodes {
              author {
                login
                ... on User {
                  company
                }
              }
              authorAssociation
              bodyText
            }
          }
        }
      }
    }
  }
  rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
''')

pr_query_2 = Template('''
{
  repositoryOwner(login: "$repo_owner") {
    repository(name: "$repo_name") {
      pullRequests(first: 100, after: "$end_cursor") {
        pageInfo {
          endCursor
          hasNextPage
        }
        nodes {
          createdAt
          updatedAt
          closedAt
          title
          mergedBy {
            login
          }
          author {
            login
            ... on User {
              company
            }
          }
          authorAssociation
          files {
            totalCount
          }
          state
          resourcePath
          bodyText
          comments(first: 25) {
            totalCount
            nodes {
              author {
                login
                ... on User {
                  company
                }
              }
              authorAssociation
              bodyText
            }
          }
        }
      }
    }
  }
  rateLimit {
    limit
    cost
    remaining
    resetAt
  }
}
''')


variables = {
    "repo_owner": "",
    "repo_name": "",
    "end_cursor": ""
}

# %%
# Function to use requests.post to make an API call
def run_query(query): 
    request = requests.post('https://api.github.com/graphql', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        print("Query failed to run by returning code of {}. {}".format(request.status_code, query))

# %%
def to_df(result):
    # Get the keys of nodes.
    data = result['data']['repositoryOwner']['repository']['pullRequests']['nodes']
    
    # Put the data into a dataframe
    df_pr = pd.DataFrame(data)
    
    return df_pr
def get_page_info(result):
    cur = result['data']['repositoryOwner']['repository']['pullRequests']['pageInfo']['endCursor']
    has_cur = result['data']['repositoryOwner']['repository']['pullRequests']['pageInfo']['hasNextPage']
    return cur, has_cur
def result_query(query):
    # Run first query
    result = run_query(query)
    # Save to DF
    df_pr = to_df(result)
    # Get end cursor and has cursor
    variables['end_cursor'], has_cursor = get_page_info(result)
    # Limit
    limit = result['data']['rateLimit']['remaining']
    
    return df_pr, has_cursor, limit

# %%
# Get `createdAt` date for repo, use that as cursor
repo_query = Template('''
{
  repositoryOwner(login:"$repo_owner") {
    id
    login
    repository(name:"$repo_name") {
      id
      name
      createdAt
      updatedAt
      description
    }
  }
}
''')

# Query for repo info
repo_query_sub = repo_query.substitute(repo_owner=repo_owner, repo_name=repo_name)

query_results = run_query(repo_query_sub)
query_dict = query_results['data']['repositoryOwner']['repository']
repo_createdAt = pd.Timestamp(query_dict['createdAt']).date()

# Update variables dict
#variables["end_cursor"] = str(repo_createdAt)
variables["end_cursor"] = str(repo_createdAt)
variables["repo_owner"] = repo_owner
variables["repo_name"] = repo_name

# %%
# Run first query
print(variables)
pr_query_sub = pr_query.substitute(**variables)
print(pr_query_2.substitute(**variables))
df_pr, has_cursor, limit = result_query(pr_query_sub)
print('Starting limit is: ', limit)
print('Start cursor: ', has_cursor, '\n')

# Run remaining queries
while has_cursor and (limit >= 0):
    try:
        # Run next queries
        df_pr_2, has_cursor, limit = result_query(pr_query_2.substitute(**variables))
        # Concat to existing df_star
        df_pr = pd.concat([df_pr, df_pr_2])
    except:
        # The print stmnt in `run_query()` will print error messages
        continue
    
    # Print limit and cursor
    print('Next limit is: ', limit)
    print('Next cursor: ', has_cursor)
    print(df_pr.shape, '\n')
# Out:
# {'repo_owner': 'pandas-dev', 'repo_name': 'pandas', 'end_cursor': '2010-08-24'}
#
# {
#   repositoryOwner(login: "pandas-dev") {
#     repository(name: "pandas") {
#       pullRequests(first: 100, after: "2010-08-24") {
#         pageInfo {
#           endCursor
#           hasNextPage
#         }
#         nodes {
#           createdAt
#           updatedAt
#           closedAt
#           title
#           mergedBy {
#             login
#           }
#           author {
#             login
#             ... on User {
#               company
#             }
#           }
#           authorAssociation
#           files {
#             totalCount
#           }
#           state
#           resourcePath
#           bodyText
#           comments(first: 25) {
#             totalCount
#             nodes {
#               author {
#                 login
#                 ... on User {
#                   company
#                 }
#               }
#               authorAssociation
#               bodyText
#             }
#           }
#         }
#       }
#     }
#   }
#   rateLimit {
#     limit
#     cost
#     remaining
#     resetAt
#   }
# }
#
# Starting limit is:  4635
# Start cursor:  True
#
# Next limit is:  4634
# Next cursor:  True
# (200, 12)
#
# Next limit is:  4633
# Next cursor:  True
# (300, 12)
#
# Next limit is:  4632
# Next cursor:  True
# (400, 12)
#
# Next limit is:  4631
# Next cursor:  True
# (500, 12)
#
# Next limit is:  4630
# Next cursor:  True
# (600, 12)
#
# Next limit is:  4629
# Next cursor:  True
# (700, 12)
#
# Next limit is:  4628
# Next cursor:  True
# (800, 12)
#
# Next limit is:  4627
# Next cursor:  True
# (900, 12)
#
# Next limit is:  4626
# Next cursor:  True
# (1000, 12)
#
# Next limit is:  4625
# Next cursor:  True
# (1100, 12)
#
# Next limit is:  4624
# Next cursor:  True
# (1200, 12)
#
# Next limit is:  4623
# Next cursor:  True
# (1300, 12)
#
# Next limit is:  4622
# Next cursor:  True
# (1400, 12)
#
# Next limit is:  4621
# Next cursor:  True
# (1500, 12)
#
# Next limit is:  4620
# Next cursor:  True
# (1600, 12)
#
# Next limit is:  4619
# Next cursor:  True
# (1700, 12)
#
# Next limit is:  4618
# Next cursor:  True
# (1800, 12)
#
# Next limit is:  4617
# Next cursor:  True
# (1900, 12)
#
# Next limit is:  4616
# Next cursor:  True
# (2000, 12)
#
# Next limit is:  4615
# Next cursor:  True
# (2100, 12)
#
# Next limit is:  4614
# Next cursor:  True
# (2200, 12)
#
# Next limit is:  4613
# Next cursor:  True
# (2300, 12)
#
# Next limit is:  4612
# Next cursor:  True
# (2400, 12)
#
# Next limit is:  4611
# Next cursor:  True
# (2500, 12)
#
# Next limit is:  4610
# Next cursor:  True
# (2600, 12)
#
# Next limit is:  4609
# Next cursor:  True
# (2700, 12)
#
# Next limit is:  4608
# Next cursor:  True
# (2800, 12)
#
# Next limit is:  4607
# Next cursor:  True
# (2900, 12)
#
# Next limit is:  4606
# Next cursor:  True
# (3000, 12)
#
# Next limit is:  4605
# Next cursor:  True
# (3100, 12)
#
# Next limit is:  4604
# Next cursor:  True
# (3200, 12)
#
# Next limit is:  4603
# Next cursor:  True
# (3300, 12)
#
# Next limit is:  4602
# Next cursor:  True
# (3400, 12)
#
# Next limit is:  4601
# Next cursor:  True
# (3500, 12)
#
# Next limit is:  4600
# Next cursor:  True
# (3600, 12)
#
# Next limit is:  4599
# Next cursor:  True
# (3700, 12)
#
# Next limit is:  4598
# Next cursor:  True
# (3800, 12)
#
# Next limit is:  4597
# Next cursor:  True
# (3900, 12)
#
# Next limit is:  4596
# Next cursor:  True
# (4000, 12)
#
# Next limit is:  4595
# Next cursor:  True
# (4100, 12)
#
# Next limit is:  4594
# Next cursor:  True
# (4200, 12)
#
# Next limit is:  4593
# Next cursor:  True
# (4300, 12)
#
# Next limit is:  4592
# Next cursor:  True
# (4400, 12)
#
# Next limit is:  4591
# Next cursor:  True
# (4500, 12)
#
# Next limit is:  4590
# Next cursor:  True
# (4600, 12)
#
# Next limit is:  4589
# Next cursor:  True
# (4700, 12)
#
# Next limit is:  4588
# Next cursor:  True
# (4800, 12)
#
# Next limit is:  4587
# Next cursor:  True
# (4900, 12)
#
# Next limit is:  4586
# Next cursor:  True
# (5000, 12)
#
# Next limit is:  4585
# Next cursor:  True
# (5100, 12)
#
# Next limit is:  4584
# Next cursor:  True
# (5200, 12)
#
# Next limit is:  4583
# Next cursor:  True
# (5300, 12)
#
# Next limit is:  4582
# Next cursor:  True
# (5400, 12)
#
# Next limit is:  4581
# Next cursor:  True
# (5500, 12)
#
# Next limit is:  4580
# Next cursor:  True
# (5600, 12)
#
# Next limit is:  4579
# Next cursor:  True
# (5700, 12)
#
# Next limit is:  4578
# Next cursor:  True
# (5800, 12)
#
# Next limit is:  4577
# Next cursor:  True
# (5900, 12)
#
# Next limit is:  4576
# Next cursor:  True
# (6000, 12)
#
# Next limit is:  4575
# Next cursor:  True
# (6100, 12)
#
# Next limit is:  4574
# Next cursor:  True
# (6200, 12)
#
# Next limit is:  4573
# Next cursor:  True
# (6300, 12)
#
# Next limit is:  4572
# Next cursor:  True
# (6400, 12)
#
# Next limit is:  4571
# Next cursor:  True
# (6500, 12)
#
# Next limit is:  4570
# Next cursor:  True
# (6600, 12)
#
# Next limit is:  4569
# Next cursor:  True
# (6700, 12)
#
# Next limit is:  4568
# Next cursor:  True
# (6800, 12)
#
# Next limit is:  4567
# Next cursor:  True
# (6900, 12)
#
# Next limit is:  4566
# Next cursor:  True
# (7000, 12)
#
# Next limit is:  4565
# Next cursor:  True
# (7100, 12)
#
# Next limit is:  4564
# Next cursor:  True
# (7200, 12)
#
# Next limit is:  4563
# Next cursor:  True
# (7300, 12)
#
# Next limit is:  4562
# Next cursor:  True
# (7400, 12)
#
# Next limit is:  4561
# Next cursor:  True
# (7500, 12)
#
# Next limit is:  4560
# Next cursor:  True
# (7600, 12)
#
# Next limit is:  4559
# Next cursor:  True
# (7700, 12)
#
# Next limit is:  4558
# Next cursor:  True
# (7800, 12)
#
# Next limit is:  4557
# Next cursor:  True
# (7900, 12)
#
# Next limit is:  4556
# Next cursor:  True
# (8000, 12)
#
# Next limit is:  4555
# Next cursor:  True
# (8100, 12)
#
# Next limit is:  4554
# Next cursor:  True
# (8200, 12)
#
# Next limit is:  4553
# Next cursor:  True
# (8300, 12)
#
# Next limit is:  4552
# Next cursor:  True
# (8400, 12)
#
# Next limit is:  4551
# Next cursor:  True
# (8500, 12)
#
# Next limit is:  4550
# Next cursor:  True
# (8600, 12)
#
# Next limit is:  4549
# Next cursor:  True
# (8700, 12)
#
# Next limit is:  4548
# Next cursor:  True
# (8800, 12)
#
# Next limit is:  4547
# Next cursor:  True
# (8900, 12)
#
# Next limit is:  4546
# Next cursor:  True
# (9000, 12)
#
# Next limit is:  4545
# Next cursor:  True
# (9100, 12)
#
# Next limit is:  4544
# Next cursor:  True
# (9200, 12)
#
# Next limit is:  4543
# Next cursor:  True
# (9300, 12)
#
# Next limit is:  4542
# Next cursor:  True
# (9400, 12)
#
# Next limit is:  4541
# Next cursor:  True
# (9500, 12)
#
# Next limit is:  4540
# Next cursor:  True
# (9600, 12)
#
# Next limit is:  4539
# Next cursor:  True
# (9700, 12)
#
# Next limit is:  4538
# Next cursor:  True
# (9800, 12)
#
# Next limit is:  4537
# Next cursor:  True
# (9900, 12)
#
# Next limit is:  4536
# Next cursor:  True
# (10000, 12)
#
# Next limit is:  4535
# Next cursor:  True
# (10100, 12)
#
# Next limit is:  4534
# Next cursor:  True
# (10200, 12)
#
# Next limit is:  4533
# Next cursor:  True
# (10300, 12)
#
# Next limit is:  4532
# Next cursor:  True
# (10400, 12)
#
# Next limit is:  4531
# Next cursor:  True
# (10500, 12)
#
# Next limit is:  4530
# Next cursor:  True
# (10600, 12)
#
# Next limit is:  4529
# Next cursor:  True
# (10700, 12)
#
# Next limit is:  4528
# Next cursor:  True
# (10800, 12)
#
# Next limit is:  4527
# Next cursor:  True
# (10900, 12)
#
# Next limit is:  4526
# Next cursor:  True
# (11000, 12)
#
# Next limit is:  4525
# Next cursor:  True
# (11100, 12)
#
# Next limit is:  4524
# Next cursor:  True
# (11200, 12)
#
# Next limit is:  4523
# Next cursor:  True
# (11300, 12)
#
# Next limit is:  4522
# Next cursor:  True
# (11400, 12)
#
# Next limit is:  4521
# Next cursor:  True
# (11500, 12)
#
# Next limit is:  4520
# Next cursor:  True
# (11600, 12)
#
# Next limit is:  4519
# Next cursor:  True
# (11700, 12)
#
# Next limit is:  4518
# Next cursor:  True
# (11800, 12)
#
# Next limit is:  4517
# Next cursor:  True
# (11900, 12)
#
# Next limit is:  4516
# Next cursor:  True
# (12000, 12)
#
# Next limit is:  4515
# Next cursor:  True
# (12100, 12)
#
# Next limit is:  4514
# Next cursor:  True
# (12200, 12)
#
# Next limit is:  4513
# Next cursor:  True
# (12300, 12)
#
# Next limit is:  4512
# Next cursor:  True
# (12400, 12)
#
# Next limit is:  4511
# Next cursor:  False
# (12429, 12)

# %%
df_pr.head()
# Out:
#                                     author authorAssociation  \
# 0                                     None              NONE
# 1                                     None              NONE
# 2                                     None              NONE
# 3  {'login': 'dieterv77', 'company': None}       CONTRIBUTOR
# 4     {'login': 'jberka', 'company': None}       CONTRIBUTOR
#
#                                             bodyText              closedAt  \
# 0  I have added hist method to frame.py and serie...  2011-02-25T01:41:56Z
# 1  Added two methods in frame.py: describe, which...  2011-03-18T20:00:26Z
# 2  So the results of DataFrame.toString() without...  2011-03-22T20:01:36Z
# 3  Hi Wes, i've been following your pandas work f...  2011-06-29T02:06:48Z
# 4  Starting small...\nIt looks like the .h5 files...  2011-08-07T16:15:41Z
#
#                                             comments             createdAt  \
# 0  {'totalCount': 2, 'nodes': [{'author': {'login...  2011-02-22T08:07:35Z
# 1  {'totalCount': 4, 'nodes': [{'author': {'login...  2011-03-06T01:35:53Z
# 2  {'totalCount': 2, 'nodes': [{'author': {'login...  2011-03-22T19:27:42Z
# 3  {'totalCount': 1, 'nodes': [{'author': {'login...  2011-06-29T00:59:24Z
# 4  {'totalCount': 1, 'nodes': [{'author': {'login...  2011-08-06T08:02:19Z
#
#                files           mergedBy                resourcePath   state  \
# 0  {'totalCount': 3}               None  /pandas-dev/pandas/pull/35  CLOSED
# 1  {'totalCount': 1}  {'login': 'wesm'}  /pandas-dev/pandas/pull/37  MERGED
# 2  {'totalCount': 1}  {'login': 'wesm'}  /pandas-dev/pandas/pull/38  MERGED
# 3  {'totalCount': 1}  {'login': 'wesm'}  /pandas-dev/pandas/pull/55  MERGED
# 4  {'totalCount': 1}  {'login': 'wesm'}  /pandas-dev/pandas/pull/89  MERGED
#
#                                                title             updatedAt
# 0  Added hist method and added auto_x argument to...  2011-02-27T05:17:56Z
# 1   added describe and scoreatpercentile in frame.py  2014-07-03T19:26:14Z
# 2  changed _pfixed in common.py to add a leading ...  2011-03-22T23:47:23Z
# 3  Minor change to CleanCommand so build works wi...  2011-06-29T02:07:07Z
# 4                                  Fix for issue #80  2014-07-17T17:26:50Z

# %%
pickle_filename = './'+repo_owner+'_'+repo_name+'_df.pk1' 

df_pr.to_pickle(pickle_filename)
