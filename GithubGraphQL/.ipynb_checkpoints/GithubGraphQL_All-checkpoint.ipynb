# %% [markdown]
# # Connect to `GitHub GraphQL` API

# %%
import requests
import pandas as pd

# %%
# Open and read file
with open ('../../../Auth_Keys/graphql_api_auth.txt') as file:
    token = file.read()
    
# Specify the Authorization code
headers = {"Authorization": 'Bearer ' + token}

# %%
# Function to use requests.post to make an API call
def run_query(query): 
    request = requests.post('https://api.github.com/graphql', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

# %% [markdown]
# ---

# %% [markdown]
# # Random Repos

# %%
df = pd.read_pickle('../../../Files/more_repos/df_repo_5000.pk1')

# %%
df[200:]
# Out:
#                      createdAt  \
# 200  2012-04-30 09:06:50+00:00
# 201  2018-09-07 03:43:00+00:00
# 202  2009-09-27 20:32:15+00:00
# 203  2009-12-06 12:05:24+00:00
# 204  2012-04-06 04:12:28+00:00
# 205  2019-04-09 23:06:17+00:00
# 206  2015-02-22 07:46:03+00:00
# 207  2013-03-05 21:35:36+00:00
# 208  2016-04-08 18:35:05+00:00
# 209  2016-06-06 13:36:38+00:00
# 210  2014-08-19 15:34:30+00:00
# 211  2015-05-01 23:49:58+00:00
# 212  2014-03-28 02:42:36+00:00
# 213  2013-10-18 07:31:57+00:00
# 214  2015-05-05 05:33:50+00:00
# 215  2013-01-03 22:08:24+00:00
# 216  2010-04-25 23:41:49+00:00
# 217  2012-01-21 13:14:51+00:00
# 218  2011-12-04 23:47:13+00:00
# 219  2016-12-12 19:45:37+00:00
# 220  2016-09-12 17:25:57+00:00
# 221  2016-05-30 00:43:29+00:00
# 222  2013-06-19 05:27:51+00:00
# 223  2014-10-20 07:40:15+00:00
# 224  2018-07-03 00:42:54+00:00
# 225  2014-12-25 20:08:12+00:00
# 226  2010-05-13 21:21:50+00:00
# 227  2011-08-01 19:23:31+00:00
# 228  2014-08-21 16:33:06+00:00
# 229  2017-07-06 01:15:32+00:00
# ...                        ...
# 4970 2012-08-03 08:50:03+00:00
# 4971 2013-07-30 00:41:31+00:00
# 4972 2016-07-14 12:11:19+00:00
# 4973 2012-12-02 19:54:40+00:00
# 4974 2012-09-30 17:06:34+00:00
# 4975 2017-02-13 21:26:34+00:00
# 4976 2011-05-06 15:11:47+00:00
# 4977 2016-10-11 06:26:42+00:00
# 4978 2009-05-17 15:00:56+00:00
# 4979 2010-06-06 13:19:49+00:00
# 4980 2015-09-27 05:18:57+00:00
# 4981 2017-10-05 16:16:46+00:00
# 4982 2017-11-05 20:34:49+00:00
# 4983 2011-03-07 09:29:25+00:00
# 4984 2010-07-15 01:00:30+00:00
# 4985 2012-07-21 14:31:29+00:00
# 4986 2016-12-24 22:07:49+00:00
# 4987 2008-11-22 12:01:18+00:00
# 4988 2012-09-23 18:07:17+00:00
# 4989 2014-05-01 17:29:02+00:00
# 4990 2018-11-29 11:36:47+00:00
# 4991 2016-07-05 04:08:35+00:00
# 4992 2009-02-24 08:52:01+00:00
# 4993 2019-07-27 21:45:47+00:00
# 4994 2015-11-09 02:23:02+00:00
# 4995 2010-09-27 02:02:07+00:00
# 4996 2014-08-17 12:02:39+00:00
# 4997 2015-04-17 00:35:54+00:00
# 4998 2019-02-12 06:02:06+00:00
# 4999 2011-08-07 22:48:33+00:00
#
#                                             description  totalForks  \
# 200   A community owned and driven, enterprise fork ...          93
# 201   SVScanner - Scanner Vulnerability And MaSsive ...          31
# 202   This project aims to be the Scala Incubator pr...          49
# 203                       The Linux Scheduler Simulator           9
# 204                                     Houdini things!          22
# 205     Repository from the article published in Medium          21
# 206                          A web spider for zhihu.com         350
# 207   A teeny tiny smooth scroll script with ease-in...         121
# 208   Список рекомендаций по неусложнению жизни себе...         101
# 209                          Native Python WFDB package         149
# 210   Tracking made easy: Don’t fool around with add...          92
# 211          Office Online test tools and documentation         108
# 212   Ansible Playbook for setting up a Django app w...         357
# 213                   The GoPiGo Robot for Raspberry Pi         191
# 214   GitHub Classroom automates repository creation...         387
# 215   CORS Anywhere is a NodeJS reverse proxy which ...         854
# 216    An ultra-lightweight, inversion of control co...           6
# 217                               Clojure OAuth library          22
# 218     A more-fun, semantic, alternative to datatables         382
# 219       Create amazing 360 and VR content using React         996
# 220   Automatic play video & cache video data in UIT...         384
# 221                             www.jakobejitblokaci.cz           9
# 222                BiB/i | EPUB Reader on your website.          60
# 223            Floppy drive emulator for Gotek hardware          55
# 224   This is the supplementary material for "How to...         107
# 225    Modules for nodeMcu (LUA intepreter for ESP8266)          49
# 226   Official Todo.txt Android app for managing you...         443
# 227        General-purpose categories of Cocoa classes.          46
# 228    The Product Studio at Cornell Tech (TECH  5900).          41
# 229                                   一步一步搭建一个react项目环境          39
# ...                                                 ...         ...
# 4970  SSH2 client and server modules written in pure...         405
# 4971                                Slide Dropdown Menu          72
# 4972  Save a web page/selection as an eBook (.epub f...          56
# 4973  Apple's JavaScript Engine, with modified proje...         150
# 4974                  A tiny debugging library for Ruby           9
# 4975  Self hosted project management and collaborati...         272
# 4976  github.com/cznic/golex has moved to modernc.or...          16
# 4977  vlc-android The latest compilation video playb...          91
# 4978        Low-glycemic OpenGL hacking for R6RS Scheme           5
# 4979  Jake2 is a port of the Quake2 game engine to j...           8
# 4980  CFA (Colour Filter Array) Demosaicing Algorith...          18
# 4981  Convert modern CSS into something browsers und...          46
# 4982  Mentalist is a graphical tool for custom wordl...          81
# 4983  A little ruby script to quickly add apache vho...          11
# 4984  Extended session management for Vim (:mksessio...          69
# 4985  Nut is a tool to manage versioned Go source co...           6
# 4986  Find common xib and storyboard-related problem...          26
# 4987                                A* search in Python          13
# 4988                the main hackademic code repository          95
# 4989  [DEPRECATED] Explorations around Android custo...         210
# 4990  An IDA Python script to extract information fr...          24
# 4991                                       从零开始研究外挂设计原理         144
# 4992                         Test your code in SYNOPSIS           8
# 4993                                               None           5
# 4994         Adds Transparency To The Gnome Shell Panel          17
# 4995          Python interface to GPU-powered libraries         141
# 4996  A curated list of quality Lua packages and res...         216
# 4997  Simple and portable (but not inflexible) GUI l...         501
# 4998  Linux privilege escalation exploit via snapd (...          90
# 4999  Open Source SW Library for NXP's LPC1114 ARM C...          20
#
#       hasIssuesEnabled  hasWikiEnabled                                id  \
# 200               True            True      MDEwOlJlcG9zaXRvcnk0MTgxMjIy
# 201               True           False  MDEwOlJlcG9zaXRvcnkxNDc3NjY5NjE=
# 202               True            True      MDEwOlJlcG9zaXRvcnkzMTkyOTY=
# 203               True            True      MDEwOlJlcG9zaXRvcnk0MDE5NTI=
# 204               True            True      MDEwOlJlcG9zaXRvcnkzOTQ2NzY3
# 205               True            True  MDEwOlJlcG9zaXRvcnkxODA0NjI1MjI=
# 206               True            True  MDEwOlJlcG9zaXRvcnkzMTE1NjM0OQ==
# 207               True            True      MDEwOlJlcG9zaXRvcnk4NTg5Njkx
# 208               True           False  MDEwOlJlcG9zaXRvcnk1NTgwMTI1Mw==
# 209               True            True  MDEwOlJlcG9zaXRvcnk2MDUzMDY2Nw==
# 210               True            True  MDEwOlJlcG9zaXRvcnkyMzExNTU2Nw==
# 211               True            True  MDEwOlJlcG9zaXRvcnkzNDkyOTI3OA==
# 212               True            True  MDEwOlJlcG9zaXRvcnkxODE5ODk5OA==
# 213               True            True  MDEwOlJlcG9zaXRvcnkxMzY3MTcyOA==
# 214               True           False  MDEwOlJlcG9zaXRvcnkzNTA3OTk2NA==
# 215               True            True      MDEwOlJlcG9zaXRvcnk3NDMxMTMz
# 216               True            True      MDEwOlJlcG9zaXRvcnk2Mjg3Nzk=
# 217               True            True      MDEwOlJlcG9zaXRvcnkzMjMzNzcx
# 218               True            True      MDEwOlJlcG9zaXRvcnkyOTEzMTE3
# 219               True           False  MDEwOlJlcG9zaXRvcnk3NjI4OTc5Nw==
# 220               True            True  MDEwOlJlcG9zaXRvcnk2ODAzMTI3NQ==
# 221               True            True  MDEwOlJlcG9zaXRvcnk1OTk3MDMxNg==
# 222               True            True  MDEwOlJlcG9zaXRvcnkxMDc4MTQ1Mw==
# 223               True            True  MDEwOlJlcG9zaXRvcnkyNTQ1NTgzMA==
# 224               True            True  MDEwOlJlcG9zaXRvcnkxMzk1MDkzNzQ=
# 225               True            True  MDEwOlJlcG9zaXRvcnkyODQ5MDIzMA==
# 226               True            True      MDEwOlJlcG9zaXRvcnk2NjUzNTc=
# 227               True            True      MDEwOlJlcG9zaXRvcnkyMTM4NTMy
# 228               True            True  MDEwOlJlcG9zaXRvcnkyMzE5NDY2Mg==
# 229               True            True  MDEwOlJlcG9zaXRvcnk5NjM3NDU3OA==
# ...                ...             ...                               ...
# 4970              True            True      MDEwOlJlcG9zaXRvcnk1MjgzMTkz
# 4971              True            True  MDEwOlJlcG9zaXRvcnkxMTc1MzA1MQ==
# 4972              True            True  MDEwOlJlcG9zaXRvcnk2MzMzMzY1Mg==
# 4973              True            True      MDEwOlJlcG9zaXRvcnk2OTcxNDY3
# 4974              True            True      MDEwOlJlcG9zaXRvcnk2MDIwMzU2
# 4975              True            True  MDEwOlJlcG9zaXRvcnk4MTg3MzYxOQ==
# 4976              True            True      MDEwOlJlcG9zaXRvcnkxNzExNzc1
# 4977              True            True  MDEwOlJlcG9zaXRvcnk3MDU2MjkwMg==
# 4978              True            True      MDEwOlJlcG9zaXRvcnkyMDMxNzg=
# 4979             False            True      MDEwOlJlcG9zaXRvcnk3MDU5NjM=
# 4980              True            True  MDEwOlJlcG9zaXRvcnk0MzIzNTQ0Nw==
# 4981              True            True  MDEwOlJlcG9zaXRvcnkxMDU5MTI0NDQ=
# 4982              True            True  MDEwOlJlcG9zaXRvcnkxMDk2MTQyMDU=
# 4983              True            True      MDEwOlJlcG9zaXRvcnkxNDQ5Mzk3
# 4984              True            True      MDEwOlJlcG9zaXRvcnk3NzU3ODA=
# 4985              True            True      MDEwOlJlcG9zaXRvcnk1MTM0MjE5
# 4986              True            True  MDEwOlJlcG9zaXRvcnk3NzMwMTY4MQ==
# 4987              True            True      MDEwOlJlcG9zaXRvcnk3OTQ2MQ==
# 4988              True            True      MDEwOlJlcG9zaXRvcnk1OTI0NjQ3
# 4989              True            True  MDEwOlJlcG9zaXRvcnkxOTM1MjAzMA==
# 4990              True            True  MDEwOlJlcG9zaXRvcnkxNTk2NTY1MzU=
# 4991              True            True  MDEwOlJlcG9zaXRvcnk2MjYwNTE1MA==
# 4992              True            True      MDEwOlJlcG9zaXRvcnkxMzYxMjA=
# 4993              True            True  MDEwOlJlcG9zaXRvcnkxOTkyMTYxODM=
# 4994              True            True  MDEwOlJlcG9zaXRvcnk0NTgwOTk3Nw==
# 4995              True            True      MDEwOlJlcG9zaXRvcnk5NDE0OTI=
# 4996              True            True  MDEwOlJlcG9zaXRvcnkyMzAzOTYwNg==
# 4997              True            True  MDEwOlJlcG9zaXRvcnkzNDA4ODI4NQ==
# 4998              True            True  MDEwOlJlcG9zaXRvcnkxNzAyNjE1OTA=
# 4999              True            True      MDEwOlJlcG9zaXRvcnkyMTcwNjAx
#
#       totalIssues   licenseInfo                                        name  \
# 200           112   NOASSERTION                                    mageplus
# 201             0    Apache-2.0                                   SVScanner
# 202            40          None                                   scala-arm
# 203             0          None                                    LinSched
# 204            12          None                             Houdini-Toolbox
# 205             0          None                          oauth2-spring-boot
# 206             4           MIT                                zhihu-spider
# 207            21           MIT                                smoothScroll
# 208             7           MIT                           idiomatic-pre-CSS
# 209           155           MIT                                 wfdb-python
# 210            64           MIT                                rack-tracker
# 211           290           MIT  Office-Online-Test-Tools-and-Documentation
# 212            71           MIT                        ansible-django-stack
# 213            30          None                                      GoPiGo
# 214          1029          None                                   classroom
# 215           161          None                               cors-anywhere
# 216             4          None                                        Hiro
# 217            16          None                                   oauth-clj
# 218           263   NOASSERTION                            jquery-dynatable
# 219           595   NOASSERTION                                   react-360
# 220           249           MIT                               JPVideoPlayer
# 221             7          None                         jakobejitblokaci.cz
# 222            45           MIT                                        bibi
# 223           251   NOASSERTION                                 FlashFloppy
# 224             2          None                           How-to-Use-GitHub
# 225             8          None                             nodemcu-modules
# 226           316       GPL-3.0                            todo.txt-android
# 227             3   NOASSERTION                              CategoriesObjC
# 228             1          None                              product-studio
# 229             4          None                        react-build-tutorial
# ...           ...           ...                                         ...
# 4970          753           MIT                                        ssh2
# 4971            8           MIT                               UzysSlideMenu
# 4972           27           MIT                               save-as-ebook
# 4973           27          None                          JavaScriptCore-iOS
# 4974           13   NOASSERTION                                     letters
# 4975          223           MIT                                    goodwork
# 4976           12   NOASSERTION                                       golex
# 4977          168          None                                 Vlc-sdk-lib
# 4978            1          None                                       agave
# 4979            0       GPL-2.0                                       jake2
# 4980            9  BSD-3-Clause                          colour-demosaicing
# 4981          114       CC0-1.0                          postcss-preset-env
# 4982            9           MIT                                   mentalist
# 4983            0          None                           osx-vhost-manager
# 4984          139          None                                 vim-session
# 4985           32   NOASSERTION                                         nut
# 4986           25           MIT                                  IBAnalyzer
# 4987            0           MIT                                python-astar
# 4988          114       GPL-3.0                                  hackademic
# 4989            3          None                      android-layout-samples
# 4990            0       GPL-3.0                             idamagicstrings
# 4991            4       MPL-2.0                     Cheating-Plugin-Program
# 4992            9          None                               test-synopsis
# 4993            0           MIT                       FacialEmotionAnalysis
# 4994           81   NOASSERTION                  dynamic-panel-transparency
# 4995          180   NOASSERTION                                 scikit-cuda
# 4996            8          None                                 awesome-lua
# 4997          318   NOASSERTION                                       libui
# 4998            6       GPL-3.0                                  dirty_sock
# 4999            1   NOASSERTION                             LPC1114CodeBase
#
#                                           nameWithOwner  \
# 200                                   mageplus/mageplus
# 201                                radenvodka/SVScanner
# 202                                  jsuereth/scala-arm
# 203                                    jontore/LinSched
# 204                        captainhammy/Houdini-Toolbox
# 205                  marcusdacoregio/oauth2-spring-boot
# 206                         MorganZhang100/zhihu-spider
# 207                          alicelieutier/smoothScroll
# 208                          nicothin/idiomatic-pre-CSS
# 209                                 MIT-LCP/wfdb-python
# 210                              railslove/rack-tracker
# 211   microsoft/Office-Online-Test-Tools-and-Documen...
# 212                       jcalazan/ansible-django-stack
# 213                                    DexterInd/GoPiGo
# 214                                 education/classroom
# 215                                Rob--W/cors-anywhere
# 216                                 philiplaureano/Hiro
# 217                                     r0man/oauth-clj
# 218                          alfajango/jquery-dynatable
# 219                                  facebook/react-360
# 220                                newyjp/JPVideoPlayer
# 221                           spaze/jakobejitblokaci.cz
# 222                                   satorumurmur/bibi
# 223                                   keirf/FlashFloppy
# 224                        llSourcell/How-to-Use-GitHub
# 225                         javieryanez/nodemcu-modules
# 226                            todotxt/todo.txt-android
# 227                         jerrykrinock/CategoriesObjC
# 228                          cornelltech/product-studio
# 229                    xieqingtian/react-build-tutorial
# ...                                                 ...
# 4970                                        mscdex/ssh2
# 4971                             uzysjung/UzysSlideMenu
# 4972                             alexadam/save-as-ebook
# 4973                       phoboslab/JavaScriptCore-iOS
# 4974                                 davejacobs/letters
# 4975                                  iluminar/goodwork
# 4976                                        cznic/golex
# 4977                           mengzhidaren/Vlc-sdk-lib
# 4978                                   dharmatech/agave
# 4979                                        mbien/jake2
# 4980                  colour-science/colour-demosaicing
# 4981                        csstools/postcss-preset-env
# 4982                                 sc0tfree/mentalist
# 4983                        jamiemill/osx-vhost-manager
# 4984                                  xolox/vim-session
# 4985                                         AlekSi/nut
# 4986                                 fastred/IBAnalyzer
# 4987                                elemel/python-astar
# 4988                              Hackademic/hackademic
# 4989                      lucasr/android-layout-samples
# 4990                        joxeankoret/idamagicstrings
# 4991                 luguanxing/Cheating-Plugin-Program
# 4992                             miyagawa/test-synopsis
# 4993                  kbsriharsha/FacialEmotionAnalysis
# 4994               rockon999/dynamic-panel-transparency
# 4995                                lebedov/scikit-cuda
# 4996                            LewisJEllis/awesome-lua
# 4997                                      andlabs/libui
# 4998                              initstring/dirty_sock
# 4999                       microbuilder/LPC1114CodeBase
#
#                                                  readMe            owner  \
# 200   Mage+\n========\n\nA community owned and drive...         mageplus
# 201   # SVScanner - Scanner Vulnerability And MaSsiv...       radenvodka
# 202   # Scala Automatic Resource Management\n\n[![Jo...         jsuereth
# 203                                                 NaN          jontore
# 204   This repository is for the Houdini Toolbox.\n\...     captainhammy
# 205   # oauth2-spring-boot\nThis repository has the ...  marcusdacoregio
# 206   # zhihu-spider\nA web spider for zhihu.com, wh...   MorganZhang100
# 207   smoothScroll\n============\n\nA teeny tiny, st...    alicelieutier
# 208                                                 NaN         nicothin
# 209                                                 NaN          MIT-LCP
# 210   # Rack::Tracker\n\n[![Code Climate](https://co...        railslove
# 211   # Office Online Test Tools and Documentation\n...        microsoft
# 212   \nansible-django-stack\n====================\n...         jcalazan
# 213   # GoPiGo\r\n\r\nThe GoPiGo is a delightful and...        DexterInd
# 214   # GitHub Classroom\n[![Build Status](https://t...        education
# 215   [![Build Status](https://travis-ci.org/Rob--W/...           Rob--W
# 216                                                 NaN   philiplaureano
# 217                                                 NaN            r0man
# 218   # jQuery Dynatable\n\n*A funner, semantic, HTM...        alfajango
# 219   # React 360 [![npm version](https://badge.fury...         facebook
# 220   <p align="left" >\n<img src="Images/logo.png" ...           newyjp
# 221   # jakobejitblokaci.cz\nTohle je www.jakobejitb...            spaze
# 222   BiB/i\n=======================================...     satorumurmur
# 223   # FlashFloppy\n\nA retro floppy emulator for t...            keirf
# 224   ## Overview\n\nThese are a list of useful comm...       llSourcell
# 225   nodemcu-modules\n===============\n\nModules fo...      javieryanez
# 226   # Todo.txt for Android [![](https://img.shield...          todotxt
# 227                                                 NaN     jerrykrinock
# 228   # Product Studio (Fall 2019)\n\n# What is the ...      cornelltech
# 229   # build-react-tutorial\n一步一步搭建一个react项目环境\n\n#...      xieqingtian
# ...                                                 ...              ...
# 4970  # Description\n\nSSH2 client and server module...           mscdex
# 4971  UzysSlideMenu\n================\n\nSlide Dropd...         uzysjung
# 4972  # save-as-ebook\n\nSave a web page/selection a...         alexadam
# 4973  ### This Project has been discontinued – Mar. ...        phoboslab
# 4974  **Letters** is a little alphabetical library t...       davejacobs
# 4975                                                NaN         iluminar
# 4976  `github.com/cznic/golex` has moved to [`modern...            cznic
# 4977  ### Vlc-sdk-lib\n\n构建切换大小屏播放器  推荐<br>\n\n  * [...     mengzhidaren
# 4978  # Quick start\n\n## Setup\n\n    $ cd ~/scheme...       dharmatech
# 4979                                                NaN            mbien
# 4980                                                NaN   colour-science
# 4981  # PostCSS Preset Env [<img src="https://postcs...         csstools
# 4982  ![Version 1.0](http://img.shields.io/badge/ver...         sc0tfree
# 4983                                                NaN        jamiemill
# 4984  # Extended session management for Vim\n\nThe v...            xolox
# 4985  nut [![Build Status](https://secure.travis-ci....           AlekSi
# 4986  [![Build Status](https://travis-ci.org/fastred...          fastred
# 4987                                                NaN           elemel
# 4988                                                NaN       Hackademic
# 4989  android-layout-samples\n======================...           lucasr
# 4990  # IDAMagicStrings\n\nAn __[IDA](https://www.he...      joxeankoret
# 4991  # 外挂设计与分析\n\n------\n\n> * 01一个简单的内存外挂\n> * 02...       luguanxing
# 4992  # NAME\n\nTest::Synopsis - Test your SYNOPSIS ...         miyagawa
# 4993  # FacialEmotionAnalysis ![](https://img.shield...      kbsriharsha
# 4994  # Dynamic Panel Transparency\n[![Demo](https:/...        rockon999
# 4995                                                NaN          lebedov
# 4996                                                NaN      LewisJEllis
# 4997  # libui: a portable GUI library for C\n\nThis ...          andlabs
# 4998  # dirty_sock: Linux Privilege Escalation (via ...       initstring
# 4999                                                NaN     microbuilder
#
#        primaryLanguage  totalPullRequests  totalCommits  totalStargazers  \
# 200                PHP                 48         212.0              385
# 201                PHP                  0          31.0              119
# 202              Scala                 40         178.0              521
# 203                  C                  0           4.0               13
# 204             Python                  1         422.0               92
# 205               Java                  0          30.0               49
# 206             Python                  1          11.0              711
# 207               HTML                 31          73.0              517
# 208               HTML                  6           NaN              343
# 209   Jupyter Notebook                 22         592.0              290
# 210               Ruby                 80         323.0              550
# 211                NaN                106         498.0              152
# 212              Shell                 51         174.0             1171
# 213               HTML                293         939.0              307
# 214               Ruby               1312        6577.0             1116
# 215         JavaScript                 34         117.0             2500
# 216                 C#                  3         122.0               57
# 217            Clojure                 15         252.0               85
# 218         JavaScript                 50         170.0             2760
# 219         JavaScript                119         426.0             7497
# 220        Objective-C                 22         470.0             1982
# 221               HTML                 16          45.0               43
# 222         JavaScript                 21         917.0              255
# 223                  C                 11         826.0              360
# 224                NaN                  0           5.0              256
# 225                Lua                  1          36.0               76
# 226               Java                193         494.0             1208
# 227        Objective-C                  1         223.0              270
# 228                NaN                  1          50.0               71
# 229               HTML                  0          45.0              149
# ...                ...                ...           ...              ...
# 4970        JavaScript                 66         864.0             3656
# 4971       Objective-C                  1          21.0              527
# 4972        JavaScript                  6         163.0              880
# 4973               C++                 10          92.0              584
# 4974              Ruby                  8          89.0              276
# 4975               PHP                379         672.0              655
# 4976                Go                  2          78.0              173
# 4977                 C                  0         109.0              360
# 4978            Scheme                  2         105.0               14
# 4979              Java                  0         640.0               23
# 4980  Jupyter Notebook                  3         137.0               63
# 4981               CSS                 35          75.0             1317
# 4982            Python                  4           6.0              556
# 4983              Ruby                  2           7.0               17
# 4984        Vim script                 41         224.0              827
# 4985                Go                  5         119.0               52
# 4986             Swift                 13          50.0              948
# 4987            Python                  1           3.0               36
# 4988               PHP                127          11.0              246
# 4989              Java                  3          42.0              798
# 4990            Python                  4          28.0              174
# 4991               C++                  0          55.0              611
# 4992              Perl                 12          84.0               10
# 4993            Python                  0          23.0                6
# 4994        JavaScript                 19         309.0              148
# 4995            Python                104         994.0              693
# 4996               NaN                 64         106.0             2121
# 4997                 C                153        3944.0             8906
# 4998            Python                  0          15.0              475
# 4999                 C                  0          64.0               54
#
#                      updatedAt
# 200  2019-08-13 15:02:06+00:00
# 201  2019-09-09 11:20:27+00:00
# 202  2019-09-05 09:32:23+00:00
# 203  2019-03-23 23:20:12+00:00
# 204  2019-09-09 15:09:56+00:00
# 205  2019-09-04 12:01:40+00:00
# 206  2019-09-07 08:19:02+00:00
# 207  2019-08-13 15:17:09+00:00
# 208  2019-09-06 20:03:42+00:00
# 209  2019-09-07 18:08:56+00:00
# 210  2019-08-29 01:48:08+00:00
# 211  2019-08-19 08:54:37+00:00
# 212  2019-09-09 18:48:21+00:00
# 213  2019-08-28 15:27:50+00:00
# 214  2019-09-09 20:12:09+00:00
# 215  2019-09-09 20:40:11+00:00
# 216  2019-07-26 15:54:26+00:00
# 217  2019-08-13 14:55:45+00:00
# 218  2019-09-09 11:47:15+00:00
# 219  2019-09-09 14:04:48+00:00
# 220  2019-09-06 03:19:49+00:00
# 221  2019-06-07 09:00:12+00:00
# 222  2019-08-31 10:47:28+00:00
# 223  2019-09-09 14:33:04+00:00
# 224  2019-08-28 14:53:46+00:00
# 225  2019-05-07 11:27:25+00:00
# 226  2019-09-09 14:18:37+00:00
# 227  2019-07-12 01:08:28+00:00
# 228  2019-09-04 18:47:09+00:00
# 229  2019-09-04 05:46:15+00:00
# ...                        ...
# 4970 2019-09-09 02:29:01+00:00
# 4971 2019-08-13 15:24:31+00:00
# 4972 2019-09-05 12:24:45+00:00
# 4973 2019-08-21 09:50:54+00:00
# 4974 2019-08-18 09:37:18+00:00
# 4975 2019-09-08 18:03:02+00:00
# 4976 2019-07-15 21:57:54+00:00
# 4977 2019-09-06 03:00:40+00:00
# 4978 2019-07-31 05:23:04+00:00
# 4979 2019-02-03 21:21:14+00:00
# 4980 2019-08-31 23:40:28+00:00
# 4981 2019-09-09 21:04:16+00:00
# 4982 2019-09-09 20:29:09+00:00
# 4983 2019-07-01 09:47:04+00:00
# 4984 2019-08-23 14:55:38+00:00
# 4985 2019-08-13 15:06:35+00:00
# 4986 2019-09-06 22:48:30+00:00
# 4987 2019-08-18 11:19:04+00:00
# 4988 2019-09-05 08:46:06+00:00
# 4989 2019-08-28 07:52:22+00:00
# 4990 2019-08-19 19:06:33+00:00
# 4991 2019-09-06 07:17:16+00:00
# 4992 2019-08-13 14:03:30+00:00
# 4993 2019-08-12 13:11:46+00:00
# 4994 2019-08-31 15:04:34+00:00
# 4995 2019-09-09 15:45:28+00:00
# 4996 2019-09-09 21:02:00+00:00
# 4997 2019-09-09 22:44:53+00:00
# 4998 2019-09-09 09:42:27+00:00
# 4999 2019-03-24 20:46:32+00:00
#
# [4800 rows x 17 columns]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # `Pull Requests`

# %% [markdown]
# ## Query x2

# %%
# Initial query
pr_query = '''
{{
  repositoryOwner(login: "{owner}") {{
    repository(name: "{name}") {{
      pullRequests(first: 50) {{
        pageInfo {{
          endCursor
          hasNextPage
        }}
        nodes {{
          createdAt
          updatedAt
          closedAt
          title
          mergedBy {{
            login
          }}
          author {{
            login
            ... on User {{
              company
            }}
          }}
          authorAssociation
          files {{
            totalCount
          }}
          state
          resourcePath
          bodyText
          comments(first: 25) {{
            totalCount
            nodes {{
              author {{
                login
                ... on User {{
                  company
                }}
              }}
              authorAssociation
              bodyText
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

# Subsequent queries
pr_query_2 = '''
{{
  repositoryOwner(login: "{owner}") {{
    repository(name: "{name}") {{
      pullRequests(first: 50, after:"{end_cursor}") {{
        pageInfo {{
          endCursor
          hasNextPage
        }}
        nodes {{
          createdAt
          updatedAt
          closedAt
          title
          mergedBy {{
            login
          }}
          author {{
            login
            ... on User {{
              company
            }}
          }}
          authorAssociation
          files {{
            totalCount
          }}
          state
          resourcePath
          bodyText
          comments(first: 25) {{
            totalCount
            nodes {{
              author {{
                login
                ... on User {{
                  company
                }}
              }}
              authorAssociation
              bodyText
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

pr_variables = {
    "end_cursor": "",
    "owner":"",
    "name":""
}

# %% [markdown]
# ## Functions to query pr

# %%
def pr_to_df(result):
    
    # Get the keys of nodes.
    data = result['data']['repositoryOwner']['repository']['pullRequests']['nodes']
    
    # Put the data into a dataframe
    df_pr = pd.DataFrame(data)
    
    return df_pr

def pr_get_page_info(result):
    cur = result['data']['repositoryOwner']['repository']['pullRequests']['pageInfo']['endCursor']
    has_cur = result['data']['repositoryOwner']['repository']['pullRequests']['pageInfo']['hasNextPage']
    return cur, has_cur

def pr_result_query(query):
    # Run first query
    result = run_query(query)

    # Save to DF
    df_pr = pr_to_df(result)

    # Get end cursor and has cursor
    pr_variables['end_cursor'], has_cursor = pr_get_page_info(result)

    # Limit
    limit = result['data']['rateLimit']['remaining']
    
    return df_pr, has_cursor, limit

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # `Issues`

# %% [markdown]
# ## Query x2

# %%
is_query = '''
{{
  repositoryOwner(login:"{owner}") {{
    repository(name:"{name}") {{
      issues(first:50) {{
        pageInfo {{
          endCursor
          hasNextPage
        }}
        nodes {{
          createdAt
          closedAt
          updatedAt
          title
          number
          author {{
            login
            ... on User {{
              company
            }}
          }}
          authorAssociation
          state
          bodyText
          comments(first:20) {{
            totalCount
            nodes {{
              author {{
                login
                ... on User {{
                  company
                }}
              }}
              createdAt
              authorAssociation
              bodyText
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

is_query_2 = '''
{{
  repositoryOwner(login:"{owner}") {{
    repository(name:"{name}") {{
      issues(first:50, after:"{end_cursor}") {{
        pageInfo {{
          endCursor
          hasNextPage
        }}
        nodes {{
          createdAt
          closedAt
          updatedAt
          title
          number
          author {{
            login
            ... on User {{
              company
            }}
          }}
          authorAssociation
          state
          bodyText
          comments(first:20) {{
            totalCount
            nodes {{
              author {{
                login
                ... on User {{
                  company
                }}
              }}
              createdAt
              authorAssociation
              bodyText
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

is_variables = {
    "end_cursor": "",
    "owner":"",
    "name":""
}

# %% [markdown]
# ## Function to query issues

# %%
def is_to_df(result):
    
    # Get the keys of nodes.
    data = result['data']['repositoryOwner']['repository']['issues']['nodes']
    
    # Put the data into a dataframe
    df_is = pd.DataFrame(data)
    
    return df_is

def is_get_page_info(result):
    cur = result['data']['repositoryOwner']['repository']['issues']['pageInfo']['endCursor']
    has_cur = result['data']['repositoryOwner']['repository']['issues']['pageInfo']['hasNextPage']
    return cur, has_cur

def is_result_query(query):
    # Run first query
    result = run_query(query)

    # Save to DF
    df_is = is_to_df(result)

    # Get end cursor and has cursor
    is_variables['end_cursor'], has_cursor = is_get_page_info(result)

    # Limit
    limit = result['data']['rateLimit']['remaining']
    
    return df_is, has_cursor, limit

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # `Commits`

# %% [markdown]
# ## Query x2

# %%
cm_query = '''
{{
  repository(owner: "{owner}", name: "{name}") {{
    ref(qualifiedName: "master") {{
      target {{
        ... on Commit {{
          history(first: 100) {{
            pageInfo {{
              hasNextPage
              endCursor
            }}
            nodes {{
              oid
              messageHeadline
              committedDate
              committer {{
                user {{
                  login
                  company
                }}
              }}
              status {{
                id
                state
              }}
              associatedPullRequests(first: 3) {{
                nodes {{
                  id
                  title
                  author {{
                    login
                  }}
                  authorAssociation
                  createdAt
                  updatedAt
                  closedAt
                  number
                  state
                }}
              }}
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

cm_query_2 = '''
{{
  repository(owner: "{owner}", name: "{name}") {{
    ref(qualifiedName: "master") {{
      target {{
        ... on Commit {{
          history(first: 100, after:"{end_cursor}") {{
            pageInfo {{
              hasNextPage
              endCursor
            }}
            nodes {{
              oid
              messageHeadline
              committedDate
              committer {{
                user {{
                  login
                  company
                }}
              }}
              status {{
                id
                state
              }}
              associatedPullRequests(first: 3) {{
                nodes {{
                  id
                  title
                  author {{
                    login
                  }}
                  authorAssociation
                  createdAt
                  updatedAt
                  closedAt
                  number
                  state
                }}
              }}
            }}
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

cm_variables = {
    "end_cursor": "",
    "owner":"",
    "name":""
}

# %% [markdown]
# ## Functions for Commits

# %%
def cm_to_df(result):
    
    # Get the keys of nodes.
    data = result['data']['repository']['ref']['target']['history']['nodes']
    
    # Put the data into a dataframe
    df_commits = pd.DataFrame(data)
    
    return df_commits

def cm_get_page_info(result):
    cur = result['data']['repository']['ref']['target']['history']['pageInfo']['endCursor']
    has_cur = result['data']['repository']['ref']['target']['history']['pageInfo']['hasNextPage']
    return cur, has_cur

def cm_result_query(query):
    # Run first query
    result = run_query(query)

    # Save to DF
    df_commits = cm_to_df(result)

    # Get end cursor and has cursor
    cm_variables['end_cursor'], has_cursor = cm_get_page_info(result)

    # Limit
    limit = result['data']['rateLimit']['remaining']
    
    return df_commits, has_cursor, limit

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # `Stargazers`

# %% [markdown]
# ## Query x2

# %%
# Query star gazers
st_query = '''
{{
  repositoryOwner(login: "{owner}") {{
    id
    login
    repository(name: "{name}") {{
      id
      name
      createdAt
      updatedAt
      description
      licenseInfo {{
        spdxId
      }}
      stargazers(first:100) {{
        totalCount
        pageInfo {{
          endCursor
          hasNextPage
        }}
        edges {{
          starredAt
          node {{
            createdAt
            updatedAt
            id
            login
            company
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

st_query_2 = '''
{{
  repositoryOwner(login: "{owner}") {{
    id
    login
    repository(name: "{name}") {{
      id
      name
      createdAt
      updatedAt
      description
      licenseInfo {{
        spdxId
      }}
      stargazers(first:100, after:"{end_cursor}") {{
        totalCount
        pageInfo {{
          endCursor
          hasNextPage
        }}
        edges {{
          starredAt
          node {{
            createdAt
            updatedAt
            id
            login
            company
          }}
        }}
      }}
    }}
  }}
  rateLimit {{
    limit
    cost
    remaining
    resetAt
  }}
}}
'''

st_variables = {
    "end_cursor": "",
    "owner":"",
    "name":""
}

# %% [markdown]
# ## Functions for stargazers

# %%
def st_to_df(result):
    
    # Get the keys of nodes.
    data = result['data']['repositoryOwner']['repository']['stargazers']['edges']
    
    # Put the data into a dataframe
    df_star = pd.DataFrame(data)
    
    return df_star

def st_get_page_info(result):
    cur = result['data']['repositoryOwner']['repository']['stargazers']['pageInfo']['endCursor']
    has_cur = result['data']['repositoryOwner']['repository']['stargazers']['pageInfo']['hasNextPage']
    return cur, has_cur

def st_result_query(query):
    # Run first query
    result = run_query(query)

    # Save to DF
    df_star = st_to_df(result)

    # Get end cursor and has cursor
    st_variables['end_cursor'], has_cursor = st_get_page_info(result)

    # Limit
    limit = result['data']['rateLimit']['remaining']
    
    return df_star, has_cursor, limit

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # `Run Queries`

# %%
import time

# %% [markdown]
# ## Set index from the random repos

# %%
i = 200

# %% [markdown]
# ## Make new Folder to store the repo data

# %%
import os

try:
    os.mkdir('../../../Files/more_repos2/' + df['owner'][i] + '-' + df['name'][i])
    print('Made Folder')
except:
    print('Folder exists')
# Out:
# Made Folder

# %% [markdown]
# ## Run PR Query

# %%
def pr_loop(df_pr, has_cursor_pr,limit):
        # Run While Loop below
        while has_cursor_pr and (limit >= 0):

            # Run next queries
            df_pr_2, has_cursor_pr, limit = pr_result_query(pr_query_2.format(**pr_variables))

            # Concat to existing df_star
            df_pr = pd.concat([df_pr, df_pr_2])

            # Print limit and cursor
            print('Next limit is: ', limit)
            print('Next cursor: ', has_cursor_pr, '\n')
            print('Shape:', df_pr.shape)
            
        else:
            
            df_pr.to_pickle('../../../Files/more_repos2/pr/' + pr_variables['owner'] + '-' + pr_variables['name'] + '/' + pr_variables['owner'] 
                + '_' + pr_variables['name'] + '_pr' + '.pk1')


def pr_looper(df_pr, has_cursor_pr,limit):
    try:
        print('try_loop')
        pr_loop(df_pr, has_cursor_pr,limit)
    except Exception as e:
        print(e)
        print('except_loop')
        time.sleep(60)
        pr_looper(df_pr, has_cursor_pr,limit)

# %%
# %%time

for i in range(200, 1000):
    
    try:
        os.mkdir('../../../Files/more_repos2/pr/' + df['owner'][i] + '-' + df['name'][i])
        print('Made Folder')
    except:
        print('Folder exists')
        
    # Set owner and name for pr_variables by changing the index
    pr_variables['owner'] = df['owner'][i]
    pr_variables['name'] = df['name'][i]

    ##### Comment Out this section if there's a error #####
    # Run first query
    df_pr, has_cursor_pr, limit = pr_result_query(pr_query.format(**pr_variables))

    print('Starting limit is: ', limit)
    print('Start cursor: ', has_cursor_pr, '\n')

    ##### Comment Out this section if there's a error #####

    pr_looper(df_pr, has_cursor_pr,limit)
# Out:
# Made Folder
# Starting limit is:  4961
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4960
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4959
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4958
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4957
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4956
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4955
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4954
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4953
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4952
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4951
# Start cursor:  True
#
# try_loop
# Next limit is:  4950
# Next cursor:  False
#
# Shape: (80, 12)
# Made Folder
# Starting limit is:  4949
# Start cursor:  True
#
# try_loop
# Next limit is:  4948
# Next cursor:  True
#
# Shape: (100, 12)
# Next limit is:  4947
# Next cursor:  False
#
# Shape: (106, 12)
# Made Folder
# Starting limit is:  4946
# Start cursor:  True
#
# try_loop
# Next limit is:  4945
# Next cursor:  False
#
# Shape: (51, 12)
# Made Folder
# Starting limit is:  4944
# Start cursor:  True
#
# try_loop
# Next limit is:  4943
# Next cursor:  True
#
# Shape: (100, 12)
# Next limit is:  4942
# Next cursor:  True
#
# Shape: (150, 12)
# Next limit is:  4941
# Next cursor:  True
#
# Shape: (200, 12)
# Next limit is:  4940
# Next cursor:  True
#
# Shape: (250, 12)
# Next limit is:  4939
# Next cursor:  False
#
# Shape: (293, 12)
# Made Folder
# Starting limit is:  4938
# Start cursor:  True
#
# try_loop
# Next limit is:  4937
# Next cursor:  True
#
# Shape: (100, 12)
# Next limit is:  4936
# Next cursor:  True
#
# Shape: (150, 12)
# Next limit is:  4935
# Next cursor:  True
#
# Shape: (200, 12)
# Next limit is:  4934
# Next cursor:  True
#
# Shape: (250, 12)
# Next limit is:  4933
# Next cursor:  True
#
# Shape: (300, 12)
# Next limit is:  4932
# Next cursor:  True
#
# Shape: (350, 12)
# Next limit is:  4931
# Next cursor:  True
#
# Shape: (400, 12)
# Next limit is:  4930
# Next cursor:  True
#
# Shape: (450, 12)
# Next limit is:  4929
# Next cursor:  True
#
# Shape: (500, 12)
# Next limit is:  4928
# Next cursor:  True
#
# Shape: (550, 12)
# Next limit is:  4927
# Next cursor:  True
#
# Shape: (600, 12)
# Next limit is:  4926
# Next cursor:  True
#
# Shape: (650, 12)
# Next limit is:  4925
# Next cursor:  True
#
# Shape: (700, 12)
# Next limit is:  4924
# Next cursor:  True
#
# Shape: (750, 12)
# Next limit is:  4923
# Next cursor:  True
#
# Shape: (800, 12)
# Next limit is:  4922
# Next cursor:  True
#
# Shape: (850, 12)
# Next limit is:  4921
# Next cursor:  True
#
# Shape: (900, 12)
# Next limit is:  4920
# Next cursor:  True
#
# Shape: (950, 12)
# Next limit is:  4919
# Next cursor:  True
#
# Shape: (1000, 12)
# Next limit is:  4918
# Next cursor:  True
#
# Shape: (1050, 12)
# Next limit is:  4917
# Next cursor:  True
#
# Shape: (1100, 12)
# Next limit is:  4916
# Next cursor:  True
#
# Shape: (1150, 12)
# Next limit is:  4915
# Next cursor:  True
#
# Shape: (1200, 12)
# Next limit is:  4914
# Next cursor:  True
#
# Shape: (1250, 12)
# Next limit is:  4913
# Next cursor:  True
#
# Shape: (1300, 12)
# Next limit is:  4912
# Next cursor:  False
#
# Shape: (1323, 12)
# Made Folder
# Starting limit is:  4911
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4910
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4909
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4908
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4907
# Start cursor:  True
#
# try_loop
# Next limit is:  4906
# Next cursor:  True
#
# Shape: (100, 12)
# Next limit is:  4905
# Next cursor:  False
#
# Shape: (119, 12)
# Made Folder
# Starting limit is:  4904
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4903
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4902
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4901
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4900
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4899
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4898
# Start cursor:  True
#
# try_loop
# Next limit is:  4897
# Next cursor:  True
#
# Shape: (100, 12)
# Next limit is:  4896
# Next cursor:  True
#
# Shape: (150, 12)
# Next limit is:  4895
# Next cursor:  False
#
# Shape: (193, 12)
# Made Folder
# Starting limit is:  4894
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4893
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4892
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4891
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4890
# Start cursor:  False
#
# try_loop
# Made Folder
# Starting limit is:  4889
# Start cursor:  True
#
# try_loop
# Next limit is:  4888
# Next cursor:  False
#
# Shape: (71, 12)
# Made Folder
# Starting limit is:  4887
# Start cursor:  True
#
# try_loop
# Next limit is:  4886
# Next cursor:  True
#
# Shape: (100, 12)
# Next limit is:  4885
# Next cursor:  True
#
# Shape: (150, 12)

# %% [markdown]
# # Old Pr query

# %%
# %%time

i=210

try:
    os.mkdir('../../../Files/more_repos2/pr' + df['owner'][i] + '-' + df['name'][i])
    print('Made Folder')
except:
    print('Folder exists')

# Set owner and name for pr_variables by changing the index
pr_variables['owner'] = df['owner'][i]
pr_variables['name'] = df['name'][i]

##### Comment Out this section if there's a error #####
# Run first query
df_pr, has_cursor_pr, limit = pr_result_query(pr_query.format(**pr_variables))

print('Starting limit is: ', limit)
print('Start cursor: ', has_cursor_pr, '\n')

##### Comment Out this section if there's a error #####

while has_cursor_pr and (limit >= 0):

    # Run next queries
    df_pr_2, has_cursor_pr, limit = pr_result_query(pr_query_2.format(**pr_variables))

    # Concat to existing df_star
    df_pr = pd.concat([df_pr, df_pr_2])

    # Print limit and cursor
    print('Next limit is: ', limit)
    print('Next cursor: ', has_cursor_pr, '\n')
    print('Shape:', df_pr.shape)
# Out:
# Made Folder
# Starting limit is:  4977
# Start cursor:  True
#
# Next limit is:  4976
# Next cursor:  False
#
# Shape: (80, 12)
# Wall time: 8.79 s

# %% [markdown]
# ### Save PR as a pickle file

# %%
df_pr.to_pickle('../../../Files/more_repos2/' + pr_variables['owner'] + '-' + pr_variables['name'] + '/' + pr_variables['owner'] 
                + '_' + pr_variables['name'] + '_pr' + '.pk1')

# %% [markdown]
# ---

# %% [markdown]
# ## Run Issues Query

# %%
# %%time

# # Set owner and name for pr_variables by changing the index
# is_variables['owner'] = df['owner'][i]
# is_variables['name'] = df['name'][i]

# ##### Comment Out this section if there's a error #####
# # Run first query
# df_is, has_cursor_is, limit = is_result_query(is_query.format(**is_variables))

# print('Starting limit is: ', limit)
# print('Start cursor: ', has_cursor_is, '\n')

# ##### Comment Out this section if there's a error #####

# # Run While Loop below
# while has_cursor_is and (limit >= 0):
    
#     # Run next queries
#     df_is_2, has_cursor_is, limit = is_result_query(is_query_2.format(**is_variables))

#     # Concat to existing df_star
#     df_is = pd.concat([df_is, df_is_2])
    
#     # Print limit and cursor
#     print('Next limit is: ', limit)
#     print('Next cursor: ', has_cursor_is, '\n')
# Out:
# Starting limit is:  4553
# Start cursor:  False
#
# Wall time: 1.27 s

# %% [markdown]
# ### Save Issues as a pickle file

# %%
# df_is.to_pickle('../../../Files/more_repos/' + is_variables['owner'] + '-' + is_variables['name'] + '/' + is_variables['owner'] 
#                 + '_' + is_variables['name'] + '_is' + '.pk1')

# %% [markdown]
# ---

# %% [markdown]
# ## Run Commits Query

# %%
# %%time

# # Set index
# cm_variables['owner'] = df['owner'][i]
# cm_variables['name'] = df['name'][i]

# ##### Comment Out this section if there's an error #####

# # Run first query
# df_commits, has_cursor_cm, limit = cm_result_query(cm_query.format(**cm_variables))

# print('Starting limit is: ', limit)
# print('Start cursor: ', has_cursor_cm, '\n')

# ##### Comment Out this section if there's an error #####

# # Run While Loop below
# while has_cursor_cm and (limit >= 0):
    
#     # Run next queries
#     df_commits_2, has_cursor_cm, limit = cm_result_query(cm_query_2.format(**cm_variables))

#     # Concat to existing df_star
#     df_commits = pd.concat([df_commits, df_commits_2])
    
#     # Print limit and cursor
#     print('Next limit is: ', limit)
#     print('Next cursor: ', has_cursor_cm, '\n')
# Out:
# Starting limit is:  4552
# Start cursor:  False
#
# Wall time: 1.62 s

# %%
# Test if query exists
# run_query(cm_query.format(**cm_variables))

# %% [markdown]
# ### Save Commits as a pickle file

# %%
# df_commits.to_pickle('../../../Files/more_repos/' + cm_variables['owner'] + '-' + cm_variables['name'] + '/' + cm_variables['owner'] 
#                 + '_' + cm_variables['name'] + '_cm' + '.pk1')

# %% [markdown]
# ---

# %% [markdown]
# ## Run Stargazer Query

# %%
# %%time

# # Set index
# st_variables['owner'] = df['owner'][i]
# st_variables['name'] = df['name'][i]

# ##### Comment Out this section if there's an error #####

# # Run first query
# df_star, has_cursor_st, limit = st_result_query(st_query.format(**st_variables))

# print('Starting limit is: ', limit)
# print('Start cursor: ', has_cursor_st, '\n')

# ##### Comment Out this section if there's an error #####

# # Run While Loop below
# while has_cursor_st and (limit >= 0):
    
#     # Run next queries
#     df_star_2, has_cursor_st, limit = st_result_query(st_query_2.format(**st_variables))

#     # Concat to existing df_star
#     df_star = pd.concat([df_star, df_star_2])
    
#     # Print limit and cursor
#     print('Next limit is: ', limit)
#     print('Next cursor: ', has_cursor_st, '\n')
# Out:
# Starting limit is:  4551
# Start cursor:  True
#
# Next limit is:  4550
# Next cursor:  True
#
# Next limit is:  4549
# Next cursor:  True
#
# Next limit is:  4548
# Next cursor:  True
#
# Next limit is:  4547
# Next cursor:  False
#
# Wall time: 2.66 s

# %% [markdown]
# ### Save stargazers to pickle

# %%
# df_star.to_pickle('../../../Files/more_repos/' + st_variables['owner'] + '-' + st_variables['name'] + '/' + st_variables['owner'] 
#                 + '_' + st_variables['name'] + '_st' + '.pk1')

# %% [markdown]
# ---
