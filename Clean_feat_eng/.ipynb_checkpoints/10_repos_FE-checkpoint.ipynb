# %%
import pandas as pd
import numpy as np 
import requests
import os
import zipfile

# %%
def month_count(dframe, column, return_column=None):
    '''This function will return a grupby object with the counts for all columns per month'''
    
    month_gb = dframe.groupby(dframe[column].dt.to_period("M")).count()
    
    if (return_column==None):
        return [month_gb[column]]
    else:
        return [month_gb[return_column]]

# %%
def association(df):
    '''This function will return a Pandas DataFrame within a list, of the association distribution for each month'''
    
    pr_count_month_mem = df[df['authorAssociation']=='MEMBER'].groupby(df.createdAt.dt.to_period('M'))
    pr_count_month_con = df[df['authorAssociation']=='CONTRIBUTOR'].groupby(df.createdAt.dt.to_period("M"))
    pr_count_month_non = df[df['authorAssociation']=='NONE'].groupby(df.createdAt.dt.to_period("M"))
    pr_count_month_own = df[df['authorAssociation']=='OWNER'].groupby(df.createdAt.dt.to_period("M"))
    
    total = month_count(df, 'createdAt')[0]
    
    unique = df.authorAssociation.unique()
    templist = []
    
    for i in unique:
#         print('loop')
        templist.append(switch(i, pr_count_month_mem, pr_count_month_con, pr_count_month_non, pr_count_month_own, total, unique)) 
    
    assoc_dist = pd.DataFrame(templist).T
    assoc_dist['v_count'] = pd.Series()
    assoc_dist = assoc_dist.fillna(0)
    print(assoc_dist.columns)
    
    for i in assoc_dist.columns[:-1]:
#         print('loop')
        assoc_dist['v_count'] += assoc_dist[i]
    
#     print(assoc_dist['v_count'])
#     assoc_dist['v_count'] = assoc_dist[0]+assoc_dist[1]+assoc_dist[2]
    
    index = assoc_dist.index.to_list()
    v_count = assoc_dist.v_count
    index_for_df = assoc_dist.index.levels[0][:]
    
    temp = pd.DataFrame({'CONTRIBUTOR':None, 'MEMBER':None, 'NONE':None, 'OWNER':None},index=index_for_df)
    
    for i in index:
        timestamp = i[0].strftime('%Y-%m')
        assoc = i[1]
        count = v_count[timestamp][assoc]
        if (assoc=='CONTRIBUTOR'):
            temp.loc[timestamp, assoc] = count
        if (assoc=='MEMBER'):
            temp.loc[timestamp, assoc] = count
        if (assoc=='NONE'):
            temp.loc[timestamp, assoc] = count
        if (assoc=='OWNER'):
            temp.loc[timestamp, assoc] = count
    temp = temp.fillna(0)
        
    return [temp]

# %%
def switch(i, mem, con, non, own, tot, uni): 
    pr_count_month_mem = mem
    pr_count_month_non = non
    pr_count_month_con = con
    pr_count_month_own = own
    total = tot
    unique = uni
    
    switcher={
            'NONE': [pr_count_month_non.authorAssociation.value_counts()/total if ('NONE' in unique) else np.nan][0], 
            'MEMBER': [pr_count_month_mem.authorAssociation.value_counts()/total if ('MEMBER' in unique) else np.nan][0],
            'CONTRIBUTOR': [pr_count_month_con.authorAssociation.value_counts()/total if ('CONTRIBUTOR' in unique) else np.nan][0],
            'OWNER': [pr_count_month_own.authorAssociation.value_counts()/total if ('OWNER' in unique) else np.nan][0]
         }
    return switcher.get(i,"Invalid")

# %%
def duration(df, duration_column):
    '''This function will return a list of a series with the avg duration per month'''
    df['duration'] = df['closedAt'] - df['createdAt']
    duration = df[duration_column].apply(lambda x: x.total_seconds()).groupby(df.createdAt.dt.to_period('M'))
    avg_duration = duration.mean().apply(lambda x: pd.to_timedelta(x, unit='s'))
    return [avg_duration]

# %%
def repo_count_filler(file_list, column_name, repo_df, return_column=None):
    '''File list must be a list of pickles, column name will create a new column where the data will be loaded to
       return column will return a different column within the groupby count df'''
    
    repo_df[column_name] = None
    for f in file_list:
        name = f.split('_', 1)[0]
        index = repo_df[repo_df['owner'].apply(lambda x: x.find(name))==0].index
        if (len(index)==0):
            continue
        else:
            index = index[0]
            repo_df.at[index, column_name] = month_count(pd.read_pickle('../data/10_repos/{}'.format(f)),'createdAt', return_column)
#             print(name)

# %%
def repo_duration_filler(file_list, column_name, repo_df):
    '''File list must be a list of pickles, column name will create a new column where the data will be loaded to
       return column will return a different column within the groupby count df'''
    
    repo_df[column_name] = None
    for f in file_list:
        name = f.split('_', 1)[0]
        index = repo_df[repo_df['owner'].apply(lambda x: x.find(name))==0].index
        if (len(index)==0):
            continue
        else:
            index = index[0]
            repo_df.at[index, column_name] = duration(pd.read_pickle('../data/10_repos/{}'.format(f)), 'duration')
#             print(name)

# %%
def repo_assoc_filler(file_list, column_name, repo_df):
    '''File list must be a list of pickles, column name will create a new column where the data will be loaded to'''
    
    repo_df[column_name] = None
    for f in file_list:
        name = f.split('_', 1)[0]
        index = repo_df[repo_df['owner'].apply(lambda x: x.find(name))==0].index
        if (len(index)==0):
            continue
        else:
            df = pd.read_pickle('../data/10_repos/{}'.format(f))
            df = df.reset_index().drop(columns='index')
            index = index[0]
#             print(index, column_name)
            repo_df.at[index, column_name] = association(df)

# %%
ten_repo.at[0, 'owner']
# Out:
# 'adamsmith'

# %% [markdown]
# ### Un-Zip repos and send them to a different dir

# %%
# extract all info on each repo
# Only run once! EVER!
path_to_zip_file = ['../../data-science/Data/10_cleaned_PRs.zip',
                    '../../data-science/Data/10_cleaned_commits.zip',
                    '../../data-science/Data/10_cleaned_issues.zip',
                    '../../data-science/Data/10_cleaned_stars.zip']
directory_to_extract_to = '../data/10_repos'

# unZip files and put them in a folder
for path in path_to_zip_file:
    with zipfile.ZipFile(path, 'r') as zip_ref:
        zip_ref.extractall(directory_to_extract_to)

# %%
path = '../data/10_repos'
pr_files = [file for file in os.listdir(path) if 'pr_cleaned.pk1' in file]
is_files = [file for file in os.listdir(path) if 'issues_cleaned.pk1' in file]
com_files = [file for file in os.listdir(path) if 'commits_cleaned.pk1' in file]
star_files = [file for file in os.listdir(path) if 'stars_cleaned.pk1' in file]

# %%
pr_files, is_files, com_files, star_files
# Out:
# (['google_pr_cleaned.pk1',
#   'guillaume_pr_cleaned.pk1',
#   'pandas_pr_cleaned.pk1',
#   'oleiade_pr_cleaned.pk1',
#   'adamsmith_pr_cleaned.pk1',
#   'yang_pr_cleaned.pk1',
#   'embulk_pr_cleaned.pk1',
#   'iven_pr_cleaned.pk1'],
#  ['microsoft_issues_cleaned.pk1',
#   'google_issues_cleaned.pk1',
#   'iven_issues_cleaned.pk1',
#   'pandas_issues_cleaned.pk1',
#   'oleiade_issues_cleaned.pk1',
#   'embulk_issues_cleaned.pk1',
#   'yang_issues_cleaned.pk1',
#   'zhn_issues_cleaned.pk1'],
#  ['guillaume_commits_cleaned.pk1',
#   'microsoft_commits_cleaned.pk1',
#   'embulk_commits_cleaned.pk1',
#   'zhn_commits_cleaned.pk1',
#   'iven_commits_cleaned.pk1',
#   'google_commits_cleaned.pk1',
#   'adamsmith_commits_cleaned.pk1',
#   'pandas_commits_cleaned.pk1',
#   'oleiade_commits_cleaned.pk1',
#   'yang_commits_cleaned.pk1'],
#  ['google_stars_cleaned.pk1',
#   'oleiade_stars_cleaned.pk1',
#   'embulk_stars_cleaned.pk1',
#   'yang_stars_cleaned.pk1',
#   'zhn_stars_cleaned.pk1',
#   'iven_stars_cleaned.pk1',
#   'microsoft_stars_cleaned.pk1',
#   'guillaume_stars_cleaned.pk1',
#   'pandas_stars_cleaned.pk1',
#   'adamsmith_stars_cleaned.pk1'])

# %% [markdown]
# -------
# ## Add the new features for each repo

# %%
ten_repo = pd.read_pickle('../pickles/df_repo_10.pk1')
ten_repo.head(10)
# Out:
#                   createdAt  \
# 0 2013-01-19 02:21:47+00:00
# 1 2014-04-01 22:40:40+00:00
# 2 2014-07-17 04:50:32+00:00
# 3 2017-03-21 11:05:58+00:00
# 4 2012-09-14 14:19:46+00:00
# 5 2013-08-14 10:22:25+00:00
# 6 2014-09-16 03:58:52+00:00
# 7 2018-01-28 08:18:24+00:00
# 8 2016-04-27 23:40:22+00:00
#
#                                          description  totalForks  \
# 0    A game-theoretic poker player (written in 2005)          30
# 1                    The Google I/O 2019 Android App        5931
# 2  SEX IS ZERO (0), so, who wanna be the ONE (1),...        1959
# 3                  在线地址: http://www.jobinfo.cc:8000/          91
# 4    Using Spring from within a Play 2.0 application          24
# 5               File based encrypted key-value store          46
# 6                Embulk: Pluggable Bulk Data Loader.         166
# 7  🌕 🌖 🌗 🌘 🌑 🌒 🌓 🌔Imitate Cosmos - a special thir...          72
# 8  C++ library and programs that demonstrate mesh...         103
#
#    hasIssuesEnabled  hasWikiEnabled                                id  \
# 0              True            True      MDEwOlJlcG9zaXRvcnk3Njk4MTkx
# 1              True           False  MDEwOlJlcG9zaXRvcnkxODM0NzQ3Ng==
# 2              True            True  MDEwOlJlcG9zaXRvcnkyMTkyOTAyOQ==
# 3              True            True  MDEwOlJlcG9zaXRvcnk4NTY5MjA1Mg==
# 4             False           False      MDEwOlJlcG9zaXRvcnk1ODEwMjM4
# 5              True            True  MDEwOlJlcG9zaXRvcnkxMjEwNjE5Mg==
# 6              True           False  MDEwOlJlcG9zaXRvcnkyNDA4NDczMA==
# 7              True            True  MDEwOlJlcG9zaXRvcnkxMTkyNDA0NTM=
# 8              True            True  MDEwOlJlcG9zaXRvcnk1NzI1NTk3Mg==
#
#    totalIssues  licenseInfo                     name  \
# 0            0         None        game-theory-poker
# 1          192  NOASSERTION                  iosched
# 2           76      GPL-2.0                 hardseed
# 3            8          MIT                webspider
# 4            0         None       play20-spring-demo
# 5          151          MIT                trousseau
# 6          391  NOASSERTION                   embulk
# 7           10      GPL-2.0                ZHNCosmos
# 8            2  NOASSERTION  Mesh-processing-library
#
#                        nameWithOwner  \
# 0        adamsmith/game-theory-poker
# 1                     google/iosched
# 2           yangyangwithgnu/hardseed
# 3                  iven-he/webspider
# 4   guillaumebort/play20-spring-demo
# 5                  oleiade/trousseau
# 6                      embulk/embulk
# 7                  zhnnnnn/ZHNCosmos
# 8  microsoft/Mesh-processing-library
#
#                                               readMe            owner  \
# 0  game-theory-poker\n=====\n\nThis is a game-the...        adamsmith
# 1  Google I/O Android App\n======================...           google
# 2  <h1 align="center">给不了你梦中情人，至少还有硬盘女神：hardseed<...  yangyangwithgnu
# 3  # \n\n[![Build Status](https://travis-ci.org/G...          iven-he
# 4  Using Spring from within a Play 2.0 applicatio...    guillaumebort
# 5  ![Trousseau, a portable encrypted keyring](tro...          oleiade
# 6  # What's Embulk?\n\nEmbulk is a parallel bulk ...           embulk
# 7  # Imitate Cosmos - a special third party weibo...          zhnnnnn
# 8  # Mesh-processing-library\nSee [README.html](h...        microsoft
#
#   primaryLanguage  totalPullRequests  totalCommits  totalStargazers  \
# 0            Java                  1             2              167
# 1          Kotlin                134          2635            18987
# 2             C++                 12           197             9102
# 3          Python                  8            51              260
# 4            Java                  3             3               88
# 5              Go                 46           547              881
# 6            Java                786          2646             1324
# 7     Objective-C                  0            37              451
# 8             C++                  0            42              399
#
#                   updatedAt
# 0 2019-08-13 15:14:46+00:00
# 1 2019-09-03 15:52:27+00:00
# 2 2019-09-02 12:40:54+00:00
# 3 2019-08-29 15:43:08+00:00
# 4 2019-05-31 11:35:43+00:00
# 5 2019-08-26 16:50:04+00:00
# 6 2019-09-03 07:27:25+00:00
# 7 2019-08-30 06:26:09+00:00
# 8 2019-09-03 03:55:23+00:00

# %% [markdown]
# ------
# #### I guess I'll have to join on owner of repo

# %%
ten_repo['pr_per_month'] = None
for f in pr_files:
    name = f.split('_', 1)[0]
    index = ten_repo[ten_repo['owner'].apply(lambda x: x.find(name))==0].index
    if (len(index)==0):
        continue
    else:
        index = index[0]
        ten_repo.at[index, 'pr_per_month'] = month_count(pd.read_pickle('../data/10_repos/{}'.format(f),'createdAt')
        print(name)

# %%
repo_count_filler(pr_files, 'pr_per_month', ten_repo)

# %%
repo_duration_filler(pr_files, 'pr_duration_month', ten_repo)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-bf368ffb0930> in <module>()
# ----> 1 repo_duration_filler(pr_files, 'pr_duration_month', ten_repo)
#
# <ipython-input-37-864df22f2f43> in repo_duration_filler(file_list, column_name, repo_df)
#      11         else:
#      12             index = index[0]
# ---> 13             repo_df.at[index, column_name] = duration(pd.read_pickle('../data/10_repos/{}'.format(f)), 'duration')
#      14 #             print(name)
#
# <ipython-input-36-f6845fcd8ae7> in duration(df, duration_column)
#       1 def duration(df, duration_column):
#       2     '''This function will return a list of a series with the avg duration per month'''
# ----> 3     df['duration'] = df['closedAt'] - df['createdAt']
#       4     duration = df[duration_column].apply(lambda x: x.total_seconds()).groupby(df.createdAt.dt.to_period('M'))
#       5     avg_duration = duration.mean().apply(lambda x: pd.to_timedelta(x, unit='s'))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1550             # test_dt64_series_add_intlike, which the index dispatching handles
#    1551             # specifically.
# -> 1552             result = dispatch_to_index_op(op, left, right, pd.DatetimeIndex)
#    1553             return construct_result(left, result,
#    1554                                     index=left.index, name=res_name,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#    1193         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1550             # test_dt64_series_add_intlike, which the index dispatching handles
#    1551             # specifically.
# -> 1552             result = dispatch_to_index_op(op, left, right, pd.DatetimeIndex)
#    1553             return construct_result(left, result,
#    1554                                     index=left.index, name=res_name,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#    1193         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops.py in rsub(left, right)
#     146
#     147 def rsub(left, right):
# --> 148     return right - left
#     149
#     150
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/datetimelike.py in __sub__(self, other)
#     499         def __sub__(self, other):
#     500             # dispatch to ExtensionArray implementation
# --> 501             result = self._data.__sub__(maybe_unwrap_index(other))
#     502             return wrap_arithmetic_op(self, other, result)
#     503
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimelike.py in __sub__(self, other)
#    1273         elif is_datetime64_dtype(other) or is_datetime64tz_dtype(other):
#    1274             # DatetimeIndex, ndarray[datetime64]
# -> 1275             result = self._sub_datetime_arraylike(other)
#    1276         elif is_period_dtype(other):
#    1277             # PeriodIndex
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in _sub_datetime_arraylike(self, other)
#     717             raise TypeError("{cls} subtraction must have the same "
#     718                             "timezones or no timezones"
# --> 719                             .format(cls=type(self).__name__))
#     720
#     721         self_i8 = self.asi8
#
# TypeError: DatetimeArray subtraction must have the same timezones or no timezones

# %%
ten_repo

# %% [markdown]
# ----------
# ## Function for creating association

# %%
repo_assoc_filler(pr_files, 'pr_assoc_dist', ten_repo)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
ten_repo['pr_assoc'] = None
pr_df.reset_index(inplace=True)
ten_repo.at[0, 'pr_assoc'] = association(pr_df)

# %%
df = pd.read_pickle('../data/10_repos/{}'.format(pr_files[]))
df = df.reset_index().drop(columns='index')
association(df)[0]
# Out:
# Index([0, 'v_count'], dtype='object')
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
#            CONTRIBUTOR  MEMBER  NONE
# createdAt
# 2013-06              0       0   1.0
# 2013-12              0       0   1.0

# %%
pr_df = pd.read_pickle('../data/10_repos/{}'.format(pr_files[0]))
# association(pr_df)
pr_df
# Out:
#    authorAssociation                                           bodyText  \
# 0             MEMBER  Cloned text from old project page at http://co...
# 1        CONTRIBUTOR                  Translated strings.xml in italian
# 2             MEMBER  This is still the 2013 version, so let's not g...
# 3        CONTRIBUTOR  Fix build broken by recently added Italian tra...
# 4             MEMBER  Add build script (.travis.yml) for travis-ci.o...
# 5             MEMBER  To clarify that this repository is a replaceme...
# 6             MEMBER  Publishing the L Preview SDK and updating README.
# 7             MEMBER
# 8             MEMBER
# 9             MEMBER
# 10       CONTRIBUTOR
# 11       CONTRIBUTOR  Hi, Thanks for the source codes. We've been pa...
# 12            MEMBER  This script is used as part of our test suite ...
# 13       CONTRIBUTOR  The reference comparison of the two strings ma...
# 14              NONE                                       2014 I/0 App
# 15       CONTRIBUTOR  Applied all the changes from forked version. N...
# 16       CONTRIBUTOR                         Fix according to issue #20
# 17              NONE
# 18              NONE
# 19              NONE
# 20       CONTRIBUTOR  The WiFiDialog Fragment accepted a parameter t...
# 21       CONTRIBUTOR  In french, a "haut-parleur" is an amplifier, n...
# 22       CONTRIBUTOR  The it-IT localization for the app is quite po...
# 23       CONTRIBUTOR  decline should be translated into "拒绝" but not...
# 24            MEMBER  Include SDK v20 for Wear support.\nSwitch to b...
# 25       CONTRIBUTOR  The issue is with '+' dependency references. T...
# 26       CONTRIBUTOR  Parameterise the keystore location so it can b...
# 27       CONTRIBUTOR  Address the following warning by putting the l...
# 28       CONTRIBUTOR  "Utils" directory should be "utils" on case-se...
# 29       CONTRIBUTOR                                 Fix for issue #11.
# ..               ...                                                ...
# 4               NONE  this commit will solve problem when we build t...
# 5               NONE  fix com.google.api.client.repackaged.com.googl...
# 6               NONE  Pull request for anyone else trying to build w...
# 7             MEMBER  Scale schedule screenshot down by 3x, so that ...
# 8               NONE
# 9        CONTRIBUTOR                          Executes unit tests only.
# 10              NONE
# 11              NONE                                 updating to latest
# 12              NONE  Update multiple dependencies to latest version...
# 13              NONE
# 14            MEMBER  icon.png is copied from shared/src/main/res/mi...
# 15              NONE  dictionary:\nhttp://dizionari.corriere.it/dizi...
# 16              NONE  A few commits to address the build problem and...
# 17              NONE  Fix #issue291\nI can recurrent this bug everyt...
# 18              NONE  more info here: https://developers.google.com/...
# 19              NONE  null can't be used as a valid content of Event...
# 20       CONTRIBUTOR                 Also, makes the project buildable.
# 21       CONTRIBUTOR
# 22              NONE
# 23              NONE  I have added some links to technical guidance ...
# 24              NONE  A link to further info about CLAs has been added.
# 25              NONE                                 Kotlin to (1.3.31)
# 26              NONE
# 27              NONE                                I hope it's useful.
# 28              NONE                                I hope it's useful.
# 29            MEMBER                             Push the code for 2019
# 30            MEMBER
# 31            MEMBER              Update the description about adssched
# 32       CONTRIBUTOR  I have implemented the latest version of Dagge...
# 33              NONE
#
#                     closedAt  \
# 0  2014-04-02 16:12:16+00:00
# 1  2014-04-23 22:18:29+00:00
# 2  2014-07-11 17:57:49+00:00
# 3  2014-05-15 01:09:39+00:00
# 4  2014-07-11 17:57:13+00:00
# 5  2014-06-25 04:53:39+00:00
# 6  2014-06-26 20:42:18+00:00
# 7  2014-07-24 22:57:55+00:00
# 8  2014-07-30 21:10:07+00:00
# 9  2014-07-30 21:14:06+00:00
# 10 2014-07-30 22:16:53+00:00
# 11 2014-08-10 21:47:23+00:00
# 12 2014-08-04 14:49:11+00:00
# 13 2014-08-04 14:51:11+00:00
# 14 2014-08-01 08:54:37+00:00
# 15 2014-10-18 12:55:14+00:00
# 16 2014-08-04 14:47:53+00:00
# 17 2014-08-03 11:44:03+00:00
# 18 2014-08-03 11:47:49+00:00
# 19 2014-08-03 11:56:33+00:00
# 20 2014-10-18 12:38:06+00:00
# 21 2014-08-12 23:04:58+00:00
# 22 2014-08-12 23:01:37+00:00
# 23 2014-08-12 18:29:19+00:00
# 24 2014-08-12 22:51:55+00:00
# 25 2015-01-07 15:02:46+00:00
# 26 2014-10-18 12:36:14+00:00
# 27 2014-10-18 12:35:19+00:00
# 28 2014-08-19 18:34:02+00:00
# 29 2014-10-18 12:29:22+00:00
# ..                       ...
# 4  2018-05-09 03:02:41+00:00
# 5  2018-08-13 17:50:27+00:00
# 6  2018-08-13 17:50:28+00:00
# 7  2018-08-13 17:58:26+00:00
# 8  2018-08-13 19:00:22+00:00
# 9  2018-08-13 19:02:08+00:00
# 10 2018-08-14 10:33:40+00:00
# 11 2018-08-16 09:58:38+00:00
# 12 2018-09-26 04:18:17+00:00
# 13                       NaT
# 14                       NaT
# 15                       NaT
# 16                       NaT
# 17                       NaT
# 18                       NaT
# 19                       NaT
# 20 2018-12-04 14:00:11+00:00
# 21 2019-08-15 10:13:47+00:00
# 22 2019-02-04 08:23:20+00:00
# 23                       NaT
# 24                       NaT
# 25                       NaT
# 26                       NaT
# 27 2019-08-13 05:39:42+00:00
# 28 2019-08-13 06:01:01+00:00
# 29 2019-08-14 10:39:34+00:00
# 30 2019-08-14 15:55:11+00:00
# 31 2019-08-19 14:16:40+00:00
# 32 2019-08-27 07:52:29+00:00
# 33 2019-08-27 07:53:31+00:00
#
#                                              comments  \
# 0                      {'totalCount': 0, 'nodes': []}
# 1   {'totalCount': 6, 'nodes': [{'author': {'login...
# 2   {'totalCount': 4, 'nodes': [{'author': {'login...
# 3   {'totalCount': 4, 'nodes': [{'author': {'login...
# 4                      {'totalCount': 0, 'nodes': []}
# 5   {'totalCount': 2, 'nodes': [{'author': {'login...
# 6   {'totalCount': 1, 'nodes': [{'author': {'login...
# 7                      {'totalCount': 0, 'nodes': []}
# 8   {'totalCount': 12, 'nodes': [{'author': {'logi...
# 9                      {'totalCount': 0, 'nodes': []}
# 10                     {'totalCount': 0, 'nodes': []}
# 11  {'totalCount': 5, 'nodes': [{'author': {'login...
# 12  {'totalCount': 2, 'nodes': [{'author': {'login...
# 13                     {'totalCount': 0, 'nodes': []}
# 14                     {'totalCount': 0, 'nodes': []}
# 15  {'totalCount': 3, 'nodes': [{'author': {'login...
# 16                     {'totalCount': 0, 'nodes': []}
# 17                     {'totalCount': 0, 'nodes': []}
# 18                     {'totalCount': 0, 'nodes': []}
# 19                     {'totalCount': 0, 'nodes': []}
# 20  {'totalCount': 3, 'nodes': [{'author': {'login...
# 21  {'totalCount': 4, 'nodes': [{'author': {'login...
# 22  {'totalCount': 5, 'nodes': [{'author': {'login...
# 23  {'totalCount': 4, 'nodes': [{'author': {'login...
# 24                     {'totalCount': 0, 'nodes': []}
# 25  {'totalCount': 3, 'nodes': [{'author': {'login...
# 26  {'totalCount': 4, 'nodes': [{'author': {'login...
# 27  {'totalCount': 2, 'nodes': [{'author': {'login...
# 28  {'totalCount': 1, 'nodes': [{'author': {'login...
# 29  {'totalCount': 5, 'nodes': [{'author': {'login...
# ..                                                ...
# 4   {'totalCount': 1, 'nodes': [{'author': {'login...
# 5                      {'totalCount': 0, 'nodes': []}
# 6                      {'totalCount': 0, 'nodes': []}
# 7                      {'totalCount': 0, 'nodes': []}
# 8   {'totalCount': 2, 'nodes': [{'author': {'login...
# 9   {'totalCount': 1, 'nodes': [{'author': {'login...
# 10  {'totalCount': 1, 'nodes': [{'author': {'login...
# 11  {'totalCount': 1, 'nodes': [{'author': {'login...
# 12                     {'totalCount': 0, 'nodes': []}
# 13  {'totalCount': 1, 'nodes': [{'author': {'login...
# 14                     {'totalCount': 0, 'nodes': []}
# 15                     {'totalCount': 0, 'nodes': []}
# 16                     {'totalCount': 0, 'nodes': []}
# 17                     {'totalCount': 0, 'nodes': []}
# 18                     {'totalCount': 0, 'nodes': []}
# 19                     {'totalCount': 0, 'nodes': []}
# 20  {'totalCount': 2, 'nodes': [{'author': {'login...
# 21  {'totalCount': 6, 'nodes': [{'author': {'login...
# 22  {'totalCount': 1, 'nodes': [{'author': {'login...
# 23  {'totalCount': 3, 'nodes': [{'author': {'login...
# 24  {'totalCount': 3, 'nodes': [{'author': {'login...
# 25                     {'totalCount': 0, 'nodes': []}
# 26                     {'totalCount': 0, 'nodes': []}
# 27                     {'totalCount': 0, 'nodes': []}
# 28                     {'totalCount': 0, 'nodes': []}
# 29  {'totalCount': 3, 'nodes': [{'author': {'login...
# 30  {'totalCount': 1, 'nodes': [{'author': {'login...
# 31  {'totalCount': 2, 'nodes': [{'author': {'login...
# 32  {'totalCount': 2, 'nodes': [{'author': {'login...
# 33  {'totalCount': 2, 'nodes': [{'author': {'login...
#
#                    createdAt              resourcePath   state  \
# 0  2014-04-02 03:58:26+00:00    /google/iosched/pull/1  MERGED
# 1  2014-04-22 15:34:57+00:00    /google/iosched/pull/2  MERGED
# 2  2014-05-08 23:30:59+00:00    /google/iosched/pull/3  MERGED
# 3  2014-05-14 13:59:55+00:00    /google/iosched/pull/4  MERGED
# 4  2014-05-15 01:05:17+00:00    /google/iosched/pull/5  MERGED
# 5  2014-06-25 04:31:38+00:00    /google/iosched/pull/7  MERGED
# 6  2014-06-26 20:31:34+00:00    /google/iosched/pull/8  MERGED
# 7  2014-07-24 22:55:29+00:00   /google/iosched/pull/13  MERGED
# 8  2014-07-30 21:08:11+00:00   /google/iosched/pull/14  MERGED
# 9  2014-07-30 21:13:41+00:00   /google/iosched/pull/15  MERGED
# 10 2014-07-30 22:16:11+00:00   /google/iosched/pull/16  MERGED
# 11 2014-07-31 02:09:52+00:00   /google/iosched/pull/17  MERGED
# 12 2014-07-31 04:33:52+00:00   /google/iosched/pull/18  MERGED
# 13 2014-07-31 22:16:52+00:00   /google/iosched/pull/21  MERGED
# 14 2014-08-01 08:54:07+00:00   /google/iosched/pull/22  CLOSED
# 15 2014-08-01 09:32:50+00:00   /google/iosched/pull/23  MERGED
# 16 2014-08-01 21:07:49+00:00   /google/iosched/pull/24  MERGED
# 17 2014-08-03 11:43:52+00:00   /google/iosched/pull/26  CLOSED
# 18 2014-08-03 11:47:32+00:00   /google/iosched/pull/27  CLOSED
# 19 2014-08-03 11:56:29+00:00   /google/iosched/pull/28  CLOSED
# 20 2014-08-06 16:59:21+00:00   /google/iosched/pull/31  MERGED
# 21 2014-08-07 07:34:39+00:00   /google/iosched/pull/32  MERGED
# 22 2014-08-07 13:51:33+00:00   /google/iosched/pull/33  MERGED
# 23 2014-08-12 06:09:09+00:00   /google/iosched/pull/34  MERGED
# 24 2014-08-12 18:54:50+00:00   /google/iosched/pull/35  MERGED
# 25 2014-08-15 23:26:30+00:00   /google/iosched/pull/39  CLOSED
# 26 2014-08-19 06:48:35+00:00   /google/iosched/pull/42  MERGED
# 27 2014-08-19 08:06:40+00:00   /google/iosched/pull/43  CLOSED
# 28 2014-08-19 15:33:25+00:00   /google/iosched/pull/44  MERGED
# 29 2014-08-21 05:50:39+00:00   /google/iosched/pull/45  MERGED
# ..                       ...                       ...     ...
# 4  2018-05-08 08:26:20+00:00  /google/iosched/pull/257  CLOSED
# 5  2018-05-09 03:01:07+00:00  /google/iosched/pull/258  CLOSED
# 6  2018-07-23 02:56:39+00:00  /google/iosched/pull/264  CLOSED
# 7  2018-08-13 17:56:15+00:00  /google/iosched/pull/265  MERGED
# 8  2018-08-13 18:07:27+00:00  /google/iosched/pull/267  CLOSED
# 9  2018-08-13 18:29:06+00:00  /google/iosched/pull/274  MERGED
# 10 2018-08-14 04:15:12+00:00  /google/iosched/pull/276  CLOSED
# 11 2018-08-14 12:53:23+00:00  /google/iosched/pull/277  CLOSED
# 12 2018-09-01 18:05:00+00:00  /google/iosched/pull/287  CLOSED
# 13 2018-09-04 10:20:28+00:00  /google/iosched/pull/288    OPEN
# 14 2018-09-18 17:15:16+00:00  /google/iosched/pull/292    OPEN
# 15 2018-09-25 19:36:48+00:00  /google/iosched/pull/295    OPEN
# 16 2018-10-07 15:51:06+00:00  /google/iosched/pull/297    OPEN
# 17 2018-10-15 10:42:32+00:00  /google/iosched/pull/299    OPEN
# 18 2018-11-15 03:43:59+00:00  /google/iosched/pull/300    OPEN
# 19 2018-11-16 20:00:24+00:00  /google/iosched/pull/301    OPEN
# 20 2018-11-29 14:20:52+00:00  /google/iosched/pull/303  MERGED
# 21 2018-12-20 08:21:02+00:00  /google/iosched/pull/304  MERGED
# 22 2019-02-04 08:23:09+00:00  /google/iosched/pull/306  CLOSED
# 23 2019-05-22 04:52:03+00:00  /google/iosched/pull/310    OPEN
# 24 2019-05-22 05:14:02+00:00  /google/iosched/pull/311    OPEN
# 25 2019-05-25 01:02:14+00:00  /google/iosched/pull/312    OPEN
# 26 2019-07-17 00:03:43+00:00  /google/iosched/pull/315    OPEN
# 27 2019-08-13 02:54:06+00:00  /google/iosched/pull/316  CLOSED
# 28 2019-08-13 05:50:22+00:00  /google/iosched/pull/317  CLOSED
# 29 2019-08-14 07:24:04+00:00  /google/iosched/pull/318  MERGED
# 30 2019-08-14 15:34:55+00:00  /google/iosched/pull/319  MERGED
# 31 2019-08-19 05:15:58+00:00  /google/iosched/pull/322  MERGED
# 32 2019-08-22 22:12:10+00:00  /google/iosched/pull/325  MERGED
# 33 2019-08-26 18:57:15+00:00  /google/iosched/pull/326  CLOSED
#
#                                                 title  \
# 0                                     Add README file
# 1                                 Italian translation
# 2          Change 2014 to 2013 in Italian translation
# 3                                           Fix build
# 4                Add support for building with Travis
# 5                              Small tweak to README.
# 6                                            Io14 apk
# 7     Adding missing copyright notice to .travis.yml.
# 8                     Publishing the I/O 2014 source.
# 9                                  Adding hero image.
# 10              Open source a bunch of source artwork
# 11  Change plugin to 'com.android.application' and...
# 12               Restore scripts/wait_for_emulator.sh
# 13                         Fixed a string comparison.
# 14           Merge pull request #1 from google/master
# 15  Updated SwipeRefreshLayout.java to the latest ...
# 16  Replace .commit() with .apply() in PrefUtils.java
# 17                                               test
# 18                                             Update
# 19                                               test
# 20                    Wifi Dialog Fragment State Loss
# 21               fix french localization of "speaker"
# 22                             Fix it-IT localization
# 23    correct translation of string decline in zh-rCN
# 24                     Update Travis CI configuration
# 25  Fix the inappropriate Play Services update req...
# 26                   Parameterise keystore properties
# 27                 Address gradle deprecation warning
# 28             Fixed case sensitive file system build
# 29  Stack multiple session feedback notifications ...
# ..                                                ...
# 4   fix "com.google.appengine.repackaged.com.googl...
# 5   fix com.google.api.client.repackaged.com.googl...
# 6       update to build with modern versions of tools
# 7                          Scale screenshot in README
# 8                                                Typo
# 9                Updates travis config to 2018 values
# 10                            Fix conflicts with okio
# 11           Merge pull request #1 from google/master
# 12                                Update dependencies
# 13                                     Fix Null check
# 14                         Add samples packaging info
# 15  Italian for "speakers" is "speaker" (s.m.inv.)...
# 16                                          Fix build
# 17              Fix bug on API level 28 (Android 9.0)
# 18  Fix build project and fix crash Google Maps SD...
# 19  Make sure type parameter of Event class is non...
# 20                  [ADSSCHED] Adds CircleCI with FTL
# 21                         Add travis badge in README
# 22                                                 Ci
# 23                 Added links to technical guidance.
# 24                              Providing info on CLA
# 25  [Android Studio-3.4.1] Updgraded gradle dist t...
# 26                                     docs: fix typo
# 27         Fix build errors, and update dependencies.
# 28          Fix build error, and update dependencies.
# 29                            Push the code for 2019
# 30                                      Fix travis CI
# 31                   Update the README about adssched
# 32  Update Dagger and implement Component.Factory ...
# 33               Update ArCoreNotSupportedFragment.kt
#
#                    updatedAt            author              company  files  \
# 0  2014-09-15 23:42:55+00:00            tjohns         Google, Inc.      1
# 1  2014-06-12 07:32:22+00:00           daftano       UN & Genuinous      1
# 2  2014-07-16 09:29:37+00:00            tjohns         Google, Inc.      1
# 3  2014-06-12 07:33:57+00:00        technoir42                 None      1
# 4  2015-01-29 05:38:06+00:00            tjohns         Google, Inc.      3
# 5  2014-06-25 04:53:39+00:00              btco                 None      1
# 6  2014-06-26 20:42:18+00:00              btco                 None      3
# 7  2014-07-24 22:57:55+00:00              btco                 None      1
# 8  2014-07-31 08:14:19+00:00              btco                 None   1332
# 9  2014-07-30 21:14:06+00:00              btco                 None      1
# 10 2014-07-30 22:16:53+00:00        romannurik             @google      26
# 11 2014-08-10 21:47:23+00:00         yelinaung                 None      2
# 12 2014-08-04 14:50:17+00:00            tjohns         Google, Inc.      1
# 13 2014-08-04 14:51:11+00:00     Lukas-Stuehrk  Westwing Group GmbH      1
# 14 2014-08-01 08:54:37+00:00  mainwaring083186                 None      0
# 15 2014-10-18 12:55:15+00:00           minas90                 None      1
# 16 2014-08-04 14:47:53+00:00            doobix                 None      1
# 17 2014-08-03 11:44:03+00:00  mainwaring083186                 None      0
# 18 2014-08-03 11:47:49+00:00  mainwaring083186                 None     13
# 19 2014-08-03 11:56:33+00:00  mainwaring083186                 None     13
# 20 2014-10-18 12:38:06+00:00             cstew       Big Nerd Ranch      1
# 21 2014-08-12 23:04:58+00:00              ph0b    Intel Corporation      1
# 22 2014-08-12 23:01:37+00:00            rock3r           @JetBrains      2
# 23 2014-08-12 18:29:19+00:00           WonShaw                 None      1
# 24 2014-08-12 22:51:55+00:00            tjohns         Google, Inc.      3
# 25 2015-01-07 15:02:46+00:00            rock3r           @JetBrains      3
# 26 2014-10-18 12:36:14+00:00          alsutton                 None      2
# 27 2014-10-18 12:35:19+00:00          alsutton                 None      2
# 28 2014-08-19 18:34:41+00:00  jacek-marchwicki                 None      1
# 29 2014-10-31 01:33:54+00:00        romannurik             @google     214
# ..                       ...               ...                  ...    ...
# 4  2018-05-09 03:02:41+00:00            tjohns         Google, Inc.      3
# 5  2018-08-13 17:50:27+00:00              btco                 None      1
# 6  2018-08-13 17:50:28+00:00              btco                 None      3
# 7  2018-08-13 17:58:26+00:00              btco                 None      1
# 8  2018-08-13 19:00:22+00:00              btco                 None   1332
# 9  2018-08-13 19:02:30+00:00              btco                 None      1
# 10 2018-08-14 10:33:57+00:00        romannurik             @google      26
# 11 2018-08-16 09:58:38+00:00         yelinaung                 None      2
# 12 2018-09-26 04:18:17+00:00            tjohns         Google, Inc.      1
# 13 2018-09-04 10:20:31+00:00     Lukas-Stuehrk  Westwing Group GmbH      1
# 14 2018-10-08 16:57:51+00:00  mainwaring083186                 None      0
# 15 2018-09-25 19:36:51+00:00           minas90                 None      1
# 16 2018-10-11 08:43:18+00:00            doobix                 None      1
# 17 2019-04-08 00:50:23+00:00  mainwaring083186                 None      0
# 18 2018-11-15 04:06:57+00:00  mainwaring083186                 None     13
# 19 2018-11-16 20:00:27+00:00  mainwaring083186                 None     13
# 20 2019-01-23 11:49:12+00:00             cstew       Big Nerd Ranch      1
# 21 2019-08-15 10:13:56+00:00              ph0b    Intel Corporation      1
# 22 2019-02-04 08:23:28+00:00            rock3r           @JetBrains      2
# 23 2019-05-26 17:15:22+00:00           WonShaw                 None      1
# 24 2019-05-26 17:11:25+00:00            tjohns         Google, Inc.      3
# 25 2019-08-28 19:03:23+00:00            rock3r           @JetBrains      3
# 26 2019-07-17 00:03:46+00:00          alsutton                 None      2
# 27 2019-08-13 05:39:42+00:00          alsutton                 None      2
# 28 2019-08-13 06:01:01+00:00  jacek-marchwicki                 None      1
# 29 2019-08-14 10:39:34+00:00        romannurik             @google     214
# 30 2019-08-14 16:01:04+00:00         willgryan                 None      1
# 31 2019-08-19 14:16:41+00:00            plnice                 None      3
# 32 2019-08-28 19:02:41+00:00         pbirdsall       erideshare.com    251
# 33 2019-08-27 07:53:31+00:00          AlexJeng                 None      1
#
#       mergedBy
# 0         btco
# 1       tjohns
# 2         btco
# 3       tjohns
# 4         btco
# 5       tjohns
# 6       tjohns
# 7      mangini
# 8      mangini
# 9      mangini
# 10     mangini
# 11      tjohns
# 12        btco
# 13        btco
# 14         NaN
# 15  romannurik
# 16        btco
# 17         NaN
# 18         NaN
# 19         NaN
# 20  romannurik
# 21      tjohns
# 22      tjohns
# 23      tjohns
# 24        btco
# 25         NaN
# 26  romannurik
# 27         NaN
# 28      tjohns
# 29  romannurik
# ..         ...
# 4         btco
# 5       tjohns
# 6       tjohns
# 7      mangini
# 8      mangini
# 9      mangini
# 10     mangini
# 11      tjohns
# 12        btco
# 13        btco
# 14         NaN
# 15  romannurik
# 16        btco
# 17         NaN
# 18         NaN
# 19         NaN
# 20  romannurik
# 21      tjohns
# 22      tjohns
# 23      tjohns
# 24        btco
# 25         NaN
# 26  romannurik
# 27         NaN
# 28      tjohns
# 29  romannurik
# 30         NaN
# 31         NaN
# 32         NaN
# 33  romannurik
#
# [134 rows x 13 columns]

# %%
ten_repo
