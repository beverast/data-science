# %%
import os

import pandas as pd
import numpy as np

# %%
# Read all pk1 commit files from Data/cm (sub)folders
pickled_commit_dirs = []
repo_names = []
for folder in os.listdir('../Data/cm'):
    try:
        pickled_commit_dirs.append(f'../Data/cm/{folder}/'+os.listdir('../Data/cm/'+folder)[0])
        repo_names.append(folder)
    except:
        print('NO COMMIT DATA IN: ', folder)
        continue

print('\n', pickled_commit_dirs[:20])
print('\n', repo_names[:20])
# Out:
# NO COMMIT DATA IN:  LeaVerou-prefixfree
# NO COMMIT DATA IN:  MinecraftForge-MinecraftForge
# NO COMMIT DATA IN:  bernii-gauge.js
# NO COMMIT DATA IN:  davetcoleman-moveit_simple_grasps
# NO COMMIT DATA IN:  lo-th-Oimo.js
# NO COMMIT DATA IN:  nicothin-idiomatic-pre-CSS
# NO COMMIT DATA IN:  skyhover-Deckard
# NO COMMIT DATA IN:  theupdateframework-tuf
# NO COMMIT DATA IN:  ubik-redmine_vote
#
#  ['../Data/cm/AE9RB-ruby-redis/AE9RB_ruby-redis_cm.pk1', '../Data/cm/AigeStudio-Android/AigeStudio_Android_cm.pk1', '../Data/cm/AlburIvan-SlickForm/AlburIvan_SlickForm_cm.pk1', '../Data/cm/AlexLiuSheng-CheckVersionLib/AlexLiuSheng_CheckVersionLib_cm.pk1', '../Data/cm/AllenDowney-ThinkJavaCode/AllenDowney_ThinkJavaCode_cm.pk1', '../Data/cm/Aufree-ESTMusicIndicator/Aufree_ESTMusicIndicator_cm.pk1', '../Data/cm/Azure-azure-storage-fuse/Azure_azure-storage-fuse_cm.pk1', '../Data/cm/BMIRDS-deepslide/BMIRDS_deepslide_cm.pk1', '../Data/cm/BetterCloud-vault-java-driver/BetterCloud_vault-java-driver_cm.pk1', '../Data/cm/BreakingMalwareResearch-eleven/BreakingMalwareResearch_eleven_cm.pk1', '../Data/cm/BurntSushi-quickcheck/BurntSushi_quickcheck_cm.pk1', '../Data/cm/BycorSanchez-resources/BycorSanchez_resources_cm.pk1', '../Data/cm/CMU-Perceptual-Computing-Lab-openpose/CMU-Perceptual-Computing-Lab_openpose_cm.pk1', '../Data/cm/CVCalendar-CVCalendar/CVCalendar_CVCalendar_cm.pk1', '../Data/cm/CaoZ-JD-Coin/CaoZ_JD-Coin_cm.pk1', '../Data/cm/ChrisXu-CXAlertView/ChrisXu_CXAlertView_cm.pk1', '../Data/cm/ClickSimply-Nano-SQL/ClickSimply_Nano-SQL_cm.pk1', '../Data/cm/Coalfire-Research-Slackor/Coalfire-Research_Slackor_cm.pk1', '../Data/cm/CollabCodeTech-forum-do-front-ao-end/CollabCodeTech_forum-do-front-ao-end_cm.pk1', '../Data/cm/CraneStation-wasmtime/CraneStation_wasmtime_cm.pk1']
#
#  ['AE9RB-ruby-redis', 'AigeStudio-Android', 'AlburIvan-SlickForm', 'AlexLiuSheng-CheckVersionLib', 'AllenDowney-ThinkJavaCode', 'Aufree-ESTMusicIndicator', 'Azure-azure-storage-fuse', 'BMIRDS-deepslide', 'BetterCloud-vault-java-driver', 'BreakingMalwareResearch-eleven', 'BurntSushi-quickcheck', 'BycorSanchez-resources', 'CMU-Perceptual-Computing-Lab-openpose', 'CVCalendar-CVCalendar', 'CaoZ-JD-Coin', 'ChrisXu-CXAlertView', 'ClickSimply-Nano-SQL', 'Coalfire-Research-Slackor', 'CollabCodeTech-forum-do-front-ao-end', 'CraneStation-wasmtime']

# %%
# Read in all pickled files
df_list = [pd.read_pickle(file_dir) for file_dir in pickled_commit_dirs]

# %%
df_list[0]
# Out:
#                                associatedPullRequests         committedDate  \
# 0                                       {'nodes': []}  2011-09-20T16:35:28Z
# 1   {'nodes': [{'id': 'MDExOlB1bGxSZXF1ZXN0MzQyNzA...  2011-09-20T16:25:41Z
# 2                                       {'nodes': []}  2011-08-01T00:37:18Z
# 3                                       {'nodes': []}  2011-08-01T00:03:43Z
# 4                                       {'nodes': []}  2011-07-31T23:53:50Z
# 5                                       {'nodes': []}  2011-07-31T22:51:30Z
# 6                                       {'nodes': []}  2011-07-31T22:21:18Z
# 7                                       {'nodes': []}  2011-07-31T21:58:17Z
# 8                                       {'nodes': []}  2011-07-31T21:54:49Z
# 9                                       {'nodes': []}  2011-07-24T03:33:37Z
# 10                                      {'nodes': []}  2011-07-24T03:30:48Z
# 11                                      {'nodes': []}  2011-07-24T02:57:32Z
# 12                                      {'nodes': []}  2011-07-24T02:56:18Z
# 13                                      {'nodes': []}  2011-07-22T03:17:58Z
# 14                                      {'nodes': []}  2011-07-22T03:04:40Z
# 15                                      {'nodes': []}  2011-07-22T02:42:52Z
# 16                                      {'nodes': []}  2011-07-22T02:26:52Z
# 17                                      {'nodes': []}  2011-07-22T00:23:38Z
# 18                                      {'nodes': []}  2011-07-21T23:57:06Z
# 19                                      {'nodes': []}  2011-07-21T22:14:05Z
# 20                                      {'nodes': []}  2011-07-21T19:14:01Z
# 21                                      {'nodes': []}  2011-07-21T18:05:50Z
# 22                                      {'nodes': []}  2011-07-21T06:05:36Z
# 23                                      {'nodes': []}  2011-07-21T06:03:56Z
# 24                                      {'nodes': []}  2011-07-20T20:20:19Z
# 25                                      {'nodes': []}  2011-07-20T04:42:40Z
# 26                                      {'nodes': []}  2011-07-20T02:24:48Z
# 27                                      {'nodes': []}  2011-07-20T01:45:05Z
# 28                                      {'nodes': []}  2011-07-19T23:28:44Z
# 29                                      {'nodes': []}  2011-07-19T23:26:07Z
# ..                                                ...                   ...
# 60                                      {'nodes': []}  2011-06-23T22:29:29Z
# 61                                      {'nodes': []}  2011-06-06T17:01:40Z
# 62                                      {'nodes': []}  2011-06-06T00:12:07Z
# 63                                      {'nodes': []}  2011-06-05T20:41:03Z
# 64                                      {'nodes': []}  2011-06-05T06:01:03Z
# 65                                      {'nodes': []}  2011-06-05T04:25:14Z
# 66                                      {'nodes': []}  2011-06-05T01:28:44Z
# 67                                      {'nodes': []}  2011-06-04T22:26:51Z
# 68                                      {'nodes': []}  2011-06-04T06:58:28Z
# 69                                      {'nodes': []}  2011-06-04T02:29:37Z
# 70                                      {'nodes': []}  2011-06-02T06:55:52Z
# 71                                      {'nodes': []}  2011-06-02T02:28:16Z
# 72                                      {'nodes': []}  2011-06-01T06:58:07Z
# 73                                      {'nodes': []}  2011-06-01T02:13:05Z
# 74                                      {'nodes': []}  2011-05-31T23:44:20Z
# 75                                      {'nodes': []}  2011-05-31T06:08:38Z
# 76                                      {'nodes': []}  2011-05-31T04:41:59Z
# 77                                      {'nodes': []}  2011-05-30T21:52:54Z
# 78                                      {'nodes': []}  2011-05-30T06:29:51Z
# 79                                      {'nodes': []}  2011-05-29T22:41:13Z
# 80                                      {'nodes': []}  2011-05-29T18:32:56Z
# 81                                      {'nodes': []}  2011-05-29T05:44:14Z
# 82                                      {'nodes': []}  2011-05-28T21:24:08Z
# 83                                      {'nodes': []}  2011-05-28T21:22:41Z
# 84                                      {'nodes': []}  2011-05-28T05:11:08Z
# 85                                      {'nodes': []}  2011-05-27T06:43:27Z
# 86                                      {'nodes': []}  2011-05-27T00:54:55Z
# 87                                      {'nodes': []}  2011-05-27T00:53:14Z
# 88                                      {'nodes': []}  2011-05-25T04:58:08Z
# 89                                      {'nodes': []}  2011-05-25T04:49:51Z
#
#                                             committer  \
# 0       {'user': {'login': 'AE9RB', 'company': None}}
# 1   {'user': {'login': 'fronx', 'company': 'Ableto...
# 2       {'user': {'login': 'AE9RB', 'company': None}}
# 3       {'user': {'login': 'AE9RB', 'company': None}}
# 4       {'user': {'login': 'AE9RB', 'company': None}}
# 5       {'user': {'login': 'AE9RB', 'company': None}}
# 6       {'user': {'login': 'AE9RB', 'company': None}}
# 7       {'user': {'login': 'AE9RB', 'company': None}}
# 8       {'user': {'login': 'AE9RB', 'company': None}}
# 9       {'user': {'login': 'AE9RB', 'company': None}}
# 10      {'user': {'login': 'AE9RB', 'company': None}}
# 11      {'user': {'login': 'AE9RB', 'company': None}}
# 12      {'user': {'login': 'AE9RB', 'company': None}}
# 13      {'user': {'login': 'AE9RB', 'company': None}}
# 14      {'user': {'login': 'AE9RB', 'company': None}}
# 15      {'user': {'login': 'AE9RB', 'company': None}}
# 16      {'user': {'login': 'AE9RB', 'company': None}}
# 17      {'user': {'login': 'AE9RB', 'company': None}}
# 18      {'user': {'login': 'AE9RB', 'company': None}}
# 19      {'user': {'login': 'AE9RB', 'company': None}}
# 20      {'user': {'login': 'AE9RB', 'company': None}}
# 21      {'user': {'login': 'AE9RB', 'company': None}}
# 22      {'user': {'login': 'AE9RB', 'company': None}}
# 23      {'user': {'login': 'AE9RB', 'company': None}}
# 24      {'user': {'login': 'AE9RB', 'company': None}}
# 25      {'user': {'login': 'AE9RB', 'company': None}}
# 26      {'user': {'login': 'AE9RB', 'company': None}}
# 27      {'user': {'login': 'AE9RB', 'company': None}}
# 28      {'user': {'login': 'AE9RB', 'company': None}}
# 29      {'user': {'login': 'AE9RB', 'company': None}}
# ..                                                ...
# 60      {'user': {'login': 'AE9RB', 'company': None}}
# 61      {'user': {'login': 'AE9RB', 'company': None}}
# 62      {'user': {'login': 'AE9RB', 'company': None}}
# 63      {'user': {'login': 'AE9RB', 'company': None}}
# 64      {'user': {'login': 'AE9RB', 'company': None}}
# 65      {'user': {'login': 'AE9RB', 'company': None}}
# 66      {'user': {'login': 'AE9RB', 'company': None}}
# 67      {'user': {'login': 'AE9RB', 'company': None}}
# 68      {'user': {'login': 'AE9RB', 'company': None}}
# 69      {'user': {'login': 'AE9RB', 'company': None}}
# 70      {'user': {'login': 'AE9RB', 'company': None}}
# 71      {'user': {'login': 'AE9RB', 'company': None}}
# 72      {'user': {'login': 'AE9RB', 'company': None}}
# 73      {'user': {'login': 'AE9RB', 'company': None}}
# 74      {'user': {'login': 'AE9RB', 'company': None}}
# 75      {'user': {'login': 'AE9RB', 'company': None}}
# 76      {'user': {'login': 'AE9RB', 'company': None}}
# 77      {'user': {'login': 'AE9RB', 'company': None}}
# 78      {'user': {'login': 'AE9RB', 'company': None}}
# 79      {'user': {'login': 'AE9RB', 'company': None}}
# 80      {'user': {'login': 'AE9RB', 'company': None}}
# 81      {'user': {'login': 'AE9RB', 'company': None}}
# 82      {'user': {'login': 'AE9RB', 'company': None}}
# 83      {'user': {'login': 'AE9RB', 'company': None}}
# 84      {'user': {'login': 'AE9RB', 'company': None}}
# 85      {'user': {'login': 'AE9RB', 'company': None}}
# 86      {'user': {'login': 'AE9RB', 'company': None}}
# 87      {'user': {'login': 'AE9RB', 'company': None}}
# 88      {'user': {'login': 'AE9RB', 'company': None}}
# 89      {'user': {'login': 'AE9RB', 'company': None}}
#
#                                       messageHeadline  \
# 0            Merge pull request #5 from fronx/patch-1
# 1                   make Keys#redis_TYPE more concise
# 2                                delete pid when done
# 3                                           bury ZSet
# 4              narrowed exceptions and thinned client
# 5                                       markdown docs
# 6                                  released gem 0.0.2
# 7                     revert EventMachine::Completion
# 8                        try EventMachine::Completion
# 9                            buffer limits for reader
# 10                                         fixed -inf
# 11                                       module Redis
# 12                                              fixes
# 13                               remove global logger
# 14                              remove unused timeout
# 15  remove global databases allowing for multiple ...
# 16        remove useless timeout for performance gain
# 17                             fix watch inside multi
# 18                              multi and exec pwnage
# 19                                  simplified pubsub
# 20                     started refactor of multi/exec
# 21                                client improvements
# 22                           all config settings work
# 23                                  fixed empty multi
# 24                                 Cleared base class
# 25                         server code is all modules
# 26                                    cleaner sending
# 27                         simplified the server core
# 28                                     released 0.0.1
# 29                                    cleaned up docs
# ..                                                ...
# 60                            gemspec and BSD license
# 61  Ruby 1.8 support.  Support for 1.8 will likely...
# 62                                             pubsub
# 63                                                cas
# 64                                             expire
# 65                         better source organization
# 66                                               sort
# 67                                      zsets working
# 68                                          more zset
# 69                                      zsets started
# 70                                               sets
# 71                                             hashes
# 72                                lists tests passing
# 73                           many lists tests passing
# 74                     tests passing up through basic
# 75                          additional protocol error
# 76               lists are running, blocking pops too
# 77                           basic unit tests passing
# 78                                       now has sets
# 79            Volatile database and better call stack
# 80                           more test basics passing
# 81                                   better organized
# 82       Completed multi-element BigString code paths
# 83                    Now using EventMachine 1.0 beta
# 84              Performance tricks moved to BigString
# 85                 first three unit tests are passing
# 86                                    tests supported
# 87                                  redis 2.2.8 tests
# 88                                               typo
# 89                                       first commit
#
#                                          oid status
# 0   bf24971866fc41c4e462a855388e4d1bf464f254   None
# 1   0a321dc8a7d1d8b8d724e924bce71ed919db498d   None
# 2   d16cc376fab1d099eea19abea2abcba3de18b65c   None
# 3   330b8f81525346edd2c4f80ba3f1b5f01b6786a6   None
# 4   0737b70cf3c0de51d02f669a11fc63fb3eecebb8   None
# 5   2aa8183b127ede7897f4045d276cbf91be3f5173   None
# 6   61c0839a05af081aaa020513d97e22c9c4740a10   None
# 7   bf7b0ab31d1e266a150b62d2c2922266863214a8   None
# 8   8d6485c161993fe969d351aa7a934711392adb05   None
# 9   74389798fc3e6c4f8402a0cb66ed2897d9f5ad9f   None
# 10  6950b1c0b8262c9055a544e33dbf76a9a2025044   None
# 11  91f83afa81151a28f383bf9d2d46a6af26012ada   None
# 12  d7563cd71f0d663fe560939cf6030d6f4a1e1bbf   None
# 13  6256e55ab4665bc088d9ec9da2c9000f29128cc9   None
# 14  7fa220c9a06b953053f9a1a5926fbd6320cb627a   None
# 15  4f354c9479e267fcaee17e604cbd2e988953b4b1   None
# 16  3e5cd0bed2db44ac85e83b5f1e87bf9187a6c24e   None
# 17  49d23eb12f2eed2c5b8eea5c75b0434e01d7fc0f   None
# 18  58b4ea4a9891888850950f031d15dcfca9e3ace2   None
# 19  7b2b9ce8ef8136b4552e64d2379760eb1a1b0e42   None
# 20  4f6d2ad93e608574c5e04b141d4785f3fa082fcf   None
# 21  3a278f57db4131e93e1c6356769a215ec43f4292   None
# 22  4a30761a8a6f29e6cbd666ce672472168a1ef20a   None
# 23  7deb60bfd3fb98d6d8492599379c6f81b91660cd   None
# 24  3c700d0aa1a4b3263e5080afe900ece49310e96c   None
# 25  7360dc9a0c462d9ebdfb64a566f6c34978fd6ac2   None
# 26  aa4e54a0ec202edfe13f7c4b4bb0bbfa3af4df4e   None
# 27  ebece8835e24939eb631b4f49322b18bce27930b   None
# 28  492b072f7ccab988830154f71f3a93d31f5e15e5   None
# 29  fd4df6cd14de94cc04f19a4a91a26954f39054ff   None
# ..                                       ...    ...
# 60  dadd0290441788d4ea9698f778a969319ac3e4e8   None
# 61  891f13b83b02c8c4fe0b4c9c2fb5cba6cf44a52c   None
# 62  f03538856d2a0f1ad2741d0c6e03fef3a7479922   None
# 63  6c2920b8db9e5042f2e9b151545be9bdfb6577ba   None
# 64  51ce197a334c27aeffa68d1b77b5e302c72c080f   None
# 65  8650a17441f266c93ceb1b01aa374faef7e65aec   None
# 66  4690d881ab3e4c3001cc3fcd59a657361b9f66b9   None
# 67  4c89ea370e13601858afd2f0066b08cf26e6899f   None
# 68  9213c2641eddf65cd22ddf5328eede3e8d5042e7   None
# 69  af0f01d5192c5240edb21bcbf1826e80d39714f4   None
# 70  b6f05635d33070de1124162fc9a35a484dfcf62a   None
# 71  8ac099c5be68c6e05d34b7b6df97a9c8619813e3   None
# 72  2ac9a07bf5c7584b581ec63e2a3ffe9217aa7037   None
# 73  3c4b0a02cfb9a9e4b2bd905c3d60dd6b06def6f5   None
# 74  0c12e1b679b0b0cd3f20ed7dd32e7604c701b6d6   None
# 75  ff13b42bf089034065301b9c001416c83f46fb56   None
# 76  cabf44c81560cd45378bf2a6aeb765ec564407da   None
# 77  20153758dcb76ae611f3fe03bc0482f9994d2bb6   None
# 78  5dfa85ba4155fa154594dae30d8d91ccf93b1249   None
# 79  588b27dd48433a807b325c79ebc4b0644b63a9a1   None
# 80  3af65c910c5a6751a8f9410e55c625c9f299a4f7   None
# 81  e6aca20cc99e698506992b98f6e3a5dbddca14b2   None
# 82  70f6594825ad79ee435cc7c704b7f752dad3c7dd   None
# 83  5ba2b483de43e11dbae3db0cfdd0b69758b64f6d   None
# 84  8ae9a6f654690430d7412b1a6e2d0595f1d30c83   None
# 85  086fc58f2c9953caeb41e96426fef64e9b8196f2   None
# 86  cc93fc0cc1ad1c5fe7e135afe4a7ce780aadccda   None
# 87  d413d86ba391ad5dcb8472f98b2f97f6095b356b   None
# 88  d6c6820c44e90797bfe3e27a5cdd6fd107e860eb   None
# 89  1c3011ae84acfceb3731b73045e01e397cfb4f1b   None
#
# [90 rows x 6 columns]

# %%
def clean_commit_df(commit_df: pd.DataFrame) -> pd.DataFrame:
    """
    Given a DataFrame of commit data, return the cleaned DataFrame.
    """

    PR_dict_list = commit_df['associatedPullRequests'].values.tolist()
    unpacked_dict_list = []

    for item in PR_dict_list:
        # If `nodes` is empty append dict of NaNs, else append data
        if len(item['nodes']) == 0:
            unpacked_dict_list.append({'id': np.NaN, 'title': np.NaN, 'author': np.NaN,\
                                       'authorAssociation': np.NaN, 'createdAt': np.NaN,\
                                       'updatedAt': np.NaN, 'closedAt': np.NaN,\
                                       'number': np.NaN, 'state': np.NaN})
        else:
            unpacked = item['nodes'][0]
            unpacked_dict_list.append(unpacked)

    assocPR_df = pd.DataFrame(unpacked_dict_list)

    ##########################

    committer_dicts = commit_df['committer'].values.tolist()
    unpacked_dict_list = []

    for item in committer_dicts:
        # If `user` is empty append dict of NaNs, else append data
        if item['user'] == None:
            unpacked_dict_list.append({'login': np.NaN, 'company': np.NaN})
        else:
            unpacked = item['user']
            unpacked_dict_list.append(unpacked)

    committer_df = pd.DataFrame(unpacked_dict_list)

    #########################

    status_dicts = commit_df['status'].values.tolist()
    unpacked_dict_list = []

    for item in status_dicts:
        # If `item` is empty append dict of NaNs, else append data
        if item == None:
            unpacked_dict_list.append({'id': np.NaN, 'state': np.NaN})
        else:
            unpacked = item
            unpacked_dict_list.append(unpacked)

    status_df = pd.DataFrame(unpacked_dict_list)

    ########################

    renamed_cols = {'author':'assocPR_author',
                    'authorAssociation':'assocPR_authorAssociation',
                    'closedAt':'assocPR_closedAt',
                    'createdAt':'assocPR_createdAt',
                    'id':'assocPR_id',
                    'number':'assocPR_number',
                    'state':'assocPR_state',
                    'title':'assocPR_title',
                    'updatedAt':'assocPR_updatedAt'}

    assocPR_df.rename(columns=renamed_cols, inplace=True)

    # Make list of PR author login values
    author_dicts = assocPR_df['assocPR_author'].values.tolist()
    unpacked_dict_list = []

    for item in author_dicts:
        # If `item` is empty append NaN, else append data
        if item == None or type(item) == float:
            unpacked_dict_list.append(np.NaN)
        else:
            unpacked_dict_list.append(item['login'])

    assocPR_df['assocPR_author'] = unpacked_dict_list

    renamed_cols = {'company':'committer_company',
                    'login':'committer_author'}
    committer_df.rename(columns=renamed_cols, inplace=True)

    renamed_cols = {'id':'status_id',
                    'state':'status_state'}
    status_df.rename(columns=renamed_cols, inplace=True)

    #######################

    commits_cleaned = pd.concat([assocPR_df, committer_df, status_df], axis='columns', ignore_index=False)

    commits_cleaned['committedDate'] = commit_df['committedDate'].values
    commits_cleaned['messageHeadline'] = commit_df['messageHeadline'].values
    commits_cleaned['oid'] = commit_df['oid'].values

    # Convert times to pd.Timestamp
    commits_cleaned['assocPR_createdAt'] = commits_cleaned['assocPR_createdAt'].apply(pd.Timestamp)
    commits_cleaned['assocPR_updatedAt'] = commits_cleaned['assocPR_updatedAt'].apply(pd.Timestamp)
    commits_cleaned['assocPR_closedAt'] = commits_cleaned['assocPR_closedAt'].apply(pd.Timestamp)
    
    return commits_cleaned

# %%
# Clean each commit DataFrame
cleaned_commits = []
for df in df_list:
    cleaned_commits.append(clean_commit_df(df))

# %%
df_list[3][:5]
# Out:
#                               associatedPullRequests         committedDate  \
# 0  {'nodes': [{'id': 'MDExOlB1bGxSZXF1ZXN0Mjk0NzU...  2019-04-30T07:46:14Z
# 1  {'nodes': [{'id': 'MDExOlB1bGxSZXF1ZXN0Mjk0NzU...  2019-04-30T06:38:14Z
# 2  {'nodes': [{'id': 'MDExOlB1bGxSZXF1ZXN0MjQ2OTE...  2019-01-25T02:39:07Z
# 3  {'nodes': [{'id': 'MDExOlB1bGxSZXF1ZXN0MjQ2OTE...  2019-01-23T10:19:23Z
# 4  {'nodes': [{'id': 'MDExOlB1bGxSZXF1ZXN0MjY1NTk...  2019-01-16T14:28:23Z
#
#                                            committer  \
# 0  {'user': {'login': 'AlexLiuSheng', 'company': ...
# 1  {'user': {'login': 'AlexLiuSheng', 'company': ...
# 2                                     {'user': None}
# 3     {'user': {'login': 'lxstar', 'company': None}}
# 4    {'user': {'login': 'ALECKLQ', 'company': None}}
#
#                                      messageHeadline  \
# 0         #fix# issues #245 #241 #240 #239 #232 #231
# 1         #fix# issues #245 #241 #240 #239 #232 #231
# 2         Merge pull request #230 from lxstar/master
# 3  fixbug: change readme excuteMission to execute...
# 4           fix issues #229 #228 #226 #225 #220 #212
#
#                                         oid  \
# 0  d2904e022abc95e6f8054dffcceb7aa91f85af13
# 1  0698498f3824a3a627e6712d6be18c266323fa7c
# 2  c6c9253efc8799a90ef94585a1ddd6efd4a9fd5d
# 3  f923992065d4fa1ffa0f7138caddd242feb441b5
# 4  3da65bc11ad9c578a2e8dd725b714fac8ef81b16
#
#                                               status
# 0  {'id': 'MDY6U3RhdHVzNjg5ODk3Njg6ZDI5MDRlMDIyYW...
# 1                                               None
# 2  {'id': 'MDY6U3RhdHVzNjg5ODk3Njg6YzZjOTI1M2VmYz...
# 3  {'id': 'MDY6U3RhdHVzNjg5ODk3Njg6ZjkyMzk5MjA2NW...
# 4  {'id': 'MDY6U3RhdHVzNjg5ODk3Njg6M2RhNjViYzExYW...

# %%
cleaned_commits[3][:5]
# Out:
#   assocPR_author assocPR_authorAssociation          assocPR_closedAt  \
# 0        leirace                     OWNER 2019-07-05 06:53:23+00:00
# 1        leirace                     OWNER 2019-07-05 06:53:23+00:00
# 2         lxstar               CONTRIBUTOR 2019-01-25 02:39:08+00:00
# 3         lxstar               CONTRIBUTOR 2019-01-25 02:39:08+00:00
# 4      zqlq4ever                     OWNER 2019-03-29 06:04:30+00:00
#
#           assocPR_createdAt                        assocPR_id  assocPR_number  \
# 0 2019-07-05 06:51:36+00:00  MDExOlB1bGxSZXF1ZXN0Mjk0NzU2NzUx             1.0
# 1 2019-07-05 06:51:36+00:00  MDExOlB1bGxSZXF1ZXN0Mjk0NzU2NzUx             1.0
# 2 2019-01-23 10:22:06+00:00  MDExOlB1bGxSZXF1ZXN0MjQ2OTExNjIx           230.0
# 3 2019-01-23 10:22:06+00:00  MDExOlB1bGxSZXF1ZXN0MjQ2OTExNjIx           230.0
# 4 2019-03-29 06:04:22+00:00  MDExOlB1bGxSZXF1ZXN0MjY1NTk2MTQ2             1.0
#
#   assocPR_state                                      assocPR_title  \
# 0        MERGED                                             update
# 1        MERGED                                             update
# 2        MERGED  fixbug: change readme excuteMission to execute...
# 3        MERGED  fixbug: change readme excuteMission to execute...
# 4        MERGED                                                  1
#
#           assocPR_updatedAt  committer_company committer_author  \
# 0 2019-07-05 06:53:23+00:00                NaN     AlexLiuSheng
# 1 2019-07-05 06:53:23+00:00                NaN     AlexLiuSheng
# 2 2019-01-25 02:39:08+00:00                NaN              NaN
# 3 2019-01-25 02:39:08+00:00                NaN           lxstar
# 4 2019-03-29 06:04:30+00:00                NaN          ALECKLQ
#
#                                            status_id status_state  \
# 0  MDY6U3RhdHVzNjg5ODk3Njg6ZDI5MDRlMDIyYWJjOTVlNm...      FAILURE
# 1                                                NaN          NaN
# 2  MDY6U3RhdHVzNjg5ODk3Njg6YzZjOTI1M2VmYzg3OTlhOT...      FAILURE
# 3  MDY6U3RhdHVzNjg5ODk3Njg6ZjkyMzk5MjA2NWQ0ZmExZm...      FAILURE
# 4  MDY6U3RhdHVzNjg5ODk3Njg6M2RhNjViYzExYWQ5YzU3OG...      FAILURE
#
#           committedDate                                    messageHeadline  \
# 0  2019-04-30T07:46:14Z         #fix# issues #245 #241 #240 #239 #232 #231
# 1  2019-04-30T06:38:14Z         #fix# issues #245 #241 #240 #239 #232 #231
# 2  2019-01-25T02:39:07Z         Merge pull request #230 from lxstar/master
# 3  2019-01-23T10:19:23Z  fixbug: change readme excuteMission to execute...
# 4  2019-01-16T14:28:23Z           fix issues #229 #228 #226 #225 #220 #212
#
#                                         oid
# 0  d2904e022abc95e6f8054dffcceb7aa91f85af13
# 1  0698498f3824a3a627e6712d6be18c266323fa7c
# 2  c6c9253efc8799a90ef94585a1ddd6efd4a9fd5d
# 3  f923992065d4fa1ffa0f7138caddd242feb441b5
# 4  3da65bc11ad9c578a2e8dd725b714fac8ef81b16

# %%
cleaned_dir = '../Data/cleaned_commits/'
for ind, df in enumerate(cleaned_commits):
    df.to_pickle(cleaned_dir+repo_names[ind]+'_cm.pk1')

# %%
# Test pickled files
pd.read_pickle(cleaned_dir+repo_names[3]+'_cm.pk1')[:5]
# Out:
#   assocPR_author assocPR_authorAssociation          assocPR_closedAt  \
# 0        leirace                     OWNER 2019-07-05 06:53:23+00:00
# 1        leirace                     OWNER 2019-07-05 06:53:23+00:00
# 2         lxstar               CONTRIBUTOR 2019-01-25 02:39:08+00:00
# 3         lxstar               CONTRIBUTOR 2019-01-25 02:39:08+00:00
# 4      zqlq4ever                     OWNER 2019-03-29 06:04:30+00:00
#
#           assocPR_createdAt                        assocPR_id  assocPR_number  \
# 0 2019-07-05 06:51:36+00:00  MDExOlB1bGxSZXF1ZXN0Mjk0NzU2NzUx             1.0
# 1 2019-07-05 06:51:36+00:00  MDExOlB1bGxSZXF1ZXN0Mjk0NzU2NzUx             1.0
# 2 2019-01-23 10:22:06+00:00  MDExOlB1bGxSZXF1ZXN0MjQ2OTExNjIx           230.0
# 3 2019-01-23 10:22:06+00:00  MDExOlB1bGxSZXF1ZXN0MjQ2OTExNjIx           230.0
# 4 2019-03-29 06:04:22+00:00  MDExOlB1bGxSZXF1ZXN0MjY1NTk2MTQ2             1.0
#
#   assocPR_state                                      assocPR_title  \
# 0        MERGED                                             update
# 1        MERGED                                             update
# 2        MERGED  fixbug: change readme excuteMission to execute...
# 3        MERGED  fixbug: change readme excuteMission to execute...
# 4        MERGED                                                  1
#
#           assocPR_updatedAt  committer_company committer_author  \
# 0 2019-07-05 06:53:23+00:00                NaN     AlexLiuSheng
# 1 2019-07-05 06:53:23+00:00                NaN     AlexLiuSheng
# 2 2019-01-25 02:39:08+00:00                NaN              NaN
# 3 2019-01-25 02:39:08+00:00                NaN           lxstar
# 4 2019-03-29 06:04:30+00:00                NaN          ALECKLQ
#
#                                            status_id status_state  \
# 0  MDY6U3RhdHVzNjg5ODk3Njg6ZDI5MDRlMDIyYWJjOTVlNm...      FAILURE
# 1                                                NaN          NaN
# 2  MDY6U3RhdHVzNjg5ODk3Njg6YzZjOTI1M2VmYzg3OTlhOT...      FAILURE
# 3  MDY6U3RhdHVzNjg5ODk3Njg6ZjkyMzk5MjA2NWQ0ZmExZm...      FAILURE
# 4  MDY6U3RhdHVzNjg5ODk3Njg6M2RhNjViYzExYWQ5YzU3OG...      FAILURE
#
#           committedDate                                    messageHeadline  \
# 0  2019-04-30T07:46:14Z         #fix# issues #245 #241 #240 #239 #232 #231
# 1  2019-04-30T06:38:14Z         #fix# issues #245 #241 #240 #239 #232 #231
# 2  2019-01-25T02:39:07Z         Merge pull request #230 from lxstar/master
# 3  2019-01-23T10:19:23Z  fixbug: change readme excuteMission to execute...
# 4  2019-01-16T14:28:23Z           fix issues #229 #228 #226 #225 #220 #212
#
#                                         oid
# 0  d2904e022abc95e6f8054dffcceb7aa91f85af13
# 1  0698498f3824a3a627e6712d6be18c266323fa7c
# 2  c6c9253efc8799a90ef94585a1ddd6efd4a9fd5d
# 3  f923992065d4fa1ffa0f7138caddd242feb441b5
# 4  3da65bc11ad9c578a2e8dd725b714fac8ef81b16
