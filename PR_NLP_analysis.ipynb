# %% [markdown]
# ### Read Pickled PR Data
#
# * If the folder `Data/cleaned_PRs` isn't present, then extract `cleaned_PRs_2.zip` into `Data/`

# %%
import os
import string

import nltk
import numpy as np
import pandas as pd

# %%
os.listdir('Data/cleaned_PRs')
# Out:
# ['AE9RB-ruby-redis_pr.pk1',
#  'AlburIvan-SlickForm_pr.pk1',
#  'AlexLiuSheng-CheckVersionLib_pr.pk1',
#  'AllenDowney-ThinkJavaCode_pr.pk1',
#  'Aufree-ESTMusicIndicator_pr.pk1',
#  'Azure-azure-storage-fuse_pr.pk1',
#  'BMIRDS-deepslide_pr.pk1',
#  'BetterCloud-vault-java-driver_pr.pk1',
#  'BurntSushi-quickcheck_pr.pk1',
#  'BycorSanchez-resources_pr.pk1',
#  'CMU-Perceptual-Computing-Lab-openpose_pr.pk1',
#  'CVCalendar-CVCalendar_pr.pk1',
#  'CaoZ-JD-Coin_pr.pk1',
#  'ChrisXu-CXAlertView_pr.pk1',
#  'ClickSimply-Nano-SQL_pr.pk1',
#  'Coalfire-Research-Slackor_pr.pk1',
#  'CollabCodeTech-forum-do-front-ao-end_pr.pk1',
#  'CraneStation-wasmtime_pr.pk1',
#  'CreateJS-EaselJS_pr.pk1',
#  'Crizstian-cinema-microservice_pr.pk1',
#  'Cue-hop_pr.pk1',
#  'DHTMLX-message_pr.pk1',
#  'Deadcows-MyBox_pr.pk1',
#  'DexterInd-GoPiGo_pr.pk1',
#  'EricSteinberger-PokerRL_pr.pk1',
#  'Facepunch-garrysmod_pr.pk1',
#  'FactoryBoy-factory_boy_pr.pk1',
#  'FlingOS-FlingOS_pr.pk1',
#  'FlowingMedia-TimeFlow_pr.pk1',
#  'FooBarWidget-default_value_for_pr.pk1',
#  'GianlucaGuarini-icaro_pr.pk1',
#  'Goingqs-PyramidBox_pr.pk1',
#  'HMBSbige-ShadowsocksR-Windows_pr.pk1',
#  'Hyra-angular-gulp-browserify-livereload-boilerplate_pr.pk1',
#  'Inist-CNRS-node-xml2json-command_pr.pk1',
#  'IsNull-TCBrute_pr.pk1',
#  'JayBizzle-Crawler-Detect_pr.pk1',
#  'JeffPaine-beautiful_idiomatic_python_pr.pk1',
#  'JuliaTPU-XLA.jl_pr.pk1',
#  'KenjiBaheux-css-font-rendering_pr.pk1',
#  'Khan-tinyquery_pr.pk1',
#  'KittenYang-KYGooeyMenu_pr.pk1',
#  'KonradIT-gopro-py-api_pr.pk1',
#  'KubeOperator-KubeOperator_pr.pk1',
#  'L0SG-relational-rnn-pytorch_pr.pk1',
#  'LeEnno-alfred-terminalfinder_pr.pk1',
#  'LeaVerou-prefixfree_pr.pk1',
#  'LinkedDataFragments-Server.js_pr.pk1',
#  'MIT-LCP-wfdb-python_pr.pk1',
#  'MSch-devise-twitter_pr.pk1',
#  'MadsAlbertsen-multi-metagenome_pr.pk1',
#  'MarioIannotta-SplitViewDragAndDrop_pr.pk1',
#  'MarioRicalde-SCSS.tmbundle_pr.pk1',
#  'MegaMark16-django-live-support_pr.pk1',
#  'MiSTer-devel-Main_MiSTer_pr.pk1',
#  'MinecraftForge-MinecraftForge_pr.pk1',
#  'ModelOriented-DrWhy_pr.pk1',
#  'MorganZhang100-zhihu-spider_pr.pk1',
#  'MvvmCross-MvvmCross_pr.pk1',
#  'MyBotRun-MyBot_pr.pk1',
#  'NixOS-nix_pr.pk1',
#  'Notos-seedbox-from-scratch_pr.pk1',
#  'OYsun-VueCircleMenu_pr.pk1',
#  'OfficeDev-script-lab_pr.pk1',
#  'OfflineIMAP-offlineimap_pr.pk1',
#  'OpenBankProject-OBP-API_pr.pk1',
#  'OzzyCzech-icalparser_pr.pk1',
#  'PAIR-code-saliency_pr.pk1',
#  'Peternator7-strum_pr.pk1',
#  'Phrogz-riblits_pr.pk1',
#  'RamonGebben-Cquence_pr.pk1',
#  'Ramotion-direct-select-android_pr.pk1',
#  'React-Scope-React-Scope_pr.pk1',
#  'ResultadosDigitais-matrix_pr.pk1',
#  'Roave-Dont_pr.pk1',
#  'Rob--W-cors-anywhere_pr.pk1',
#  'SIPfoundry-legacy-sipxecs_pr.pk1',
#  'ShenYujun-InterFaceGAN_pr.pk1',
#  'Shinpeim-introduction-to-git_pr.pk1',
#  'Smilexuhc-Data-Competition-TopSolution_pr.pk1',
#  'Stampie-Stampie_pr.pk1',
#  'SublimeText-VBScript_pr.pk1',
#  'SunboX-Php-Web-Application-Installer_pr.pk1',
#  'TAMUArch-cookbook.windows_ad_pr.pk1',
#  'TGAC-KAT_pr.pk1',
#  'Tencent-weui-wxss_pr.pk1',
#  'TimPietrusky-weloveiconfonts_pr.pk1',
#  'ToDou-nestrefresh_pr.pk1',
#  'Tom-Alexander-regression-js_pr.pk1',
#  'TooTallNate-node-proxy-agent_pr.pk1',
#  'TooTallNate-ref_pr.pk1',
#  'TypeStrong-tsify_pr.pk1',
#  'Unity-Technologies-guid-based-reference_pr.pk1',
#  'Viacheslav-Radchenko-TSUIKit_pr.pk1',
#  'XCSoar-XCSoar_pr.pk1',
#  'XProger-OpenLara_pr.pk1',
#  'Yalantis-Phoenix_pr.pk1',
#  'Yi-Lyu-Migrating-from-PHP5.6.x-to-PHP7.0.x_pr.pk1',
#  'ZhaoJ9014-Dynamic-Conditional-Networks.PyTorch_pr.pk1',
#  'acrosa-kafka-rb_pr.pk1',
#  'adafruit-Adafruit_MintyBoost_PCB_pr.pk1',
#  'adafruit-MAX6675-library_pr.pk1',
#  'addywaddy-jquery.tagcloud.js_pr.pk1',
#  'adereth-dactyl-keyboard_pr.pk1',
#  'admiralobvious-flask-mysqldb_pr.pk1',
#  'adrianhall-restaurant-reviews_pr.pk1',
#  'agibsonsw-AndySublime_pr.pk1',
#  'agrison-harpoon_pr.pk1',
#  'ahobson-ruby-pcap_pr.pk1',
#  'airalab-hs-web3_pr.pk1',
#  'aivis-PHP-file-upload-class_pr.pk1',
#  'akveo-blur-admin_pr.pk1',
#  'alanbsmith-react-electron-starter_pr.pk1',
#  'alanszlosek-dbFacile_pr.pk1',
#  'alexcrichton-cc-rs_pr.pk1',
#  'alfajango-jquery-dynatable_pr.pk1',
#  'alicelieutier-smoothScroll_pr.pk1',
#  'alizahid-slinky_pr.pk1',
#  'all-contributors-all-contributors-bot_pr.pk1',
#  'alphazero-Go-Redis_pr.pk1',
#  'amberbit-xmp_pr.pk1',
#  'andersbll-neural_artistic_style_pr.pk1',
#  'andrewroycarter-UIView-Helpers_pr.pk1',
#  'andygrunwald-go-gerrit_pr.pk1',
#  'angular-angular-seed_pr.pk1',
#  'apache-incubator-echarts_pr.pk1',
#  'apachecn-Interview_pr.pk1',
#  'apjs-ReactVelocity_pr.pk1',
#  'apla-me.apla.cordova.app-preferences_pr.pk1',
#  'apngasm-apngasm_pr.pk1',
#  'apollographql-eslint-plugin-graphql_pr.pk1',
#  'apollographql-persistgraphql_pr.pk1',
#  'aqui18-purescript-three_pr.pk1',
#  'arguiot-Descartes_pr.pk1',
#  'army8735-jsdc_pr.pk1',
#  'artem-oppermann-Deep-Autoencoders-For-Collaborative-Filtering_pr.pk1',
#  'artha42-mm-versionable_pr.pk1',
#  'artonomous-artonomous-mvp_pr.pk1',
#  'arx-deidentifier-arx_pr.pk1',
#  'aschmelyun-larametrics_pr.pk1',
#  'askn-crystal-by-example_pr.pk1',
#  'astaxie-godoc_pr.pk1',
#  'astorfi-speechpy_pr.pk1',
#  'atom-material-atom-material-ui_pr.pk1',
#  'auth0-blog-angular-token-auth_pr.pk1',
#  'avdi-nulldb_pr.pk1',
#  'axetroy-sms-boom_pr.pk1',
#  'azat-co-node-patterns_pr.pk1',
#  'aziz-GoogleReader-OSXLionUI_pr.pk1',
#  'badunk-multer-s3_pr.pk1',
#  'baidu-brpc-java_pr.pk1',
#  'balde-balde_pr.pk1',
#  'banker-mongulator_pr.pk1',
#  'bartTC-django-markup_pr.pk1',
#  'baudm-mplayer.py_pr.pk1',
#  'beego-bee_pr.pk1',
#  'beeker1121-exit-intent-popup_pr.pk1',
#  'bemoss-BEMOSS3.5_pr.pk1',
#  'benpickles-js-model_pr.pk1',
#  'bernii-gauge.js_pr.pk1',
#  'binarylogic-settingslogic_pr.pk1',
#  'bintray-bintray-examples_pr.pk1',
#  'biqing-MessengerJS_pr.pk1',
#  'bkw-node-dronestream_pr.pk1',
#  'bmkmanoj-js-by-examples_pr.pk1',
#  'bookshelf-bookshelf_pr.pk1',
#  'briot-geneapro_pr.pk1',
#  'brutella-hkcam_pr.pk1',
#  'bryanjos-geo_pr.pk1',
#  'bufferapp-AdaptableBottomNavigation_pr.pk1',
#  'builtwithluv-ZenFocus_pr.pk1',
#  'burke-software-django-report-builder_pr.pk1',
#  'bytedance-xgplayer_pr.pk1',
#  'cSploit-android_pr.pk1',
#  'caffeinated-shinobi_pr.pk1',
#  'capitalone-react-native-pathjs-charts_pr.pk1',
#  'captainhammy-Houdini-Toolbox_pr.pk1',
#  'cask-cask_pr.pk1',
#  'castaway-dbix-class-book_pr.pk1',
#  'cbd-edis_pr.pk1',
#  'cemmanouilidis-naturalscrolling_pr.pk1',
#  'cferdinandi-reef_pr.pk1',
#  'chinese-poetry-chinese-poetry_pr.pk1',
#  'chnm-anthologize_pr.pk1',
#  'chrippa-ds4drv_pr.pk1',
#  'chrisdonahue-nesmdb_pr.pk1',
#  'chrisdunelm-DotNetAnywhere_pr.pk1',
#  'christkv-node-git_pr.pk1',
#  'christoomey-vim-tmux-navigator_pr.pk1',
#  'citusdata-postgresql-hll_pr.pk1',
#  'cloudfavorites-favorites-web_pr.pk1',
#  'cloudwu-lua-trace_pr.pk1',
#  'clue-php-commander_pr.pk1',
#  'cmf-psiviewer_pr.pk1',
#  'cnsnake11-blog_pr.pk1',
#  'codepath-android_guides_pr.pk1',
#  'container-interop-container-interop_pr.pk1',
#  'contentsync-SketchContentSync_pr.pk1',
#  'cookpad-garage_pr.pk1',
#  'coolbeet-CBStoreHouseTransition_pr.pk1',
#  'coreylynch-async-rl_pr.pk1',
#  'corkami-pics_pr.pk1',
#  'cornelltech-product-studio_pr.pk1',
#  'creativetimofficial-material-dashboard_pr.pk1',
#  'crossbario-crossbar-examples_pr.pk1',
#  'csete-qthid_pr.pk1',
#  'curiousdannii-ifvms.js_pr.pk1',
#  'cxs-css-cxs_pr.pk1',
#  'cyq1162-cyqdata_pr.pk1',
#  'dabit3-aws-appsync-react-workshop_pr.pk1',
#  'daenerys-sre-source_pr.pk1',
#  'danburkert-memmap-rs_pr.pk1',
#  'danwrong-liquid-inheritance_pr.pk1',
#  'davetcoleman-moveit_simple_grasps_pr.pk1',
#  'dberesford-exiv2node_pr.pk1',
#  'dborzov-lsp_pr.pk1',
#  'ddollar-heroku-buildpack-apt_pr.pk1',
#  'debezium-debezium-examples_pr.pk1',
#  'defunkt-coffee-mode_pr.pk1',
#  'defunkt-unicorn_pr.pk1',
#  'dermusikman-sonicpi.vim_pr.pk1',
#  'developit-preact-redux_pr.pk1',
#  'devilist-AdvancedTextView_pr.pk1',
#  'devinsays-portfolio-press_pr.pk1',
#  'dfm-emcee_pr.pk1',
#  'distributed-system-analysis-smallfile_pr.pk1',
#  'djfly-dcms2_pr.pk1',
#  'djpate-jTag_pr.pk1',
#  'dmaclay-python-smpp_pr.pk1',
#  'docker-docker-py_pr.pk1',
#  'dockerfiles-django-uwsgi-nginx_pr.pk1',
#  'dotnet-iot_pr.pk1',
#  'dotnet-websharper-core_pr.pk1',
#  'drawpile-Drawpile_pr.pk1',
#  'drewconway-ML-Email-Code_pr.pk1',
#  'dvdhrm-xwiimote_pr.pk1',
#  'dwilhelm89-LeafletSlider_pr.pk1',
#  'edavis10-redmine_rate_pr.pk1',
#  'editorconfig-editorconfig_pr.pk1',
#  'edmund-huber-ergonomadic_pr.pk1',
#  'education-classroom_pr.pk1',
#  'eggjs-awesome-egg_pr.pk1',
#  'eholk-harlan_pr.pk1',
#  'ejeschke-ginga_pr.pk1',
#  'ember-links-list_pr.pk1',
#  'emberjs-rfcs_pr.pk1',
#  'envato-safe_shell_pr.pk1',
#  'epuzanov-ZenPacks.community.DistributedCollectors_pr.pk1',
#  'equinor-pylops_pr.pk1',
#  'eric2003-OneFLOW_pr.pk1',
#  'ericclemmons-webpack-hot-server-example_pr.pk1',
#  'eriwen-lcov-to-cobertura-xml_pr.pk1',
#  'ermalkaleci-CarbonKit_pr.pk1',
#  'esl-lhttpc_pr.pk1',
#  'espes-MacTerrariaWrapper_pr.pk1',
#  'esterTion-Youku-HTML5-Player_pr.pk1',
#  'etsy-411_pr.pk1',
#  'exercism-typescript_pr.pk1',
#  'existentialmutt-lt-ruby_pr.pk1',
#  'fabiofalci-sconsify_pr.pk1',
#  'fabric-patchwork_pr.pk1',
#  'facebook-proxygen_pr.pk1',
#  'facebook-react-360_pr.pk1',
#  'facebookresearch-luckmatters_pr.pk1',
#  'farizrahman4u-recurrentshop_pr.pk1',
#  'felis-USB_Host_Shield_2.0_pr.pk1',
#  'felixrieseberg-windows-development-environment_pr.pk1',
#  'fengyuanchen-compressorjs_pr.pk1',
#  'fhoenig-Kellner_pr.pk1',
#  'filecoin-project-go-filecoin_pr.pk1',
#  'firecracker-microvm-firecracker-go-sdk_pr.pk1',
#  'flexdinesh-npm-module-boilerplate_pr.pk1',
#  'florent37-KotlinPleaseAnimate_pr.pk1',
#  'foradian-fluxday_pr.pk1',
#  'foundweekends-pamflet_pr.pk1',
#  'frank-fs-frank_pr.pk1',
#  'franzinc-aserve_pr.pk1',
#  'frogermcs-InstaMaterial_pr.pk1',
#  'fsjohnhuang-iPromise_pr.pk1',
#  'gajus-redux-immutable_pr.pk1',
#  'gajus-usus_pr.pk1',
#  'gchp-rustbox_pr.pk1',
#  'gentilkiwi-mimikatz_pr.pk1',
#  'georust-geo_pr.pk1',
#  'gferreira-hTools2_pr.pk1',
#  'giginet-Crossroad_pr.pk1',
#  'gilbox-css-bliss_pr.pk1',
#  'github-balanced-employee-ip-agreement_pr.pk1',
#  'github-enable-security-alerts-sample_pr.pk1',
#  'github-pengge-PyTorch-progressive_growing_of_gans_pr.pk1',
#  'gkopff-gson-jodatime-serialisers_pr.pk1',
#  'go-joe-joe_pr.pk1',
#  'go-llvm-llgo_pr.pk1',
#  'go-martini-martini_pr.pk1',
#  'gogo2-npp-darcula_pr.pk1',
#  'google-codeworld_pr.pk1',
#  'google-keytransparency_pr.pk1',
#  'google-security-research-pocs_pr.pk1',
#  'grahamscott-pusherrestdotnet_pr.pk1',
#  'graphite-project-graphite-web_pr.pk1',
#  'graphql-rust-graphql-client_pr.pk1',
#  'greatseth-mediainfo_pr.pk1',
#  'green-arrow-react-firestore_pr.pk1',
#  'grncdr-merge-stream_pr.pk1',
#  'gu-fan-riv.vim_pr.pk1',
#  'guanguans-notes_pr.pk1',
#  'gzc-CLRS_pr.pk1',
#  'halfninja-android-ffmpeg-x264_pr.pk1',
#  'haqiqiw-react-native-slideshow_pr.pk1',
#  'hardphp-tp5-api_pr.pk1',
#  'hashivim-vim-terraform_pr.pk1',
#  'hhblaze-DBreeze_pr.pk1',
#  'hipchat-hipchat-rb_pr.pk1',
#  'hipchat-hubot-hipchat_pr.pk1',
#  'hober-planet.emacsen.org_pr.pk1',
#  'hoisted-hoisted_pr.pk1',
#  'huanxsd-MeiTuan_pr.pk1',
#  'huge-success-sanic-openapi_pr.pk1',
#  'humhub-humhub_pr.pk1',
#  'hyper0x-awesome-go-China_pr.pk1',
#  'i8ramin-fb-menu_pr.pk1',
#  'iamtrask-Docs_pr.pk1',
#  'icanzilb-EasyAnimation_pr.pk1',
#  'ijoshsmith-json2swift_pr.pk1',
#  'imagemin-imagemin-mozjpeg_pr.pk1',
#  'immerjs-immer_pr.pk1',
#  'infosecn1nja-AD-Attack-Defense_pr.pk1',
#  'inoutcode-ethereum_book_pr.pk1',
#  'ipjohnson-Grace_pr.pk1',
#  'ivankorobkov-python-inject_pr.pk1',
#  'jaliss-securesocial_pr.pk1',
#  'jasonfb-nondestructive_migrations_pr.pk1',
#  'javalite-activejdbc_pr.pk1',
#  'javan-whenever_pr.pk1',
#  'javieryanez-nodemcu-modules_pr.pk1',
#  'jayshah19949596-CodingInterviews_pr.pk1',
#  'jbutz-bootstrap-lightbox_pr.pk1',
#  'jcalazan-ansible-django-stack_pr.pk1',
#  'jeffbski-bench-rest_pr.pk1',
#  'jeffellis-grails-yammer-metrics_pr.pk1',
#  'jeffijoe-awilix_pr.pk1',
#  'jekor-vocabulink_pr.pk1',
#  'jeromeetienne-virtualjoystick.js_pr.pk1',
#  'jerrykrinock-CategoriesObjC_pr.pk1',
#  'jevinskie-mDNSResponder_pr.pk1',
#  'jfox015-Bonfire-News_pr.pk1',
#  'jgoodall-us-maps_pr.pk1',
#  'ji4ozhu-kkcap_pr.pk1',
#  'jimuyouyou-node-interview-questions_pr.pk1',
#  'jinfagang-tensorflow_poems_pr.pk1',
#  'jlipps-yiewd_pr.pk1',
#  'jlooper-elocute_pr.pk1',
#  'jmarnold-EmbeddedMail_pr.pk1',
#  'jobertabma-recon.sh_pr.pk1',
#  'joelparkerhenderson-architecture_decision_record_pr.pk1',
#  'joewalker-gcli_pr.pk1',
#  'jondwillis-AChartEngine_pr.pk1',
#  'joshwcomeau-panther_pr.pk1',
#  'jre2-JapaneseStudy_pr.pk1',
#  'jsonform-jsonform_pr.pk1',
#  'jsuereth-scala-arm_pr.pk1',
#  'jubalm-grunt-fontello_pr.pk1',
#  'juhanurmi-ahmia_pr.pk1',
#  'julien-c-Circular_pr.pk1',
#  'jupyterhub-kubespawner_pr.pk1',
#  'justdeleteme-justdelete.me_pr.pk1',
#  'justquick-django-math-captcha_pr.pk1',
#  'jvilk-BrowserFS_pr.pk1',
#  'jwaliszko-ExpressiveAnnotations_pr.pk1',
#  'karlseguin-parse-dotnet_pr.pk1',
#  'keijiro-DepthInverseProjection_pr.pk1',
#  'keirf-FlashFloppy_pr.pk1',
#  'kelseyhightower-kubernetes-the-hard-way_pr.pk1',
#  'kelthuzadx-hosts_pr.pk1',
#  'kentcdodds-airtable-netlify-short-urls_pr.pk1',
#  'kettanaito-atomic-layout_pr.pk1',
#  'kevin1024-pytest-httpbin_pr.pk1',
#  'kewlbear-FFmpeg-iOS-build-script_pr.pk1',
#  'kiooeht-ModTheSpire_pr.pk1',
#  'kitao-divsugar_pr.pk1',
#  'kiwanami-emacs-widget-mvc_pr.pk1',
#  'kizitonwose-CalendarView_pr.pk1',
#  'koajs-koa_pr.pk1',
#  'kovasb-gamma_pr.pk1',
#  'kpavlov-jreactive-8583_pr.pk1',
#  'kpzhang93-MTCNN_face_detection_alignment_pr.pk1',
#  'kriskbx-whatsapp-sharing_pr.pk1',
#  'kyleshank-apt-transport-s3_pr.pk1',
#  'kyow-tfidf_ja_pr.pk1',
#  'lancejpollard-authlogic-connect_pr.pk1',
#  'laramies-theHarvester_pr.pk1',
#  'leafo-pgmoon_pr.pk1',
#  'lericson-simples3_pr.pk1',
#  'letrunghieu-active_pr.pk1',
#  'leungwensen-svg-icon_pr.pk1',
#  'libratbag-libratbag_pr.pk1',
#  'lifechurch-k8s-deploy-helper_pr.pk1',
#  'lightszero-LSharp_pr.pk1',
#  'lingej-pnp4nagios_pr.pk1',
#  'linkedin-parseq_pr.pk1',
#  'linq2db-linq2db_pr.pk1',
#  'liuzhiyi1992-ZYCornerRadius_pr.pk1',
#  'llSourcell-Learn_Computer_Science_in_5_Months_pr.pk1',
#  'lmller-gof-in-kotlin_pr.pk1',
#  'lo-th-Oimo.js_pr.pk1',
#  'lybenson-bilibili-vue_pr.pk1',
#  'm2ym-optima_pr.pk1',
#  'mafintosh-polo_pr.pk1',
#  'mageplus-mageplus_pr.pk1',
#  'maguowei-gotok8s_pr.pk1',
#  'major-cis-rhel-ansible_pr.pk1',
#  'malihu-malihu-custom-scrollbar-plugin_pr.pk1',
#  'marcelklehr-changesets_pr.pk1',
#  'mariogeiger-se3cnn_pr.pk1',
#  'martijnversluis-ChordSheetJS_pr.pk1',
#  'matadon-mizuno_pr.pk1',
#  'matiassingers-awesome-slack_pr.pk1',
#  'matteocrippa-awesome-swift_pr.pk1',
#  'matteofigus-awesome-speaking_pr.pk1',
#  'matthaywardwebdesign-node-security_pr.pk1',
#  'mattlewis92-angular-calendar_pr.pk1',
#  'maxlicheng-luci-app-unblockmusic_pr.pk1',
#  'mazen160-Firefox-Security-Toolkit_pr.pk1',
#  'mbbill-undotree_pr.pk1',
#  'mcedit-pymclevel_pr.pk1',
#  'mcmilk-7-Zip-zstd_pr.pk1',
#  'mediamonks-tilt-game-android_pr.pk1',
#  'mekarpeles-captcha-decoder_pr.pk1',
#  'metajack-strophejs-plugins_pr.pk1',
#  'mher-node-celery_pr.pk1',
#  'michaeldorner-BeeTee_pr.pk1',
#  'michaelliao-learn-python_pr.pk1',
#  'michalkonturek-GraphKit_pr.pk1',
#  'micheleg-dash-to-dock_pr.pk1',
#  'microsoft-Office-Online-Test-Tools-and-Documentation_pr.pk1',
#  'microsoft-WinObjC_pr.pk1',
#  'microsoft-vs4mac-labs_pr.pk1',
#  'mike-bourgeous-cliserver_pr.pk1',
#  'mikebuss-MTBBarcodeScanner_pr.pk1',
#  'mikenz-twitter-text-php_pr.pk1',
#  'mikeryan-crackle_pr.pk1',
#  'mini-mpvue-mpvue-douban_pr.pk1',
#  'minimaxir-automl-gs_pr.pk1',
#  'minimaxir-person-blocker_pr.pk1',
#  'minishift-minishift_pr.pk1',
#  'mixitconf-mixit_pr.pk1',
#  'miyagawa-CGI-Compile_pr.pk1',
#  'miyagawa-Tatsumaki_pr.pk1',
#  'mkeeter-antimony_pr.pk1',
#  'mmatl-pyrender_pr.pk1',
#  'mo-abortcontroller-polyfill_pr.pk1',
#  'mob-sakai-UIEffect_pr.pk1',
#  'mobfarm-FastPdfKit_pr.pk1',
#  'mojombo-bert.erl_pr.pk1',
#  'mojs-mojs_pr.pk1',
#  'morgoth-alexa_pr.pk1',
#  'mostjs-core_pr.pk1',
#  'mseitzer-pytorch-fid_pr.pk1',
#  'mseknibilel-OpenStack-Grizzly-Install-Guide_pr.pk1',
#  'mtonio91-AMSmoothAlert_pr.pk1',
#  'mururu-elixir-build_pr.pk1',
#  'mustache-mustache.github.com_pr.pk1',
#  'mxbi-mlcrate_pr.pk1',
#  'mycelium-com-wallet-android_pr.pk1',
#  'myshov-awesome-mobile-web-development_pr.pk1',
#  'mysqludf-lib_mysqludf_sys_pr.pk1',
#  'mystor-rust-cpp_pr.pk1',
#  'nZEDb-nZEDb_pr.pk1',
#  'nagadomi-lbpcascade_animeface_pr.pk1',
#  'nayuki-Project-Euler-solutions_pr.pk1',
#  'net-ssh-net-ssh_pr.pk1',
#  'newyjp-JPVideoPlayer_pr.pk1',
#  'nicolasbeauvais-vue-social-sharing_pr.pk1',
#  'nicothin-idiomatic-pre-CSS_pr.pk1',
#  'nightscout-cgm-remote-monitor_pr.pk1',
#  'ninjaprox-NVBnbCollectionView_pr.pk1',
#  'njtierney-naniar_pr.pk1',
#  'nmsdvid-ie-alert_pr.pk1',
#  'nntuyen-text-decorator_pr.pk1',
#  'nodebots-nodebotsday_pr.pk1',
#  'nodemcu-nodemcu-firmware_pr.pk1',
#  'notracking-hosts-blocklists_pr.pk1',
#  'nst-objc_strings_pr.pk1',
#  'nuxeo-nuxeo_pr.pk1',
#  'o1298098-Flutter-Movie_pr.pk1',
#  'oakes-SolidOak_pr.pk1',
#  'okteto-okteto_pr.pk1',
#  'oleksiyk-kafka_pr.pk1',
#  'oliverschwarz-php-excel_pr.pk1',
#  'olofd-react-native-photos-framework_pr.pk1',
#  'olucurious-PyFCM_pr.pk1',
#  'onejgordon-flow-dashboard_pr.pk1',
#  'onyxfish-invar_pr.pk1',
#  'openSUSE-osem_pr.pk1',
#  'opengl-tutorials-ogl_pr.pk1',
#  'opentelecoms-org-jsmpp_pr.pk1',
#  'opentracing-contrib-nginx-opentracing_pr.pk1',
#  'opentripplanner-OpenTripPlanner_pr.pk1',
#  'orpheus-db-implementation_pr.pk1',
#  'orta-cocoapods-keys_pr.pk1',
#  'outflanknl-Dumpert_pr.pk1',
#  'overboming-ZCAnimatedLabel_pr.pk1',
#  'owensd-json-swift_pr.pk1',
#  'padelt-temper-python_pr.pk1',
#  'pazguille-shuffle-array_pr.pk1',
#  'perfectline-validates_url_pr.pk1',
#  'philiplaureano-Hiro_pr.pk1',
#  'pi-hole-pi-hole_pr.pk1',
#  'picturepan2-devices.css_pr.pk1',
#  'playframework-anorm_pr.pk1',
#  'pomerium-awesome-zero-trust_pr.pk1',
#  'postlight-headless-wp-starter_pr.pk1',
#  'pqina-react-filepond_pr.pk1',
#  'pre-commit-pre-commit_pr.pk1',
#  'probml-pmtk3_pr.pk1',
#  'puma-puma-dev_pr.pk1',
#  'puppetlabs-lumogon_pr.pk1',
#  'pusher-pusher-angular_pr.pk1',
#  'q1x-zabbix-gnomes_pr.pk1',
#  'qiyeboy-SpiderBook_pr.pk1',
#  'qutebrowser-qutebrowser_pr.pk1',
#  'r0man-oauth-clj_pr.pk1',
#  'rabchev-brackets-server_pr.pk1',
#  'raccy-japanese-wrap_pr.pk1',
#  'rafalp-Misago_pr.pk1',
#  'railslove-rack-tracker_pr.pk1',
#  'ralph-group-pymeasure_pr.pk1',
#  'ramitsurana-awesome-kubernetes_pr.pk1',
#  'rancher-k3os_pr.pk1',
#  'randyjensen-handcrafted-wp-theme_pr.pk1',
#  'ravendb-ravendb.contrib_pr.pk1',
#  'rgeo-rgeo-shapefile_pr.pk1',
#  'ricardojmendez-UnitySteerExamples_pr.pk1',
#  'richardbarran-django-photologue_pr.pk1',
#  'rigoneri-syte_pr.pk1',
#  'ritschwumm-xsbt-webstart_pr.pk1',
#  'rmt-pyinputevent_pr.pk1',
#  'rnewson-couchdb-lucene_pr.pk1',
#  'rngtng-launchpad_pr.pk1',
#  'robb0wen-tornis_pr.pk1',
#  'rosado-clj-processing_pr.pk1',
#  'rs-cors_pr.pk1',
#  'rsms-scrup_pr.pk1',
#  'rumpkernel-wiki_pr.pk1',
#  'rwl-PyCIM_pr.pk1',
#  'ryoyakawai-WebMIDIAPIWrapper_pr.pk1',
#  'samuelbirch-MultiBox_pr.pk1',
#  'satorumurmur-bibi_pr.pk1',
#  'savonrb-akami_pr.pk1',
#  'scala-pickling_pr.pk1',
#  'sciactive-pnotify_pr.pk1',
#  'scikit-learn-contrib-boruta_py_pr.pk1',
#  'sensepost-gowitness_pr.pk1',
#  'sethlilly-Vapor_pr.pk1',
#  'shenweichen-DeepCTR_pr.pk1',
#  'shivamMg-ppds_pr.pk1',
#  'simos-keyboardlayouteditor_pr.pk1',
#  'sindresorhus-clipboardy_pr.pk1',
#  'skorokithakis-python-fuse-sample_pr.pk1',
#  'skuroda-FindKeyConflicts_pr.pk1',
#  'skyhee-Algorithms-Learning-With-Go_pr.pk1',
#  'skyhover-Deckard_pr.pk1',
#  'skywalker512-FlarumChina_pr.pk1',
#  'slugify-slugify_pr.pk1',
#  'soegaard-minipascal_pr.pk1',
#  'sonicretro-s1disasm_pr.pk1',
#  'soufianesakhi-feedly-filtering-and-sorting_pr.pk1',
#  'spatie-searchindex_pr.pk1',
#  'spaze-jakobejitblokaci.cz_pr.pk1',
#  'splewis-csgo-multi-1v1_pr.pk1',
#  'spree-contrib-spree_social_pr.pk1',
#  'sqlcollaborative-dbatools_pr.pk1',
#  'sskodje-wpfchrometabs-mvvm_pr.pk1',
#  'stackmagic-bitly-api-client_pr.pk1',
#  'steadicat-react-rebound_pr.pk1']

# %%
# Read all pk1 PR files from Data/cleaned_PRs
pickled_dirs = []
repo_names = []
for file in os.listdir('Data/cleaned_PRs'):
    try:
        pickled_dirs.append('Data/cleaned_PRs/'+file)
        repo_names.append(file.rstrip('_pr.pk1'))
    except:
        print('NO PULL REQUEST DATA IN: ', file)
        continue

print('\nFile Paths\n', pickled_dirs[:20])
print('\nRepo Names\n', repo_names[:20])
# Out:
# File Paths
#  ['Data/cleaned_PRs/AE9RB-ruby-redis_pr.pk1', 'Data/cleaned_PRs/AlburIvan-SlickForm_pr.pk1', 'Data/cleaned_PRs/AlexLiuSheng-CheckVersionLib_pr.pk1', 'Data/cleaned_PRs/AllenDowney-ThinkJavaCode_pr.pk1', 'Data/cleaned_PRs/Aufree-ESTMusicIndicator_pr.pk1', 'Data/cleaned_PRs/Azure-azure-storage-fuse_pr.pk1', 'Data/cleaned_PRs/BMIRDS-deepslide_pr.pk1', 'Data/cleaned_PRs/BetterCloud-vault-java-driver_pr.pk1', 'Data/cleaned_PRs/BurntSushi-quickcheck_pr.pk1', 'Data/cleaned_PRs/BycorSanchez-resources_pr.pk1', 'Data/cleaned_PRs/CMU-Perceptual-Computing-Lab-openpose_pr.pk1', 'Data/cleaned_PRs/CVCalendar-CVCalendar_pr.pk1', 'Data/cleaned_PRs/CaoZ-JD-Coin_pr.pk1', 'Data/cleaned_PRs/ChrisXu-CXAlertView_pr.pk1', 'Data/cleaned_PRs/ClickSimply-Nano-SQL_pr.pk1', 'Data/cleaned_PRs/Coalfire-Research-Slackor_pr.pk1', 'Data/cleaned_PRs/CollabCodeTech-forum-do-front-ao-end_pr.pk1', 'Data/cleaned_PRs/CraneStation-wasmtime_pr.pk1', 'Data/cleaned_PRs/CreateJS-EaselJS_pr.pk1', 'Data/cleaned_PRs/Crizstian-cinema-microservice_pr.pk1']
#
# Repo Names
#  ['AE9RB-ruby-redis', 'AlburIvan-SlickForm', 'AlexLiuSheng-CheckVersionLib', 'AllenDowney-ThinkJavaCode', 'Aufree-ESTMusicIndicato', 'Azure-azure-storage-fuse', 'BMIRDS-deepslide', 'BetterCloud-vault-java-drive', 'BurntSushi-quickchec', 'BycorSanchez-resources', 'CMU-Perceptual-Computing-Lab-openpose', 'CVCalendar-CVCalenda', 'CaoZ-JD-Coin', 'ChrisXu-CXAlertView', 'ClickSimply-Nano-SQL', 'Coalfire-Research-Slacko', 'CollabCodeTech-forum-do-front-ao-end', 'CraneStation-wasmtime', 'CreateJS-EaselJS', 'Crizstian-cinema-microservice']

# %%
# Unpickle PR files
df_list = [pd.read_pickle(pickled_df) for pickled_df in pickled_dirs]

# %%
# View two PR DataFrames
df_list[6].head()
# Out:
#   authorAssociation                                           bodyText  \
# 0      COLLABORATOR                                  …a single method.
# 1      COLLABORATOR
# 2       CONTRIBUTOR  The withRetries() method is on the Vault class...
# 3       CONTRIBUTOR                  Missed a spot in my prior PR.  :(
# 4       CONTRIBUTOR                                           Fixes #8
#
#                    closedAt  \
# 0 2016-01-17 21:21:05+00:00
# 1 2016-01-17 23:40:39+00:00
# 2 2016-03-01 16:37:31+00:00
# 3 2016-03-01 16:37:46+00:00
# 4 2016-03-20 01:07:26+00:00
#
#                                             comments  \
# 0                     {'totalCount': 0, 'nodes': []}
# 1                     {'totalCount': 0, 'nodes': []}
# 2  {'totalCount': 1, 'nodes': [{'author': {'login...
# 3  {'totalCount': 1, 'nodes': [{'author': {'login...
# 4                     {'totalCount': 0, 'nodes': []}
#
#                   createdAt                           resourcePath   state  \
# 0 2016-01-17 21:20:38+00:00  /BetterCloud/vault-java-driver/pull/1  MERGED
# 1 2016-01-17 23:40:20+00:00  /BetterCloud/vault-java-driver/pull/2  MERGED
# 2 2016-03-01 04:31:45+00:00  /BetterCloud/vault-java-driver/pull/3  MERGED
# 3 2016-03-01 04:35:43+00:00  /BetterCloud/vault-java-driver/pull/4  MERGED
# 4 2016-03-19 18:40:03+00:00  /BetterCloud/vault-java-driver/pull/9  MERGED
#
#                                                title  \
# 0  Modifies REST client to use per-verb methods, ...
# 1  Adds stubs for 'put' and 'delete' ops in REST ...
# 2        Fix position of withRetries() in call chain
# 3        Fix position of withRetries() in call chain
# 4  Keys with null values cause UnsupportedOperati...
#
#                   updatedAt         author        company  files  \
# 0 2016-01-17 21:21:05+00:00  steve-perkins  @BetterCloud       3
# 1 2016-01-17 23:40:39+00:00  steve-perkins  @BetterCloud       6
# 2 2016-03-01 16:37:37+00:00    happybob007           None      1
# 3 2016-03-01 16:37:51+00:00    happybob007           None      1
# 4 2016-03-20 01:07:26+00:00      kunickiaj   @streamsets       2
#
#            mergedBy
# 0  steve-perkins-bc
# 1  steve-perkins-bc
# 2  steve-perkins-bc
# 3  steve-perkins-bc
# 4     steve-perkins

# %% [markdown]
# ---------------
# ### Collect Text Data & Tokenize

# %%
# Columns of text data
text_cols = ['bodyText', 'comments', 'title']

# Sample from df_list
sample_df = df_list[6]

sample_df[text_cols].head()
# Out:
#                                             bodyText  \
# 0                                  …a single method.
# 1
# 2  The withRetries() method is on the Vault class...
# 3                  Missed a spot in my prior PR.  :(
# 4                                           Fixes #8
#
#                                             comments  \
# 0                     {'totalCount': 0, 'nodes': []}
# 1                     {'totalCount': 0, 'nodes': []}
# 2  {'totalCount': 1, 'nodes': [{'author': {'login...
# 3  {'totalCount': 1, 'nodes': [{'author': {'login...
# 4                     {'totalCount': 0, 'nodes': []}
#
#                                                title
# 0  Modifies REST client to use per-verb methods, ...
# 1  Adds stubs for 'put' and 'delete' ops in REST ...
# 2        Fix position of withRetries() in call chain
# 3        Fix position of withRetries() in call chain
# 4  Keys with null values cause UnsupportedOperati...

# %%
# Check NLTK's tokenization
bodyText_obs = sample_df['bodyText'].values.tolist()
bodyText_tokens = []

for obs in bodyText_obs:
    # Remove punctuation
    for punct in string.punctuation:
        obs = obs.replace(punct, '')

    sent = nltk.sent_tokenize(obs)
    
    for words in sent:
        bodyText_tokens.append(nltk.word_tokenize(words))

# %%
print(bodyText_tokens[0], bodyText_tokens[-1])
# Out:
# ['…a', 'single', 'method'] ['Unclear', 'if', 'this', 'is', 'wanted', 'but', 'here', 'is', 'my', 'suggestion', 'of', 'a', 'zerodep', 'idiomatic', 'proxy', 'support', 'addition', 'to', 'your', 'API', 'NotesRationale', 'Use', 'of', 'things', 'like', 'proxy', 'properties', 'is', 'kind', 'of', 'bad', 'People', 'who', 'need', 'to', 'use', 'a', 'proxy', 'to', 'access', 'Vault', 'may', 'not', 'want', 'the', 'proxy', 'configuration', 'globally', 'set', 'for', 'the', 'JDK', 'Similarly', 'the', 'current', 'API', 'behaviour', 'of', 'implicitly', 'relying', 'on', 'the', 'ProxySelectorgetDefault', 'through', 'URLopenConnection', 'is', 'rather', 'evil', 'as', 'this', 'means', 'that', 'the', 'only', 'way', 'to', 'control', 'the', 'proxy', 'requires', 'race', 'conditions', 'with', 'other', 'JDK', 'code', 'nevermind', 'that', 'in', 'some', 'cases', 'the', 'JRE', 'permissions', 'may', 'have', 'blocked', 'setProxySelector', 'from', 'the', 'application', 'The', 'JREs', 'Proxy', 'class', 'does', 'not', 'encapsulate', 'proxy', 'authentication', 'but', 'is', 'otherwise', 'sufficiently', 'generic', 'that', 'it', 'should', 'be', 'ok', 'With', 'regards', 'to', 'proxy', 'authentication', 'this', 'can', 'be', 'a', 'tricky', 'problem', 'for', 'example', 'if', 'Kerberos', 'authentication', 'is', 'configured', 'on', 'the', 'proxy', 'For', 'this', 'reason', 'I', 'am', 'suggesting', 'either', 'to', 'leave', 'proxy', 'authentication', 'out', 'first', 'commit', 'on', 'PR', 'or', 'to', 'just', 'expose', 'the', 'ability', 'to', 'configure', 'the', 'ProxyAuthenticate', 'header', 'second', 'commit', 'on', 'PR', 'a', 'fancier', 'solution', 'would', 'be', 'to', 'change', 'the', 'proxyAuth', 'field', 'from', 'a', 'String', 'to', 'a', 'SupplierString', 'to', 'enable', 'perrequest', 'header', 'generation', 'though', 'anyone', 'with', 'that', 'complex', 'a', 'need', 'is', 'probably', 'better', 'off', 'just', 'creating', 'a', 'new', 'Vault', 'instance', 'for', 'each', 'request', 'anyway']

# %% [markdown]
# --------------------
# ### Analyze PR `bodyText` using NLTK's `vader.SentimentIntensityAnalyzer`
#
# For future reference, instead of using Vader, a NaiveBayesClassifier could be trained and used for disparate types of text data.
#
# NLTK docs on both methods: http://www.nltk.org/howto/sentiment.html
#
# Code tutorial for both: https://opensourceforu.com/2016/12/analysing-sentiments-nltk/

# %%
# Perform S.A. on bodyText_tokens
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/joseph/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
def get_unpacked_comments(df):
    '''df is the dataframe you want to extract from. Column_name is what the new column will be named'''
    comment_list = []
    column_list = []

    for thing in df.comments:
        if (thing['totalCount'] != 0):
            for com in thing['nodes']:
                comment_list.append(com['bodyText'])
            column_list.append(comment_list)
            # Reset comments after each row
            comment_list = []
        else:
            column_list.append([])
            
    return column_list

def get_bodyText(df):
    bodyText_obs = df['bodyText'].values.tolist()
    bodyText_tokens = []
    bodyText_sentiment = []
    
    no_sentiment_data = {'neg': np.NaN, 'neu': np.NaN, 'pos': np.NaN, 'compound': np.NaN}
    sid = SentimentIntensityAnalyzer()

    # Vader expects a single string, not a list of tokenized strings
    for obs in bodyText_obs:
        # Remove punctuation
        for punct in string.punctuation:
            obs = obs.replace(punct, '')

        # Tokenize bodyText
        sent = nltk.sent_tokenize(obs)
        bodyText_tokens.append(sent)

        # If there's text: calcualte polarity score, else append NaNs
        if len(sent) > 0:
            polarity_score = sid.polarity_scores(sent[0])
            bodyText_sentiment.append(polarity_score)
        else:
            bodyText_sentiment.append(no_sentiment_data)
            
    # Convert bodyText_sent to pandas df
    sent_df = pd.DataFrame(bodyText_sentiment)

    # Add sentiment columns
    # text_cols = ['bodyText', 'comments', 'title']
    # sentiment_df = df[text_cols]
    sentiment_df = df.copy()
    sentiment_df['bodyText_compound'] = sent_df['compound']
    sentiment_df['bodyText_pos'] = sent_df['pos']
    sentiment_df['bodyText_neu'] = sent_df['neu']
    sentiment_df['bodyText_neg'] = sent_df['neg']

    # Unpack comments
    sentiment_df['comments_unpacked'] = get_unpacked_comments(df)
    sentiment_df['comments_unpacked'] = sentiment_df['comments_unpacked'].str.join(' ')
#     sentiment_df = sentiment_df[['bodyText', 'bodyText_compound', 
#                          'bodyText_pos','bodyText_neu', 
#                          'bodyText_neg', 'comments', 
#                          'comments_unpacked']]

    return sentiment_df

# %% [markdown]
# `sample_df` is from `df_list[6]` so the name of the repo should be the equivalent index in `repo_names`.

# %%
repo_names[6]
# Out:
# 'BMIRDS-deepslide'

# %%
deepslide_df = get_bodyText(sample_df)

# %% [markdown]
# -----------
# ### Analyze PR `comments` Sentiment
#
# 1. Make a column containing list of comments per PR
# 2. Calculate sentiment for concatenated comments per PR
# 3. Append a column of a single sentiment value for each comment list per PR

# %%
deepslide_df.head()
# Out:
#   authorAssociation                                           bodyText  \
# 0      COLLABORATOR                                  …a single method.
# 1      COLLABORATOR
# 2       CONTRIBUTOR  The withRetries() method is on the Vault class...
# 3       CONTRIBUTOR                  Missed a spot in my prior PR.  :(
# 4       CONTRIBUTOR                                           Fixes #8
#
#                    closedAt  \
# 0 2016-01-17 21:21:05+00:00
# 1 2016-01-17 23:40:39+00:00
# 2 2016-03-01 16:37:31+00:00
# 3 2016-03-01 16:37:46+00:00
# 4 2016-03-20 01:07:26+00:00
#
#                                             comments  \
# 0                     {'totalCount': 0, 'nodes': []}
# 1                     {'totalCount': 0, 'nodes': []}
# 2  {'totalCount': 1, 'nodes': [{'author': {'login...
# 3  {'totalCount': 1, 'nodes': [{'author': {'login...
# 4                     {'totalCount': 0, 'nodes': []}
#
#                   createdAt                           resourcePath   state  \
# 0 2016-01-17 21:20:38+00:00  /BetterCloud/vault-java-driver/pull/1  MERGED
# 1 2016-01-17 23:40:20+00:00  /BetterCloud/vault-java-driver/pull/2  MERGED
# 2 2016-03-01 04:31:45+00:00  /BetterCloud/vault-java-driver/pull/3  MERGED
# 3 2016-03-01 04:35:43+00:00  /BetterCloud/vault-java-driver/pull/4  MERGED
# 4 2016-03-19 18:40:03+00:00  /BetterCloud/vault-java-driver/pull/9  MERGED
#
#                                                title  \
# 0  Modifies REST client to use per-verb methods, ...
# 1  Adds stubs for 'put' and 'delete' ops in REST ...
# 2        Fix position of withRetries() in call chain
# 3        Fix position of withRetries() in call chain
# 4  Keys with null values cause UnsupportedOperati...
#
#                   updatedAt         author        company  files  \
# 0 2016-01-17 21:21:05+00:00  steve-perkins  @BetterCloud       3
# 1 2016-01-17 23:40:39+00:00  steve-perkins  @BetterCloud       6
# 2 2016-03-01 16:37:37+00:00    happybob007           None      1
# 3 2016-03-01 16:37:51+00:00    happybob007           None      1
# 4 2016-03-20 01:07:26+00:00      kunickiaj   @streamsets       2
#
#            mergedBy  bodyText_compound  bodyText_pos  bodyText_neu  \
# 0  steve-perkins-bc              0.000           0.0         1.000
# 1  steve-perkins-bc                NaN           NaN           NaN
# 2  steve-perkins-bc              0.000           0.0         1.000
# 3  steve-perkins-bc             -0.296           0.0         0.694
# 4     steve-perkins              0.000           0.0         1.000
#
#    bodyText_neg comments_unpacked
# 0         0.000
# 1           NaN
# 2         0.000           Thanks!
# 3         0.306           Thanks!
# 4         0.000

# %%
def score_comments(df):
    """ Given a DataFrame with `unpacked_comments`, return a df with sentiment scores for comments."""
    commentText_list = df['comments_unpacked'].values.tolist()
    commentText_sentiment = []
    no_sentiment_data = {'neg': np.NaN, 'neu': np.NaN, 'pos': np.NaN, 'compound': np.NaN}
    
    sid = SentimentIntensityAnalyzer()

    for obs in commentText_list:
        if len(obs) == 0:
            commentText_sentiment.append(no_sentiment_data)
        else:
            # Converts list of comments to a single `str` comment
            combined_text = ''.join(obs)

            # Remove punctuation
            combined_text = combined_text.replace('\n', '')
            for punct in string.punctuation:
                combined_text = combined_text.replace(punct, '')

            # Tokenize bodyText: this function returns a single-item list
            # This will catch comments that are only punctuation/empty and append NaNs
            try:
                sent = nltk.sent_tokenize(combined_text)[0]
                polarity_score = sid.polarity_scores(sent)
                commentText_sentiment.append(polarity_score)
            except:
                commentText_sentiment.append(no_sentiment_data)

            del combined_text
    
    sent_df = pd.DataFrame(commentText_sentiment)
    df['comments_compound'] = sent_df['compound']
    df['comments_pos'] = sent_df['pos']
    df['comments_neu'] = sent_df['neu']
    df['comments_neg'] = sent_df['neg']
    
    return df

# %%
deepslide_df = score_comments(deepslide_df)
deepslide_df.head()
# Out:
#   authorAssociation                                           bodyText  \
# 0      COLLABORATOR                                  …a single method.
# 1      COLLABORATOR
# 2       CONTRIBUTOR  The withRetries() method is on the Vault class...
# 3       CONTRIBUTOR                  Missed a spot in my prior PR.  :(
# 4       CONTRIBUTOR                                           Fixes #8
#
#                    closedAt  \
# 0 2016-01-17 21:21:05+00:00
# 1 2016-01-17 23:40:39+00:00
# 2 2016-03-01 16:37:31+00:00
# 3 2016-03-01 16:37:46+00:00
# 4 2016-03-20 01:07:26+00:00
#
#                                             comments  \
# 0                     {'totalCount': 0, 'nodes': []}
# 1                     {'totalCount': 0, 'nodes': []}
# 2  {'totalCount': 1, 'nodes': [{'author': {'login...
# 3  {'totalCount': 1, 'nodes': [{'author': {'login...
# 4                     {'totalCount': 0, 'nodes': []}
#
#                   createdAt                           resourcePath   state  \
# 0 2016-01-17 21:20:38+00:00  /BetterCloud/vault-java-driver/pull/1  MERGED
# 1 2016-01-17 23:40:20+00:00  /BetterCloud/vault-java-driver/pull/2  MERGED
# 2 2016-03-01 04:31:45+00:00  /BetterCloud/vault-java-driver/pull/3  MERGED
# 3 2016-03-01 04:35:43+00:00  /BetterCloud/vault-java-driver/pull/4  MERGED
# 4 2016-03-19 18:40:03+00:00  /BetterCloud/vault-java-driver/pull/9  MERGED
#
#                                                title  \
# 0  Modifies REST client to use per-verb methods, ...
# 1  Adds stubs for 'put' and 'delete' ops in REST ...
# 2        Fix position of withRetries() in call chain
# 3        Fix position of withRetries() in call chain
# 4  Keys with null values cause UnsupportedOperati...
#
#                   updatedAt         author  ...          mergedBy  \
# 0 2016-01-17 21:21:05+00:00  steve-perkins  ...  steve-perkins-bc
# 1 2016-01-17 23:40:39+00:00  steve-perkins  ...  steve-perkins-bc
# 2 2016-03-01 16:37:37+00:00    happybob007  ...  steve-perkins-bc
# 3 2016-03-01 16:37:51+00:00    happybob007  ...  steve-perkins-bc
# 4 2016-03-20 01:07:26+00:00      kunickiaj  ...     steve-perkins
#
#    bodyText_compound bodyText_pos  bodyText_neu  bodyText_neg  \
# 0              0.000          0.0         1.000         0.000
# 1                NaN          NaN           NaN           NaN
# 2              0.000          0.0         1.000         0.000
# 3             -0.296          0.0         0.694         0.306
# 4              0.000          0.0         1.000         0.000
#
#    comments_unpacked  comments_compound comments_pos  comments_neu  \
# 0                                   NaN          NaN           NaN
# 1                                   NaN          NaN           NaN
# 2            Thanks!             0.4404          1.0           0.0
# 3            Thanks!             0.4404          1.0           0.0
# 4                                   NaN          NaN           NaN
#
#    comments_neg
# 0           NaN
# 1           NaN
# 2           0.0
# 3           0.0
# 4           NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ------------
# ### Perform Sentiment Analysis for All DataFrames

# %%
nlp_list = []
for df in df_list:
    df2 = df.copy()
    df2 = get_bodyText(df2)
    df2 = score_comments(df2)
    nlp_list.append(df2)
print(len(nlp_list), len(df_list))
# Out:
# 575 575

# %%
nlp_list[6].head()
# Out:
#   authorAssociation                                           bodyText  \
# 0       CONTRIBUTOR  Allows for items to do shearing actions on she...
# 1       CONTRIBUTOR  Split ModLoader's "modtick" client profiler se...
# 2              NONE                                              ...t.
# 3              NONE       Fix of a small spelling error of 'frequency'
# 4       CONTRIBUTOR  IChunkLoadHandler with register functions call...
#
#                    closedAt  \
# 0 2012-02-14 21:15:24+00:00
# 1 2012-06-06 01:49:47+00:00
# 2 2012-02-24 20:45:41+00:00
# 3 2012-02-25 23:28:15+00:00
# 4 2012-03-09 06:49:23+00:00
#
#                                             comments  \
# 0  {'totalCount': 1, 'nodes': [{'author': {'login...
# 1  {'totalCount': 1, 'nodes': [{'author': {'login...
# 2                     {'totalCount': 0, 'nodes': []}
# 3                     {'totalCount': 0, 'nodes': []}
# 4  {'totalCount': 1, 'nodes': [{'author': {'login...
#
#                   createdAt                           resourcePath   state  \
# 0 2012-02-10 16:21:34+00:00  /MinecraftForge/MinecraftForge/pull/1  CLOSED
# 1 2012-02-22 19:34:18+00:00  /MinecraftForge/MinecraftForge/pull/2  CLOSED
# 2 2012-02-24 20:26:46+00:00  /MinecraftForge/MinecraftForge/pull/3  MERGED
# 3 2012-02-25 18:50:08+00:00  /MinecraftForge/MinecraftForge/pull/4  MERGED
# 4 2012-02-27 07:08:05+00:00  /MinecraftForge/MinecraftForge/pull/5  CLOSED
#
#                                                title  \
# 0                               Add a shears handler
# 1                   ModLoader profiling improvements
# 2  People may think the server needs the mods to ...
# 3                                 Fix spelling error
# 4                               Add chunkload hooks.
#
#                   updatedAt         author  ...        mergedBy  \
# 0 2014-06-27 09:11:47+00:00    richardg867  ...             NaN
# 1 2014-06-14 14:25:04+00:00    richardg867  ...             NaN
# 2 2014-07-09 09:13:01+00:00            NaN  ...  MinecraftForge
# 3 2014-08-15 22:02:56+00:00            NaN  ...  MinecraftForge
# 4 2014-06-15 02:05:08+00:00  Chicken-Bones  ...             NaN
#
#    bodyText_compound bodyText_pos  bodyText_neu  bodyText_neg  \
# 0             0.3612        0.167         0.760         0.072
# 1             0.0258        0.040         0.908         0.053
# 2             0.0000        0.000         0.000         0.000
# 3            -0.4019        0.000         0.690         0.310
# 4             0.0258        0.068         0.932         0.000
#
#                                    comments_unpacked  comments_compound  \
# 0      Implemented in a more generic fashion f2b973e             0.0000
# 1  I would find this useful yes, but I fear most ...            -0.3099
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                              Added             0.0000
#
#   comments_pos  comments_neu  comments_neg
# 0        0.000         1.000         0.000
# 1        0.098         0.798         0.104
# 2          NaN           NaN           NaN
# 3          NaN           NaN           NaN
# 4        0.000         1.000         0.000
#
# [5 rows x 22 columns]

# %%
import pickle

with open('PR_nlp_analysis.pkl', 'wb') as f:
    pickle.dump(nlp_list, f)
